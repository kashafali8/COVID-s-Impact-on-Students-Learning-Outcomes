# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gc

# %%
# Reading files

# Read in the data
# 2018
ela_2018 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2018\Annual EM ELA.csv"
)
math_2018 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2018\Annual EM Math.csv"
)
science_2018 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2018\Annual EM SCIENCE.csv"
)
# Out:
# C:\Users\ericr\AppData\Local\Temp\ipykernel_6576\1614234590.py:5: DtypeWarning: Columns (15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   ela_2018 = pd.read_csv(
# C:\Users\ericr\AppData\Local\Temp\ipykernel_6576\1614234590.py:8: DtypeWarning: Columns (15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   math_2018 = pd.read_csv(
# C:\Users\ericr\AppData\Local\Temp\ipykernel_6576\1614234590.py:11: DtypeWarning: Columns (15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   science_2018 = pd.read_csv(

# %%
# Checking types
ela_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 654694 entries, 0 to 654693
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ENTITY_CD           654694 non-null  int64
#  1   ENTITY_NAME         654694 non-null  object
#  2   YEAR                654694 non-null  int64
#  3   ASSESSMENT_NAME     654694 non-null  object
#  4   SUBGROUP_NAME       654694 non-null  object
#  5   NUM_TESTED          654694 non-null  int64
#  6   NOT_TESTED          654694 non-null  int64
#  7   LEVEL1_COUNT        654694 non-null  object
#  8   LEVEL1_%TESTED      654694 non-null  object
#  9   LEVEL2_COUNT        654694 non-null  object
#  10  LEVEL2_%TESTED      654694 non-null  object
#  11  LEVEL3_COUNT        654694 non-null  object
#  12  LEVEL3_%TESTED      654694 non-null  object
#  13  LEVEL4_COUNT        654694 non-null  object
#  14  LEVEL4_%TESTED      654694 non-null  object
#  15  LEVEL5_COUNT        304561 non-null  object
#  16  LEVEL5_%TESTED      304561 non-null  object
#  17  NUM_PROF            304561 non-null  object
#  18  PER_PROF            304561 non-null  object
#  19  TOTAL_SCALE_SCORES  654694 non-null  object
#  20  MEAN_SCORE          620662 non-null  object
# dtypes: int64(4), object(17)
# memory usage: 104.9+ MB

# %%
ela_2018["NUM_TESTED"].isnull().sum()
# Out:
# 0

# %%
# Our columns of interest
Team_9_keep_cols = ["NUM_TESTED", "NUM_PROF", "TOTAL_SCALE_SCORES", "MEAN_SCORE"]
subgroup_9_keep_cols = [
    "Hispanic or Latino",
    "Black or African American",
    "American Indian or Alaska Native",
    "Asian or Native Hawaiian/Other Pacific Islander",
    "Multiracial",
    "White",
]

# %%
# Scouting racial groups
ela_2018.SUBGROUP_NAME.unique()
# Out:
# array(['Hispanic or Latino', 'Homeless', 'Male',
#        'Non-English Language Learners', 'Not Economically Disadvantaged',
#        'American Indian or Alaska Native',
#        'Asian or Native Hawaiian/Other Pacific Islander',
#        'Black or African American', 'Economically Disadvantaged',
#        'English Language Learners', 'Female', 'General Education',
#        'Multiracial', 'All Students', 'Not Migrant',
#        'Students with Disabilities', 'White', 'Migrant',
#        'Small Group Total', 'American Indian or Alaska Native Female',
#        'American Indian or Alaska Native Male',
#        'Asian or Native Hawaiian/Other Pacific Islander Female',
#        'Asian or Native Hawaiian/Other Pacific Islander Male',
#        'Black or African American Female',
#        'Black or African American Male', 'Hispanic or Latino Female',
#        'Hispanic or Latino Male', 'Multiracial Female',
#        'Multiracial Male', 'White Female', 'White Male', 'Not Homeless',
#        'Not in Foster Care', 'Parent in Armed Forces',
#        'Parent Not in Armed Forces', 'In Foster Care'], dtype=object)

# %%
for col in Team_9_keep_cols:

    for val in ela_2018[col].unique():
        
        try:
            
            int(val)

            if int(val) <= 0:
                print(col, val)
            
        except:
            print(col, val)
# Out:
# NUM_PROF 0
# NUM_PROF s
# NUM_PROF nan
# TOTAL_SCALE_SCORES s
# TOTAL_SCALE_SCORES 00
# MEAN_SCORE s
# MEAN_SCORE 00
# MEAN_SCORE nan

# %%
def sanity_check_entity_cd(ds):
    
    for i in ds.ENTITY_CD.unique():
        try: 
            int(i)
        except:
            print(i)

# %%
def race_df_maker(
    df: pd.DataFrame,
    base_cols: list[str],
    subgroups: list[str],
    keep_cols: list[str] = [],
    impute: bool = False,
    race_refactor: bool = False,
    show_refactor : bool = False,
    check : bool = False,
) -> pd.DataFrame:
    """Takes a our base dataframe and stacks the subgroups horizontally
    via a merge.
    """

    copy_df = df.copy()  # to contain all the core records

    copy_df["Subject"] = copy_df["ASSESSMENT_NAME"].str.extract(
        r"([A-Za-z]*).*", expand=False
    )

    if race_refactor:

        for col in keep_cols:
            try:
                copy_df[col].fillna(0, inplace=True)
            except:
                print(col, "fillna failed")

            try:
                copy_df[copy_df[col] == "nan"] = 0
            except:
                print(col, "string nan replacement failed")   
                pass
                 
            try:
                copy_df[copy_df[col] == "s"] = 0
            except:
                print(col, "s replacement failed")

            try:
                copy_df[copy_df[col] == "00"] = 0
            except:
                print(col, "00 replacement failed")
                raise ValueError("Processing error")
            
            copy_df[col] = copy_df[col].astype(float)

    else:
        copy_df[copy_df.MEAN_SCORE == "s"] = np.nan

    if impute:
        copy_df["MEAN_SCORE"] = copy_df["MEAN_SCORE"].astype(float)

        copy_df["MEAN_SCORE"].fillna(
            copy_df.groupby(["YEAR", "ENTITY_CD", "Subject"])["MEAN_SCORE"].transform(
                "mean"
            ),
            inplace=True,
        )

    base_cols.append("Subject")

    if keep_cols != []:
        new_cols = keep_cols + base_cols + ["SUBGROUP_NAME"]

    else:
        new_cols = base_cols + ["SUBGROUP_NAME"]

    base_df = copy_df[new_cols].copy()  # get the core records

    base_df.drop_duplicates(
        subset=base_cols, inplace=True, ignore_index=True
    )  # remove duplicates

    core_df = copy_df[new_cols].copy()  # get the core records

    # At this point, we have a df custom to merge with Team 9's base data
    # that contains all the schools,
    # But we still need the data by race

    # We will create a dictionary of dataframes

    for group in subgroups:
        # copy to avoid pointer issues

        group_df = core_df[core_df["SUBGROUP_NAME"] == group].copy()

        formatted_name = group.replace(" ", "_").lower()

        base_df = base_df.merge(
            group_df, on=base_cols, how="left", suffixes=("", f"_{formatted_name}")
        )

    # Removing the subgroup name columns

    ls_subgroup_cols = [
        col for col in base_df.columns if "subgroup_name" in col.lower()
    ]

    extra_cols = ["NUM_TESTED", "NUM_PROF", "TOTAL_SCALE_SCORES", "MEAN_SCORE"]

    base_df.drop(columns=ls_subgroup_cols + extra_cols, inplace=True)

    if race_refactor:

        for col in keep_cols:

            col_to_add = col + "_non_white"

            base_df[col_to_add] = 0

            for other_col in base_df.columns:

                if col in other_col and not ("white" in other_col):

                    base_df[col_to_add] += base_df[other_col].fillna(0)

            base_df[col_to_add] = base_df[col_to_add].astype(float)
            base_df[base_df[col_to_add] == 0] = np.nan

        
        if show_refactor:

            return base_df
        
        else:

            # Mean score fix

            see_dict = {"MEAN_SCORE" : []}
            for other_col in base_df.columns:
                
                # print(other_col, "MEAN_SCORE" in other_col)
                if "MEAN_SCORE" in other_col and not ("white" in other_col):
                    see_dict["MEAN_SCORE"].append(other_col)
                    # print("appended", other_col)

            # print(see_dict)
            mean_fix = base_df[see_dict["MEAN_SCORE"]].copy()
            mean_fix["MEAN_SCORE_non_white"] = mean_fix.mean(axis=1, skipna=True)
            base_df["MEAN_SCORE_non_white"] = mean_fix["MEAN_SCORE_non_white"]
            if check is True:
                return mean_fix
            
            
            for col in keep_cols:

                for other_col in base_df.columns:

                    if col in other_col and not ("white" in other_col):

                        base_df.drop(columns=other_col, inplace=True)

    return base_df

# %%
# testing the function
race_df_maker(
    ela_2018,
    ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
    subgroup_9_keep_cols, keep_cols=Team_9_keep_cols
).keys()
# Out:
# Index(['ENTITY_CD', 'YEAR', 'ASSESSMENT_NAME', 'Subject',
#        'NUM_TESTED_hispanic_or_latino', 'NUM_PROF_hispanic_or_latino',
#        'TOTAL_SCALE_SCORES_hispanic_or_latino',
#        'MEAN_SCORE_hispanic_or_latino', 'NUM_TESTED_black_or_african_american',
#        'NUM_PROF_black_or_african_american',
#        'TOTAL_SCALE_SCORES_black_or_african_american',
#        'MEAN_SCORE_black_or_african_american',
#        'NUM_TESTED_american_indian_or_alaska_native',
#        'NUM_PROF_american_indian_or_alaska_native',
#        'TOTAL_SCALE_SCORES_american_indian_or_alaska_native',
#        'MEAN_SCORE_american_indian_or_alaska_native',
#        'NUM_TESTED_asian_or_native_hawaiian/other_pacific_islander',
#        'NUM_PROF_asian_or_native_hawaiian/other_pacific_islander',
#        'TOTAL_SCALE_SCORES_asian_or_native_hawaiian/other_pacific_islander',
#        'MEAN_SCORE_asian_or_native_hawaiian/other_pacific_islander',
#        'NUM_TESTED_multiracial', 'NUM_PROF_multiracial',
#        'TOTAL_SCALE_SCORES_multiracial', 'MEAN_SCORE_multiracial',
#        'NUM_TESTED_white', 'NUM_PROF_white', 'TOTAL_SCALE_SCORES_white',
#        'MEAN_SCORE_white'],
#       dtype='object')

# %%
race_df_maker(
    ela_2018,
    ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
    subgroup_9_keep_cols, keep_cols=Team_9_keep_cols
).shape
# Out:
# (36740, 28)

# %%
x = race_df_maker(
    ela_2018,
    ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
    subgroup_9_keep_cols, keep_cols=Team_9_keep_cols
)

# %%
x.isnull().sum()
# Out:
# ENTITY_CD                                                                 1
# YEAR                                                                      1
# ASSESSMENT_NAME                                                           1
# Subject                                                                   1
# NUM_TESTED_hispanic_or_latino                                         20229
# NUM_PROF_hispanic_or_latino                                           28298
# TOTAL_SCALE_SCORES_hispanic_or_latino                                 20229
# MEAN_SCORE_hispanic_or_latino                                         20229
# NUM_TESTED_black_or_african_american                                  24739
# NUM_PROF_black_or_african_american                                    30693
# TOTAL_SCALE_SCORES_black_or_african_american                          24739
# MEAN_SCORE_black_or_african_american                                  24739
# NUM_TESTED_american_indian_or_alaska_native                           35656
# NUM_PROF_american_indian_or_alaska_native                             36194
# TOTAL_SCALE_SCORES_american_indian_or_alaska_native                   35656
# MEAN_SCORE_american_indian_or_alaska_native                           35656
# NUM_TESTED_asian_or_native_hawaiian/other_pacific_islander            28702
# NUM_PROF_asian_or_native_hawaiian/other_pacific_islander              32654
# TOTAL_SCALE_SCORES_asian_or_native_hawaiian/other_pacific_islander    28702
# MEAN_SCORE_asian_or_native_hawaiian/other_pacific_islander            28702
# NUM_TESTED_multiracial                                                32710
# NUM_PROF_multiracial                                                  34607
# TOTAL_SCALE_SCORES_multiracial                                        32710
# MEAN_SCORE_multiracial                                                32710
# NUM_TESTED_white                                                      17807
# NUM_PROF_white                                                        27184
# TOTAL_SCALE_SCORES_white                                              17807
# MEAN_SCORE_white                                                      17807
# dtype: int64

# %%
x
# Out:
#           ENTITY_CD    YEAR ASSESSMENT_NAME Subject
# 0      3.314000e+11  2018.0            ELA8     ELA  \
# 1      3.314000e+11  2018.0            ELA7     ELA
# 2      3.314000e+11  2018.0            ELA6     ELA
# 3               NaN     NaN             NaN     NaN
# 4      3.314000e+11  2018.0            ELA8     ELA
# ...             ...     ...             ...     ...
# 36735  6.808010e+11  2018.0            ELA5     ELA
# 36736  6.808010e+11  2018.0          ELA3_8     ELA
# 36737  6.808010e+11  2018.0            ELA6     ELA
# 36738  6.808010e+11  2018.0            ELA3     ELA
# 36739  6.808010e+11  2018.0            ELA4     ELA
#
#        NUM_TESTED_hispanic_or_latino NUM_PROF_hispanic_or_latino
# 0                               39.0                           7  \
# 1                               36.0                           6
# 2                               36.0                          15
# 3                                NaN                         NaN
# 4                               24.0                          10
# ...                              ...                         ...
# 36735                            NaN                         NaN
# 36736                            NaN                         NaN
# 36737                            NaN                         NaN
# 36738                            NaN                         NaN
# 36739                            NaN                         NaN
#
#       TOTAL_SCALE_SCORES_hispanic_or_latino MEAN_SCORE_hispanic_or_latino
# 0                                     22910                           587  \
# 1                                     21346                           593
# 2                                     21466                           596
# 3                                       NaN                           NaN
# 4                                     14345                           598
# ...                                     ...                           ...
# 36735                                   NaN                           NaN
# 36736                                   NaN                           NaN
# 36737                                   NaN                           NaN
# 36738                                   NaN                           NaN
# 36739                                   NaN                           NaN
#
#        NUM_TESTED_black_or_african_american
# 0                                       NaN  \
# 1                                       NaN
# 2                                      12.0
# 3                                       NaN
# 4                                      14.0
# ...                                     ...
# 36735                                   NaN
# 36736                                   NaN
# 36737                                   NaN
# 36738                                   NaN
# 36739                                   NaN
#
#       NUM_PROF_black_or_african_american  ...
# 0                                    NaN  ...  \
# 1                                    NaN  ...
# 2                                      2  ...
# 3                                    NaN  ...
# 4                                      6  ...
# ...                                  ...  ...
# 36735                                NaN  ...
# 36736                                NaN  ...
# 36737                                NaN  ...
# 36738                                NaN  ...
# 36739                                NaN  ...
#
#       TOTAL_SCALE_SCORES_asian_or_native_hawaiian/other_pacific_islander
# 0                                                    NaN                  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36735                                                NaN
# 36736                                                NaN
# 36737                                                NaN
# 36738                                                NaN
# 36739                                                NaN
#
#       MEAN_SCORE_asian_or_native_hawaiian/other_pacific_islander
# 0                                                    NaN          \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36735                                                NaN
# 36736                                                NaN
# 36737                                                NaN
# 36738                                                NaN
# 36739                                                NaN
#
#        NUM_TESTED_multiracial NUM_PROF_multiracial
# 0                         NaN                  NaN  \
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
# ...                       ...                  ...
# 36735                     NaN                  NaN
# 36736                     NaN                  NaN
# 36737                     NaN                  NaN
# 36738                     NaN                  NaN
# 36739                     NaN                  NaN
#
#       TOTAL_SCALE_SCORES_multiracial MEAN_SCORE_multiracial  NUM_TESTED_white
# 0                                NaN                    NaN               NaN  \
# 1                                NaN                    NaN               NaN
# 2                                NaN                    NaN               NaN
# 3                                NaN                    NaN               NaN
# 4                                NaN                    NaN               NaN
# ...                              ...                    ...               ...
# 36735                            NaN                    NaN               NaN
# 36736                            NaN                    NaN               NaN
# 36737                            NaN                    NaN               NaN
# 36738                            NaN                    NaN               NaN
# 36739                            NaN                    NaN               NaN
#
#       NUM_PROF_white TOTAL_SCALE_SCORES_white MEAN_SCORE_white
# 0                NaN                      NaN              NaN
# 1                NaN                      NaN              NaN
# 2                NaN                      NaN              NaN
# 3                NaN                      NaN              NaN
# 4                NaN                      NaN              NaN
# ...              ...                      ...              ...
# 36735            NaN                      NaN              NaN
# 36736            NaN                      NaN              NaN
# 36737            NaN                      NaN              NaN
# 36738            NaN                      NaN              NaN
# 36739            NaN                      NaN              NaN
#
# [36740 rows x 28 columns]

# %%
x.isnull().sum()
# Out:
# ENTITY_CD                                                                 1
# YEAR                                                                      1
# ASSESSMENT_NAME                                                           1
# Subject                                                                   1
# NUM_TESTED_hispanic_or_latino                                         20229
# NUM_PROF_hispanic_or_latino                                           28298
# TOTAL_SCALE_SCORES_hispanic_or_latino                                 20229
# MEAN_SCORE_hispanic_or_latino                                         20229
# NUM_TESTED_black_or_african_american                                  24739
# NUM_PROF_black_or_african_american                                    30693
# TOTAL_SCALE_SCORES_black_or_african_american                          24739
# MEAN_SCORE_black_or_african_american                                  24739
# NUM_TESTED_american_indian_or_alaska_native                           35656
# NUM_PROF_american_indian_or_alaska_native                             36194
# TOTAL_SCALE_SCORES_american_indian_or_alaska_native                   35656
# MEAN_SCORE_american_indian_or_alaska_native                           35656
# NUM_TESTED_asian_or_native_hawaiian/other_pacific_islander            28702
# NUM_PROF_asian_or_native_hawaiian/other_pacific_islander              32654
# TOTAL_SCALE_SCORES_asian_or_native_hawaiian/other_pacific_islander    28702
# MEAN_SCORE_asian_or_native_hawaiian/other_pacific_islander            28702
# NUM_TESTED_multiracial                                                32710
# NUM_PROF_multiracial                                                  34607
# TOTAL_SCALE_SCORES_multiracial                                        32710
# MEAN_SCORE_multiracial                                                32710
# NUM_TESTED_white                                                      17807
# NUM_PROF_white                                                        27184
# TOTAL_SCALE_SCORES_white                                              17807
# MEAN_SCORE_white                                                      17807
# dtype: int64

# %%
y = race_df_maker(
    ela_2018,
    ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
    subgroup_9_keep_cols, keep_cols=Team_9_keep_cols,
    race_refactor=True,
    show_refactor=True,
)

y
# Out:
#           ENTITY_CD    YEAR ASSESSMENT_NAME Subject
# 0      3.314000e+11  2018.0            ELA8     ELA  \
# 1      3.314000e+11  2018.0            ELA7     ELA
# 2      3.314000e+11  2018.0            ELA6     ELA
# 3               NaN     NaN             NaN     NaN
# 4      3.314000e+11  2018.0            ELA8     ELA
# ...             ...     ...             ...     ...
# 32376           NaN     NaN             NaN     NaN
# 32377           NaN     NaN             NaN     NaN
# 32378           NaN     NaN             NaN     NaN
# 32379           NaN     NaN             NaN     NaN
# 32380           NaN     NaN             NaN     NaN
#
#        NUM_TESTED_hispanic_or_latino  NUM_PROF_hispanic_or_latino
# 0                               39.0                          7.0  \
# 1                               36.0                          6.0
# 2                               36.0                         15.0
# 3                                NaN                          NaN
# 4                               24.0                         10.0
# ...                              ...                          ...
# 32376                            NaN                          NaN
# 32377                            NaN                          NaN
# 32378                            NaN                          NaN
# 32379                            NaN                          NaN
# 32380                            NaN                          NaN
#
#        TOTAL_SCALE_SCORES_hispanic_or_latino  MEAN_SCORE_hispanic_or_latino
# 0                                    22910.0                          587.0  \
# 1                                    21346.0                          593.0
# 2                                    21466.0                          596.0
# 3                                        NaN                            NaN
# 4                                    14345.0                          598.0
# ...                                      ...                            ...
# 32376                                    NaN                            NaN
# 32377                                    NaN                            NaN
# 32378                                    NaN                            NaN
# 32379                                    NaN                            NaN
# 32380                                    NaN                            NaN
#
#        NUM_TESTED_black_or_african_american
# 0                                       NaN  \
# 1                                       NaN
# 2                                      12.0
# 3                                       NaN
# 4                                      14.0
# ...                                     ...
# 32376                                   NaN
# 32377                                   NaN
# 32378                                   NaN
# 32379                                   NaN
# 32380                                   NaN
#
#        NUM_PROF_black_or_african_american  ...
# 0                                     NaN  ...  \
# 1                                     NaN  ...
# 2                                     2.0  ...
# 3                                     NaN  ...
# 4                                     6.0  ...
# ...                                   ...  ...
# 32376                                 NaN  ...
# 32377                                 NaN  ...
# 32378                                 NaN  ...
# 32379                                 NaN  ...
# 32380                                 NaN  ...
#
#        TOTAL_SCALE_SCORES_multiracial  MEAN_SCORE_multiracial
# 0                                 NaN                     NaN  \
# 1                                 NaN                     NaN
# 2                                 NaN                     NaN
# 3                                 NaN                     NaN
# 4                                 NaN                     NaN
# ...                               ...                     ...
# 32376                             NaN                     NaN
# 32377                             NaN                     NaN
# 32378                             NaN                     NaN
# 32379                             NaN                     NaN
# 32380                             NaN                     NaN
#
#        NUM_TESTED_white  NUM_PROF_white  TOTAL_SCALE_SCORES_white
# 0                   NaN             NaN                       NaN  \
# 1                   NaN             NaN                       NaN
# 2                   NaN             NaN                       NaN
# 3                   NaN             NaN                       NaN
# 4                   NaN             NaN                       NaN
# ...                 ...             ...                       ...
# 32376               NaN             NaN                       NaN
# 32377               NaN             NaN                       NaN
# 32378               NaN             NaN                       NaN
# 32379               NaN             NaN                       NaN
# 32380               NaN             NaN                       NaN
#
#        MEAN_SCORE_white  NUM_TESTED_non_white  NUM_PROF_non_white
# 0                   NaN                  39.0                 7.0  \
# 1                   NaN                  36.0                 6.0
# 2                   NaN                  48.0                17.0
# 3                   NaN                   NaN                 NaN
# 4                   NaN                  38.0                16.0
# ...                 ...                   ...                 ...
# 32376               NaN                   NaN                 NaN
# 32377               NaN                   NaN                 NaN
# 32378               NaN                   NaN                 NaN
# 32379               NaN                   NaN                 NaN
# 32380               NaN                   NaN                 NaN
#
#        TOTAL_SCALE_SCORES_non_white  MEAN_SCORE_non_white
# 0                           22910.0                 587.0
# 1                           21346.0                 593.0
# 2                           28589.0                1190.0
# 3                               NaN                   NaN
# 4                           22729.0                1197.0
# ...                             ...                   ...
# 32376                           NaN                   NaN
# 32377                           NaN                   NaN
# 32378                           NaN                   NaN
# 32379                           NaN                   NaN
# 32380                           NaN                   NaN
#
# [32381 rows x 32 columns]

# %%
see_dict = {}
for col in Team_9_keep_cols:
    see_list = []   
    for other_col in y.columns:
        if col in other_col and (not ("white" in other_col) or "non_white" in other_col):
            see_list.append(other_col)
    see_dict[col] = see_list

# %%
y[see_dict['NUM_TESTED']]
# Out:
#        NUM_TESTED_hispanic_or_latino  NUM_TESTED_black_or_african_american
# 0                               39.0                                   NaN  \
# 1                               36.0                                   NaN
# 2                               36.0                                  12.0
# 3                                NaN                                   NaN
# 4                               24.0                                  14.0
# ...                              ...                                   ...
# 32376                            NaN                                   NaN
# 32377                            NaN                                   NaN
# 32378                            NaN                                   NaN
# 32379                            NaN                                   NaN
# 32380                            NaN                                   NaN
#
#        NUM_TESTED_american_indian_or_alaska_native
# 0                                              NaN  \
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 32376                                          NaN
# 32377                                          NaN
# 32378                                          NaN
# 32379                                          NaN
# 32380                                          NaN
#
#        NUM_TESTED_asian_or_native_hawaiian/other_pacific_islander
# 0                                                    NaN           \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32376                                                NaN
# 32377                                                NaN
# 32378                                                NaN
# 32379                                                NaN
# 32380                                                NaN
#
#        NUM_TESTED_multiracial  NUM_TESTED_non_white
# 0                         NaN                  39.0
# 1                         NaN                  36.0
# 2                         NaN                  48.0
# 3                         NaN                   NaN
# 4                         NaN                  38.0
# ...                       ...                   ...
# 32376                     NaN                   NaN
# 32377                     NaN                   NaN
# 32378                     NaN                   NaN
# 32379                     NaN                   NaN
# 32380                     NaN                   NaN
#
# [32381 rows x 6 columns]

# %%
y[see_dict["NUM_PROF"]]
# Out:
#        NUM_PROF_hispanic_or_latino  NUM_PROF_black_or_african_american
# 0                              7.0                                 NaN  \
# 1                              6.0                                 NaN
# 2                             15.0                                 2.0
# 3                              NaN                                 NaN
# 4                             10.0                                 6.0
# ...                            ...                                 ...
# 32376                          NaN                                 NaN
# 32377                          NaN                                 NaN
# 32378                          NaN                                 NaN
# 32379                          NaN                                 NaN
# 32380                          NaN                                 NaN
#
#        NUM_PROF_american_indian_or_alaska_native
# 0                                            NaN  \
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 32376                                        NaN
# 32377                                        NaN
# 32378                                        NaN
# 32379                                        NaN
# 32380                                        NaN
#
#        NUM_PROF_asian_or_native_hawaiian/other_pacific_islander
# 0                                                    NaN         \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32376                                                NaN
# 32377                                                NaN
# 32378                                                NaN
# 32379                                                NaN
# 32380                                                NaN
#
#        NUM_PROF_multiracial  NUM_PROF_non_white
# 0                       NaN                 7.0
# 1                       NaN                 6.0
# 2                       NaN                17.0
# 3                       NaN                 NaN
# 4                       NaN                16.0
# ...                     ...                 ...
# 32376                   NaN                 NaN
# 32377                   NaN                 NaN
# 32378                   NaN                 NaN
# 32379                   NaN                 NaN
# 32380                   NaN                 NaN
#
# [32381 rows x 6 columns]

# %%
y[see_dict["TOTAL_SCALE_SCORES"]]
# Out:
#        TOTAL_SCALE_SCORES_hispanic_or_latino
# 0                                    22910.0  \
# 1                                    21346.0
# 2                                    21466.0
# 3                                        NaN
# 4                                    14345.0
# ...                                      ...
# 32376                                    NaN
# 32377                                    NaN
# 32378                                    NaN
# 32379                                    NaN
# 32380                                    NaN
#
#        TOTAL_SCALE_SCORES_black_or_african_american
# 0                                               NaN  \
# 1                                               NaN
# 2                                            7123.0
# 3                                               NaN
# 4                                            8384.0
# ...                                             ...
# 32376                                           NaN
# 32377                                           NaN
# 32378                                           NaN
# 32379                                           NaN
# 32380                                           NaN
#
#        TOTAL_SCALE_SCORES_american_indian_or_alaska_native
# 0                                                    NaN    \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32376                                                NaN
# 32377                                                NaN
# 32378                                                NaN
# 32379                                                NaN
# 32380                                                NaN
#
#        TOTAL_SCALE_SCORES_asian_or_native_hawaiian/other_pacific_islander
# 0                                                    NaN                   \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32376                                                NaN
# 32377                                                NaN
# 32378                                                NaN
# 32379                                                NaN
# 32380                                                NaN
#
#        TOTAL_SCALE_SCORES_multiracial  TOTAL_SCALE_SCORES_non_white
# 0                                 NaN                       22910.0
# 1                                 NaN                       21346.0
# 2                                 NaN                       28589.0
# 3                                 NaN                           NaN
# 4                                 NaN                       22729.0
# ...                               ...                           ...
# 32376                             NaN                           NaN
# 32377                             NaN                           NaN
# 32378                             NaN                           NaN
# 32379                             NaN                           NaN
# 32380                             NaN                           NaN
#
# [32381 rows x 6 columns]

# %%
y[see_dict["MEAN_SCORE"]]
# Out:
#        MEAN_SCORE_hispanic_or_latino  MEAN_SCORE_black_or_african_american
# 0                              587.0                                   NaN  \
# 1                              593.0                                   NaN
# 2                              596.0                                 594.0
# 3                                NaN                                   NaN
# 4                              598.0                                 599.0
# ...                              ...                                   ...
# 32376                            NaN                                   NaN
# 32377                            NaN                                   NaN
# 32378                            NaN                                   NaN
# 32379                            NaN                                   NaN
# 32380                            NaN                                   NaN
#
#        MEAN_SCORE_american_indian_or_alaska_native
# 0                                              NaN  \
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 32376                                          NaN
# 32377                                          NaN
# 32378                                          NaN
# 32379                                          NaN
# 32380                                          NaN
#
#        MEAN_SCORE_asian_or_native_hawaiian/other_pacific_islander
# 0                                                    NaN           \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32376                                                NaN
# 32377                                                NaN
# 32378                                                NaN
# 32379                                                NaN
# 32380                                                NaN
#
#        MEAN_SCORE_multiracial  MEAN_SCORE_non_white
# 0                         NaN                 587.0
# 1                         NaN                 593.0
# 2                         NaN                1190.0
# 3                         NaN                   NaN
# 4                         NaN                1197.0
# ...                       ...                   ...
# 32376                     NaN                   NaN
# 32377                     NaN                   NaN
# 32378                     NaN                   NaN
# 32379                     NaN                   NaN
# 32380                     NaN                   NaN
#
# [32381 rows x 6 columns]

# %%
y.isnull().sum()
# Out:
# ENTITY_CD                                                             21839
# YEAR                                                                  21839
# ASSESSMENT_NAME                                                       21839
# Subject                                                               21839
# NUM_TESTED_hispanic_or_latino                                         24044
# NUM_PROF_hispanic_or_latino                                           24044
# TOTAL_SCALE_SCORES_hispanic_or_latino                                 24044
# MEAN_SCORE_hispanic_or_latino                                         24044
# NUM_TESTED_black_or_african_american                                  26412
# NUM_PROF_black_or_african_american                                    26412
# TOTAL_SCALE_SCORES_black_or_african_american                          26412
# MEAN_SCORE_black_or_african_american                                  26412
# NUM_TESTED_american_indian_or_alaska_native                           31843
# NUM_PROF_american_indian_or_alaska_native                             31843
# TOTAL_SCALE_SCORES_american_indian_or_alaska_native                   31843
# MEAN_SCORE_american_indian_or_alaska_native                           31843
# NUM_TESTED_asian_or_native_hawaiian/other_pacific_islander            28295
# NUM_PROF_asian_or_native_hawaiian/other_pacific_islander              28295
# TOTAL_SCALE_SCORES_asian_or_native_hawaiian/other_pacific_islander    28295
# MEAN_SCORE_asian_or_native_hawaiian/other_pacific_islander            28295
# NUM_TESTED_multiracial                                                30259
# NUM_PROF_multiracial                                                  30259
# TOTAL_SCALE_SCORES_multiracial                                        30259
# MEAN_SCORE_multiracial                                                30259
# NUM_TESTED_white                                                      25698
# NUM_PROF_white                                                        25698
# TOTAL_SCALE_SCORES_white                                              25698
# MEAN_SCORE_white                                                      25698
# NUM_TESTED_non_white                                                  21839
# NUM_PROF_non_white                                                    21839
# TOTAL_SCALE_SCORES_non_white                                          21839
# MEAN_SCORE_non_white                                                  21839
# dtype: int64

# %%
z = race_df_maker(
    ela_2018,
    ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
    subgroup_9_keep_cols, keep_cols=Team_9_keep_cols,
    race_refactor=True,
)

z
# Out:
#           ENTITY_CD    YEAR ASSESSMENT_NAME Subject  NUM_TESTED_white
# 0      3.314000e+11  2018.0            ELA8     ELA               NaN  \
# 1      3.314000e+11  2018.0            ELA7     ELA               NaN
# 2      3.314000e+11  2018.0            ELA6     ELA               NaN
# 3               NaN     NaN             NaN     NaN               NaN
# 4      3.314000e+11  2018.0            ELA8     ELA               NaN
# ...             ...     ...             ...     ...               ...
# 32376           NaN     NaN             NaN     NaN               NaN
# 32377           NaN     NaN             NaN     NaN               NaN
# 32378           NaN     NaN             NaN     NaN               NaN
# 32379           NaN     NaN             NaN     NaN               NaN
# 32380           NaN     NaN             NaN     NaN               NaN
#
#        NUM_PROF_white  TOTAL_SCALE_SCORES_white  MEAN_SCORE_white
# 0                 NaN                       NaN               NaN  \
# 1                 NaN                       NaN               NaN
# 2                 NaN                       NaN               NaN
# 3                 NaN                       NaN               NaN
# 4                 NaN                       NaN               NaN
# ...               ...                       ...               ...
# 32376             NaN                       NaN               NaN
# 32377             NaN                       NaN               NaN
# 32378             NaN                       NaN               NaN
# 32379             NaN                       NaN               NaN
# 32380             NaN                       NaN               NaN
#
#        NUM_TESTED_non_white  NUM_PROF_non_white  TOTAL_SCALE_SCORES_non_white
# 0                      39.0                 7.0                       22910.0  \
# 1                      36.0                 6.0                       21346.0
# 2                      48.0                17.0                       28589.0
# 3                       NaN                 NaN                           NaN
# 4                      38.0                16.0                       22729.0
# ...                     ...                 ...                           ...
# 32376                   NaN                 NaN                           NaN
# 32377                   NaN                 NaN                           NaN
# 32378                   NaN                 NaN                           NaN
# 32379                   NaN                 NaN                           NaN
# 32380                   NaN                 NaN                           NaN
#
#        MEAN_SCORE_non_white
# 0                     587.0
# 1                     593.0
# 2                     595.0
# 3                       NaN
# 4                     598.5
# ...                     ...
# 32376                   NaN
# 32377                   NaN
# 32378                   NaN
# 32379                   NaN
# 32380                   NaN
#
# [32381 rows x 12 columns]

# %%
race_df_maker(
    ela_2018,
    ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
    subgroup_9_keep_cols, keep_cols=Team_9_keep_cols,
    race_refactor=True, check=True,
)
# Out:
#        MEAN_SCORE_hispanic_or_latino  MEAN_SCORE_black_or_african_american
# 0                              587.0                                   NaN  \
# 1                              593.0                                   NaN
# 2                              596.0                                 594.0
# 3                                NaN                                   NaN
# 4                              598.0                                 599.0
# ...                              ...                                   ...
# 32376                            NaN                                   NaN
# 32377                            NaN                                   NaN
# 32378                            NaN                                   NaN
# 32379                            NaN                                   NaN
# 32380                            NaN                                   NaN
#
#        MEAN_SCORE_american_indian_or_alaska_native
# 0                                              NaN  \
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 32376                                          NaN
# 32377                                          NaN
# 32378                                          NaN
# 32379                                          NaN
# 32380                                          NaN
#
#        MEAN_SCORE_asian_or_native_hawaiian/other_pacific_islander
# 0                                                    NaN           \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32376                                                NaN
# 32377                                                NaN
# 32378                                                NaN
# 32379                                                NaN
# 32380                                                NaN
#
#        MEAN_SCORE_multiracial  MEAN_SCORE_non_white
# 0                         NaN                 587.0
# 1                         NaN                 593.0
# 2                         NaN                 595.0
# 3                         NaN                   NaN
# 4                         NaN                 598.5
# ...                       ...                   ...
# 32376                     NaN                   NaN
# 32377                     NaN                   NaN
# 32378                     NaN                   NaN
# 32379                     NaN                   NaN
# 32380                     NaN                   NaN
#
# [32381 rows x 6 columns]

# %% [markdown]
# ### 2018

# %%
# testing the function
for ds in [ela_2018, math_2018, science_2018]:
    sanity_check_entity_cd(ds)
    try: 
        race_df_maker(
            ds,
            ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
            subgroup_9_keep_cols, keep_cols=Team_9_keep_cols,
            race_refactor=True,
        )

    except Exception as e:
        print(e)
        print(ds.head())
        print(ds.shape)

# %%
final_ds = None

# CHANGE HERE

for ds in [ela_2018, math_2018, science_2018]:
    assert 2018 in ds.YEAR.unique()
    print(ds.YEAR.unique())

#     new_ds = race_df_maker(
#         ds,
#         ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],  # ENTITY_NAME
#         subgroup_9_keep_cols,
#         keep_cols=Team_9_keep_cols,
#         race_refactor=True,
#     )

#     if final_ds is None:
#         final_ds = new_ds.copy()

#     else:
#         final_ds = pd.concat([final_ds, new_ds], ignore_index=True)
# Out:
# [2018 2017]
# [2017 2018]
# [2018 2017]

# %%
# sanity checks

# print("Shape of final_ds:", final_ds.shape)
# print("")

# %%
# final_ds.head(10)

# %%
# delete the dataframes to save memory
del ela_2018, math_2018, science_2018
gc.collect()
# Out:
# 640

# %% [markdown]
# ### 2019

# %%
# 2019

ela_2019 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2019\Annual EM ELA.csv"
)
math_2019 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2019\Annual EM MATH.csv"
)
science_2019 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2019\Annual EM SCIENCE.csv"
)

# testing the function
for ds in [ela_2019, math_2019, science_2019]:
    sanity_check_entity_cd(ds)

    try: 
        race_df_maker(
            ds,
            ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
            subgroup_9_keep_cols, keep_cols=Team_9_keep_cols,
            race_refactor=True,
        )

    except Exception as e:
        print(e)
        print(ds.head())
        print(ds.shape)

# %%
for ds in [ela_2019, math_2019, science_2019]:

    assert 2019 in ds.YEAR.unique()
    print(ds.YEAR.unique())
    
    new_ds = race_df_maker(
        ds,
        ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],  # ENTITY_NAME
        subgroup_9_keep_cols,
        keep_cols=Team_9_keep_cols,
        race_refactor=True,
    )

    if final_ds is None:

        final_ds = new_ds.copy()

    else:

        final_ds = pd.concat([final_ds, new_ds], ignore_index=True)
# Out:
# [2018 2019]
# [2018 2019]
# [2018 2019]

# %%
# sanity checks

print("Shape of final_ds:", final_ds.shape)
print("")
# Out:
# Shape of final_ds: (91606, 12)

# %%
final_ds.tail(10)
# Out:
#        ENTITY_CD  YEAR ASSESSMENT_NAME Subject  NUM_TESTED_white
# 91596        NaN   NaN             NaN     NaN               NaN  \
# 91597        NaN   NaN             NaN     NaN               NaN
# 91598        NaN   NaN             NaN     NaN               NaN
# 91599        NaN   NaN             NaN     NaN               NaN
# 91600        NaN   NaN             NaN     NaN               NaN
# 91601        NaN   NaN             NaN     NaN               NaN
# 91602        NaN   NaN             NaN     NaN               NaN
# 91603        NaN   NaN             NaN     NaN               NaN
# 91604        NaN   NaN             NaN     NaN               NaN
# 91605        NaN   NaN             NaN     NaN               NaN
#
#        NUM_PROF_white  TOTAL_SCALE_SCORES_white  MEAN_SCORE_white
# 91596             NaN                       NaN               NaN  \
# 91597             NaN                       NaN               NaN
# 91598             NaN                       NaN               NaN
# 91599             NaN                       NaN               NaN
# 91600             NaN                       NaN               NaN
# 91601             NaN                       NaN               NaN
# 91602             NaN                       NaN               NaN
# 91603             NaN                       NaN               NaN
# 91604             NaN                       NaN               NaN
# 91605             NaN                       NaN               NaN
#
#        NUM_TESTED_non_white  NUM_PROF_non_white  TOTAL_SCALE_SCORES_non_white
# 91596                   NaN                 NaN                           NaN  \
# 91597                   NaN                 NaN                           NaN
# 91598                   NaN                 NaN                           NaN
# 91599                   NaN                 NaN                           NaN
# 91600                   NaN                 NaN                           NaN
# 91601                   NaN                 NaN                           NaN
# 91602                   NaN                 NaN                           NaN
# 91603                   NaN                 NaN                           NaN
# 91604                   NaN                 NaN                           NaN
# 91605                   NaN                 NaN                           NaN
#
#        MEAN_SCORE_non_white
# 91596                   NaN
# 91597                   NaN
# 91598                   NaN
# 91599                   NaN
# 91600                   NaN
# 91601                   NaN
# 91602                   NaN
# 91603                   NaN
# 91604                   NaN
# 91605                   NaN

# %%
# delete the dataframes to save memory
del ela_2019, math_2019, science_2019
gc.collect()
# Out:
# 0

# %% [markdown]
# ### 2020 does not exist

# %% [markdown]
# ### 2021

# %%
# 2020 is unobserved

# 2021
ela_2021 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2021\Annual EM ELA.csv"
)
math_2021 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2021\Annual EM Math.csv"
)
science_2021 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2021\Annual EM SCIENCE.csv"
)


# testing the function

for ds in [ela_2021, math_2021, science_2021]:
    
    sanity_check_entity_cd(ds)

    try: 
        race_df_maker(
            ds,
            ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
            subgroup_9_keep_cols, keep_cols=Team_9_keep_cols,
            race_refactor=True,
        )

    except Exception as e:
        print(ds.YEAR.unique(), ds.ASSESSMENT_NAME.unique())
        print(e)
        print(ds.head())
        print(ds.shape)
        continue
# Out:
# C:\Users\ericr\AppData\Local\Temp\ipykernel_6576\684444587.py:7: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   math_2021 = pd.read_csv(
# TOTAL_SCALE_SCORES fillna failed
# TOTAL_SCALE_SCORES string nan replacement failed
# TOTAL_SCALE_SCORES s replacement failed
# TOTAL_SCALE_SCORES 00 replacement failed
# [2021] ['ELA3' 'ELA4' 'ELA5' 'ELA6' 'ELA7' 'ELA8' 'ELA3_8']
# Processing error
#    INSTITUTION_ID     ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME
# 0    8.000001e+11  111111111111  All Public Schools  2021            ELA3  \
# 1    8.000001e+11  111111111111  All Public Schools  2021            ELA3
# 2    8.000001e+11  111111111111  All Public Schools  2021            ELA3
# 3    8.000001e+11  111111111111  All Public Schools  2021            ELA3
# 4    8.000001e+11  111111111111  All Public Schools  2021            ELA3
#
#                       SUBGROUP_NAME  TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED
# 0                      All Students       192560       99642              52  \
# 1                            Female        93485       47472              51
# 2                              Male        99075       52170              53
# 3  American Indian or Alaska Native         1469         963              66
# 4         Black or African American        30796       21583              70
#
#    NUM_TESTED  ...  LEVEL1_COUNT LEVEL1_%TESTED LEVEL2_COUNT LEVEL2_%TESTED
# 0       92918  ...         12736             14        24076             26  \
# 1       46013  ...          5725             12        11651             25
# 2       46905  ...          7011             15        12425             26
# 3         506  ...            84             17          173             34
# 4        9213  ...          2215             24         3036             33
#
#   LEVEL3_COUNT LEVEL3_%TESTED LEVEL4_COUNT LEVEL4_%TESTED NUM_PROF PER_PROF
# 0        37709             41        18397             20    56106       60
# 1        19049             41         9588             21    28637       62
# 2        18660             40         8809             19    27469       59
# 3          185             37           64             13      249       49
# 4         3071             33          891             10     3962       43
#
# [5 rows x 21 columns]
# (319420, 21)
# TOTAL_SCALE_SCORES fillna failed
# TOTAL_SCALE_SCORES string nan replacement failed
# TOTAL_SCALE_SCORES s replacement failed
# TOTAL_SCALE_SCORES 00 replacement failed
# [2021] ['MATH3' 'MATH4' 'MATH5' 'MATH6' 'MATH7' 'MATH8' 'Combined7Math'
#  'RegentsMath8' 'RegentsMath7' 'Combined8Math' 'MATH3_8']
# Processing error
#    INSTITUTION_ID  ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME
# 0             NaN    4000000  CATTARAUGUS County  2021           MATH3  \
# 1             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 2             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 3             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 4             NaN    5000000       CAYUGA County  2021           MATH3
#
#                 SUBGROUP_NAME  TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED
# 0              In Foster Care          4.0           1            25.0  \
# 1          Not in Foster Care        862.0         139            16.0
# 2      Parent in Armed Forces          4.0           0             0.0
# 3  Parent Not in Armed Forces        862.0         140            16.0
# 4                All Students        642.0         107            17.0
#
#    NUM_TESTED  ...  LEVEL4_%TESTED LEVEL5_COUNT LEVEL5_%TESTED NUM_PROF
# 0           3  ...               s          NaN            NaN        s  \
# 1         723  ...               s          NaN            NaN        s
# 2           4  ...               s          NaN            NaN        s
# 3         722  ...               s          NaN            NaN        s
# 4         535  ...              15          NaN            NaN      232
#
#   PER_PROF TOTAL_EXEMPT NUM_EXEMPT_NTEST PCT_EXEMPT_NTEST NUM_EXEMPT_TEST
# 0        s          NaN              NaN              NaN             NaN  \
# 1        s          NaN              NaN              NaN             NaN
# 2        s          NaN              NaN              NaN             NaN
# 3        s          NaN              NaN              NaN             NaN
# 4       43          NaN              NaN              NaN             NaN
#
#   PCT_EXEMPT_TEST
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 28 columns]
# (325779, 28)
# TOTAL_SCALE_SCORES fillna failed
# TOTAL_SCALE_SCORES string nan replacement failed
# TOTAL_SCALE_SCORES s replacement failed
# TOTAL_SCALE_SCORES 00 replacement failed
# [2021] ['Science4' 'Science8' 'RegentsScience8' 'CombinedScience ' 'Science4_8']
# Processing error
#    INSTITUTION_ID     ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME
# 0    8.000001e+11  111111111111  All Public Schools  2021        Science4  \
# 1    8.000001e+11  111111111111  All Public Schools  2021        Science4
# 2    8.000001e+11  111111111111  All Public Schools  2021        Science4
# 3    8.000001e+11  111111111111  All Public Schools  2021        Science4
# 4    8.000001e+11  111111111111  All Public Schools  2021        Science4
#
#                       SUBGROUP_NAME  TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED
# 0                      All Students     193111.0      102757              53  \
# 1                            Female      93970.0       49789              53
# 2                              Male      99141.0       52968              53
# 3  American Indian or Alaska Native       1400.0         890              64
# 4         Black or African American      31224.0       22574              72
#
#    NUM_TESTED  ...  LEVEL3_%TESTED LEVEL4_COUNT LEVEL4_%TESTED NUM_PROF
# 0       90354  ...              35        42977             48    74535  \
# 1       44181  ...              37        19896             45    36380
# 2       46173  ...              33        23081             50    38155
# 3         510  ...              41          175             34      384
# 4        8650  ...              39         2313             27     5703
#
#   PER_PROF TOTAL_EXEMPT NUM_EXEMPT_NTEST PCT_EXEMPT_NTEST NUM_EXEMPT_TEST
# 0       82          NaN              NaN              NaN             NaN  \
# 1       82          NaN              NaN              NaN             NaN
# 2       83          NaN              NaN              NaN             NaN
# 3       75          NaN              NaN              NaN             NaN
# 4       66          NaN              NaN              NaN             NaN
#
#   PCT_EXEMPT_TEST
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 26 columns]
# (111678, 26)

# %%
math_2021.keys()
# Out:
# Index(['INSTITUTION_ID', 'ENTITY_CD', 'ENTITY_NAME', 'YEAR', 'ASSESSMENT_NAME',
#        'SUBGROUP_NAME', 'TOTAL_COUNT', 'NOT_TESTED', 'PCT_NOT_TESTED',
#        'NUM_TESTED', 'PCT_TESTED', 'LEVEL1_COUNT', 'LEVEL1_%TESTED',
#        'LEVEL2_COUNT', 'LEVEL2_%TESTED', 'LEVEL3_COUNT', 'LEVEL3_%TESTED',
#        'LEVEL4_COUNT', 'LEVEL4_%TESTED', 'LEVEL5_COUNT', 'LEVEL5_%TESTED',
#        'NUM_PROF', 'PER_PROF', 'TOTAL_EXEMPT', 'NUM_EXEMPT_NTEST',
#        'PCT_EXEMPT_NTEST', 'NUM_EXEMPT_TEST', 'PCT_EXEMPT_TEST'],
#       dtype='object')

# %% [markdown]
# >2021 has no mean scores. The message propagates across all 3 subjects.

# %%
# delete the dataframes to save memory
del ela_2021, math_2021, science_2021
gc.collect()
# Out:
# 66

# %% [markdown]
# ### 2022

# %%
# 2022

ela_2022 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2022\Annual EM ELA.csv"
)
math_2022 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2022\Annual EM Math.csv"
)
science_2022 = pd.read_csv(
    r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2022\Annual EM SCIENCE.csv"
)

# testing the function
for ds in [ela_2022, math_2022, science_2022]:

    sanity_check_entity_cd(ds)

    try: 
        race_df_maker(
            ds,
            ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"], # ENTITY_NAME
            subgroup_9_keep_cols, keep_cols=Team_9_keep_cols,
            race_refactor=True,
        )

    except Exception as e:
        print(e)
        print(ds.head())
        print(ds.shape)
# Out:
# C:\Users\ericr\AppData\Local\Temp\ipykernel_6576\3543199631.py:6: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   math_2022 = pd.read_csv(

# %%
for ds in [ela_2022, math_2022, science_2022]:

    assert 2022 in ds.YEAR.unique()
    print(ds.YEAR.value_counts())

    print(ds.YEAR.unique())
    
    new_ds = race_df_maker(
        ds,
        ["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],  # ENTITY_NAME
        subgroup_9_keep_cols,
        keep_cols=Team_9_keep_cols,
        race_refactor=True,
    )

    if final_ds is None:

        final_ds = new_ds.copy()

    else:

        final_ds = pd.concat([final_ds, new_ds], ignore_index=True)
# Out:
# YEAR
# 2022    321603
# 2021    319420
# Name: count, dtype: int64
# [2021 2022]
# YEAR
# 2022    330819
# 2021    325779
# Name: count, dtype: int64
# [2021 2022]
# YEAR
# 2022    112881
# 2021    111678
# Name: count, dtype: int64
# [2021 2022]

# %%
# sanity checks

print("Shape of final_ds:", final_ds.shape)
print("")
final_ds.tail(10)
# Out:
# Shape of final_ds: (215559, 12)
#         ENTITY_CD  YEAR ASSESSMENT_NAME Subject  NUM_TESTED_white
# 215549        NaN   NaN             NaN     NaN               NaN  \
# 215550        NaN   NaN             NaN     NaN               NaN
# 215551        NaN   NaN             NaN     NaN               NaN
# 215552        NaN   NaN             NaN     NaN               NaN
# 215553        NaN   NaN             NaN     NaN               NaN
# 215554        NaN   NaN             NaN     NaN               NaN
# 215555        NaN   NaN             NaN     NaN               NaN
# 215556        NaN   NaN             NaN     NaN               NaN
# 215557        NaN   NaN             NaN     NaN               NaN
# 215558        NaN   NaN             NaN     NaN               NaN
#
#         NUM_PROF_white  TOTAL_SCALE_SCORES_white  MEAN_SCORE_white
# 215549             NaN                       NaN               NaN  \
# 215550             NaN                       NaN               NaN
# 215551             NaN                       NaN               NaN
# 215552             NaN                       NaN               NaN
# 215553             NaN                       NaN               NaN
# 215554             NaN                       NaN               NaN
# 215555             NaN                       NaN               NaN
# 215556             NaN                       NaN               NaN
# 215557             NaN                       NaN               NaN
# 215558             NaN                       NaN               NaN
#
#         NUM_TESTED_non_white  NUM_PROF_non_white
# 215549                   NaN                 NaN  \
# 215550                   NaN                 NaN
# 215551                   NaN                 NaN
# 215552                   NaN                 NaN
# 215553                   NaN                 NaN
# 215554                   NaN                 NaN
# 215555                   NaN                 NaN
# 215556                   NaN                 NaN
# 215557                   NaN                 NaN
# 215558                   NaN                 NaN
#
#         TOTAL_SCALE_SCORES_non_white  MEAN_SCORE_non_white
# 215549                           NaN                   NaN
# 215550                           NaN                   NaN
# 215551                           NaN                   NaN
# 215552                           NaN                   NaN
# 215553                           NaN                   NaN
# 215554                           NaN                   NaN
# 215555                           NaN                   NaN
# 215556                           NaN                   NaN
# 215557                           NaN                   NaN
# 215558                           NaN                   NaN

# %%
# delete the dataframes to save memory
del ela_2022, math_2022, science_2022

# %% [markdown]
# ### Merging with Team 9's All Data CSV

# %%
all_data = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\unifying-data-science-2023-project-grupo9\final.csv")

# %%
# sanity checks
print("Shape of all_data:", all_data.shape)
# Out:
# Shape of all_data: (2933498, 4)

# %%
all_data.head()
# Out:
#    ENTITY_CD  YEAR Subject ASSESSMENT_NAME
# 0          1  2018     ELA            ELA5
# 1          1  2018     ELA          ELA3_8
# 2          1  2018     ELA            ELA3
# 3          1  2018     ELA            ELA7
# 4          1  2018     ELA            ELA8

# %%
full_data = pd.merge(all_data, final_ds, how="left", on=["ENTITY_CD", "YEAR", "Subject", "ASSESSMENT_NAME"])
full_data.head()
# Out:
#    ENTITY_CD  YEAR Subject ASSESSMENT_NAME  NUM_TESTED_white  NUM_PROF_white
# 0          1  2018     ELA            ELA5           11063.0          6383.0  \
# 1          1  2018     ELA          ELA3_8               NaN             NaN
# 2          1  2018     ELA            ELA3           11416.0          7869.0
# 3          1  2018     ELA            ELA7           10365.0          6680.0
# 4          1  2018     ELA            ELA8            9850.0          6707.0
#
#    TOTAL_SCALE_SCORES_white  MEAN_SCORE_white  NUM_TESTED_non_white
# 0                 6745329.0             610.0               57376.0  \
# 1                       NaN               NaN                   NaN
# 2                 6950213.0             609.0               55821.0
# 3                 6332714.0             611.0               54885.0
# 4                 6002917.0             609.0               53333.0
#
#    NUM_PROF_non_white  TOTAL_SCALE_SCORES_non_white  MEAN_SCORE_non_white
# 0             19607.0                    34364993.0                 602.6
# 1                 NaN                           NaN                   NaN
# 2             26167.0                    33411345.0                 602.0
# 3             21132.0                    32922142.0                 603.4
# 4             25335.0                    32016776.0                 603.2

# %%
full_data.keys()
# Out:
# Index(['ENTITY_CD', 'YEAR', 'Subject', 'ASSESSMENT_NAME', 'NUM_TESTED_white',
#        'NUM_PROF_white', 'TOTAL_SCALE_SCORES_white', 'MEAN_SCORE_white',
#        'NUM_TESTED_non_white', 'NUM_PROF_non_white',
#        'TOTAL_SCALE_SCORES_non_white', 'MEAN_SCORE_non_white'],
#       dtype='object')

# %%
full_data.to_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\unifying-data-science-2023-project-grupo9\full_data_BinaryRace_Fixed.csv", index=False)

# %%
full_data.isnull().sum()

na_cols = full_data.isnull().sum()[full_data.isnull().sum() > 0].index

# %%
full_data.isnull().sum()
# Out:
# ENTITY_CD                             0
# YEAR                                  0
# Subject                               0
# ASSESSMENT_NAME                       0
# NUM_TESTED_white                2221634
# NUM_PROF_white                  2221634
# TOTAL_SCALE_SCORES_white        2221634
# MEAN_SCORE_white                2221634
# NUM_TESTED_non_white            1659153
# NUM_PROF_non_white              1659153
# TOTAL_SCALE_SCORES_non_white    1659153
# MEAN_SCORE_non_white            1659153
# dtype: int64

# %%
test_copy = full_data.copy()

# %%
# for col in na_cols:

#     test_copy[col].fillna(test_copy.groupby(["YEAR","ENTITY_CD","Subject", "ASSESSMENT_NAME"])[col].transform("median"), inplace=True)

# %%
test_copy.head()
# Out:
#    ENTITY_CD  YEAR Subject ASSESSMENT_NAME  NUM_TESTED_white  NUM_PROF_white
# 0          1  2018     ELA            ELA5           11063.0          6383.0  \
# 1          1  2018     ELA            ELA5           11063.0          6383.0
# 2          1  2018     ELA          ELA3_8               NaN             NaN
# 3          1  2018     ELA            ELA3           11416.0          7869.0
# 4          1  2018     ELA            ELA3           11416.0          7869.0
#
#    TOTAL_SCALE_SCORES_white  MEAN_SCORE_white  NUM_TESTED_non_white
# 0                 6745329.0             610.0               57376.0  \
# 1                 6745329.0             610.0               57376.0
# 2                       NaN               NaN                   NaN
# 3                 6950213.0             609.0               55821.0
# 4                 6950213.0             609.0               55821.0
#
#    NUM_PROF_non_white  TOTAL_SCALE_SCORES_non_white  MEAN_SCORE_non_white
# 0             19607.0                    34364993.0                 602.6
# 1             19607.0                    34364993.0                 602.6
# 2                 NaN                           NaN                   NaN
# 3             26167.0                    33411345.0                 602.0
# 4             26167.0                    33411345.0                 602.0

# %%
test_copy.isnull().sum()
# Out:
# ENTITY_CD                             0
# YEAR                                  0
# Subject                               0
# ASSESSMENT_NAME                       0
# NUM_TESTED_white                2221634
# NUM_PROF_white                  2221634
# TOTAL_SCALE_SCORES_white        2221634
# MEAN_SCORE_white                2221634
# NUM_TESTED_non_white            1659153
# NUM_PROF_non_white              1659153
# TOTAL_SCALE_SCORES_non_white    1659153
# MEAN_SCORE_non_white            1659153
# dtype: int64

# %%
full_data

full_data["MEAN_SCORE"].fillna(copy_df.groupby(["YEAR", "ENTITY_CD", "Subject"])["MEAN_SCORE"].transform("mean"), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ericr\miniconda3\envs\udsV\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\ericr\miniconda3\envs\udsV\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ericr\miniconda3\envs\udsV\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MEAN_SCORE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 3
#       1 full_data
# ----> 3 full_data["MEAN_SCORE"].fillna(copy_df.groupby(["YEAR", "ENTITY_CD", "Subject"])["MEAN_SCORE"].transform("mean"), inplace=True)
#
# File c:\Users\ericr\miniconda3\envs\udsV\Lib\site-packages\pandas\core\frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File c:\Users\ericr\miniconda3\envs\udsV\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'MEAN_SCORE'
