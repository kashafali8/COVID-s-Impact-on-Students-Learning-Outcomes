# %%
import pandas as pd
import numpy as np

df_annual_em_math_2022 = pd.read_csv(
    "/Users/kashafali/Documents/Duke/Spring23/UDS/Project/Data/2022/Annual EM Math.csv"
)
# Out:
# /var/folders/2s/c87gg64118ndg_yrky9zvlnc0000gn/T/ipykernel_70083/3208445464.py:4: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_annual_em_math_2022 = pd.read_csv(

# %%
df_annual_em_math_2022.columns
# Out:
# Index(['INSTITUTION_ID', 'ENTITY_CD', 'ENTITY_NAME', 'YEAR', 'ASSESSMENT_NAME',
#        'SUBGROUP_NAME', 'TOTAL_COUNT', 'NOT_TESTED', 'PCT_NOT_TESTED',
#        'NUM_TESTED', 'PCT_TESTED', 'LEVEL1_COUNT', 'LEVEL1_%TESTED',
#        'LEVEL2_COUNT', 'LEVEL2_%TESTED', 'LEVEL3_COUNT', 'LEVEL3_%TESTED',
#        'LEVEL4_COUNT', 'LEVEL4_%TESTED', 'LEVEL5_COUNT', 'LEVEL5_%TESTED',
#        'NUM_PROF', 'PER_PROF', 'TOTAL_SCALE_SCORES', 'MEAN_SCORE',
#        'TOTAL_EXEMPT', 'NUM_EXEMPT_NTEST', 'PCT_EXEMPT_NTEST',
#        'NUM_EXEMPT_TEST', 'PCT_EXEMPT_TEST'],
#       dtype='object')

# %% [markdown]
# # Dataframe for All Students

# %%
# only keep columns
column_names = [
    "ENTITY_CD",
    "ENTITY_NAME",
    "YEAR",
    "ASSESSMENT_NAME",
    "SUBGROUP_NAME",
    "TOTAL_COUNT",
    "NOT_TESTED",
    "PCT_NOT_TESTED",
    "NUM_TESTED",
    "PCT_TESTED",
    "NUM_PROF",
    "PER_PROF",
    "TOTAL_SCALE_SCORES",
    "MEAN_SCORE",
]

df_annual_em_math_2022_total = df_annual_em_math_2022[column_names]
df_annual_em_math_2022_total = df_annual_em_math_2022_total[
    df_annual_em_math_2022_total["SUBGROUP_NAME"] == "All Students"
]

# %%
df_annual_em_math_2022_total.head()
# Out:
#        ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME SUBGROUP_NAME  \
# 4        5000000       CAYUGA County  2021           MATH3  All Students
# 16  111111111111  All Public Schools  2021           MATH3  All Students
# 39       1000000       ALBANY County  2021           MATH3  All Students
# 61       2000000     ALLEGANY County  2021           MATH3  All Students
# 81       3000000       BROOME County  2021           MATH3  All Students
#
#     TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  \
# 4         642.0         107            17.0         535        83.0      232
# 16     192538.0       98519            51.0       94019        49.0    49774
# 39       3000.0         997            33.0        2003        67.0     1112
# 61        416.0          43            10.0         373        90.0      191
# 81       1864.0         505            27.0        1359        73.0      641
#
#    PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE
# ...

# %%
df_annual_em_math_2022_merge = df_annual_em_math_2022.drop(
    columns=["SUBGROUP_NAME"]
).copy()

# %% [markdown]
# # Dataframe for Gender

# %%
df_annual_em_math_2022_gender = df_annual_em_math_2022.copy()

df_annual_em_math_2022_gender = df_annual_em_math_2022_gender[column_names]

df_annual_em_math_2022_gender = df_annual_em_math_2022_gender[
    (df_annual_em_math_2022_gender["SUBGROUP_NAME"] == "Female")
    | (df_annual_em_math_2022_gender["SUBGROUP_NAME"] == "Male")
]

# %%
# fix index
df_annual_em_math_2022_gender = df_annual_em_math_2022_gender.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_math_2022_gender = df_annual_em_math_2022_gender.reindex(
    columns=sorted(df_annual_em_math_2022_gender.columns, key=lambda x: x[::-1])
)

df_annual_em_math_2022_gender.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_math_2022_gender.columns
]

df_annual_em_math_2022_gender = pd.DataFrame(df_annual_em_math_2022_gender.to_records())

# %%
df_annual_em_math_2022_gender.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME  Female_ENTITY_NAME Female_MEAN_SCORE  \
# 0          1  2021           MATH3  NYC Public Schools               600
# 1          1  2021           MATH4  NYC Public Schools               599
# 2          1  2021           MATH5  NYC Public Schools               599
# 3          1  2021           MATH6  NYC Public Schools               599
# 4          1  2021           MATH7  NYC Public Schools               603
#
#    Female_NOT_TESTED Female_NUM_PROF  Female_NUM_TESTED  \
# 0            23468.0            5343             8974.0
# 1            23671.0            4626             8950.0
# 2            25509.0            3926             8216.0
# 3            26289.0            2970             6698.0
# 4            26862.0            3343             6481.0
#
#    Female_PCT_NOT_TESTED  Female_PCT_TESTED  ...    Male_ENTITY_NAME  \
# 0                   72.0               28.0  ...  NYC Public Schools
# ...

# %% [markdown]
# # Merge Gender Dataframe with All Students Dataframe

# %%
df_math_2022_1 = pd.merge(
    df_annual_em_math_2022_merge,
    df_annual_em_math_2022_gender,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_math_2022_1.head()
# Out:
#    INSTITUTION_ID  ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  \
# 0             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 1             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 2             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 3             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 4             NaN    5000000       CAYUGA County  2021           MATH3
#
#    TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED  ...  \
# 0          4.0           1            25.0           3        75.0  ...
# 1        862.0         139            16.0         723        84.0  ...
# 2          4.0           0             0.0           4       100.0  ...
# 3        862.0         140            16.0         722        84.0  ...
# 4        642.0         107            17.0         535        83.0  ...
#
#      Male_ENTITY_NAME Male_MEAN_SCORE Male_NOT_TESTED Male_NUM_PROF  \
# ...

# %% [markdown]
# # Dataframe for Race

# %%
df_annual_em_math_2022_race = df_annual_em_math_2022[column_names].copy()

df_annual_em_math_2022_race = df_annual_em_math_2022_race[
    (df_annual_em_math_2022_race["SUBGROUP_NAME"] == "American Indian or Alaska Native")
    | (df_annual_em_math_2022_race["SUBGROUP_NAME"] == "Black or African American")
    | (df_annual_em_math_2022_race["SUBGROUP_NAME"] == "Hispanic or Latino")
    | (
        df_annual_em_math_2022_race["SUBGROUP_NAME"]
        == "Asian or Native Hawaiian/Other Pacific Islander"
    )
    | (df_annual_em_math_2022_race["SUBGROUP_NAME"] == "White")
    | (df_annual_em_math_2022_race["SUBGROUP_NAME"] == "Multiracial")
]

# %%
# reindex

df_annual_em_math_2022_race = df_annual_em_math_2022_race.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_math_2022_race = df_annual_em_math_2022_race.reindex(
    columns=sorted(df_annual_em_math_2022_race.columns, key=lambda x: x[::-1])
)

df_annual_em_math_2022_race.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_math_2022_race.columns
]

df_annual_em_math_2022_race = pd.DataFrame(df_annual_em_math_2022_race.to_records())

# %%
df_annual_em_math_2022_race.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME  \
# 0          1  2021           MATH3
# 1          1  2021           MATH4
# 2          1  2021           MATH5
# 3          1  2021           MATH6
# 4          1  2021           MATH7
#
#   American Indian or Alaska Native_ENTITY_NAME  \
# 0                           NYC Public Schools
# 1                           NYC Public Schools
# 2                           NYC Public Schools
# 3                           NYC Public Schools
# 4                           NYC Public Schools
#
#   American Indian or Alaska Native_MEAN_SCORE  \
# 0                                         598
# 1                                         595
# 2                                         594
# 3                                         597
# 4                                         595
#
#    American Indian or Alaska Native_NOT_TESTED  \
# 0                                        684.0
# 1                                        598.0
# ...

# %% [markdown]
# # Merge Race Dataset with All Students + Gender Dataset

# %%
df_math_2022_2 = pd.merge(
    df_math_2022_1,
    df_annual_em_math_2022_race,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_math_2022_2.head()
# Out:
#    INSTITUTION_ID  ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  \
# 0             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 1             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 2             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 3             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 4             NaN    5000000       CAYUGA County  2021           MATH3
#
#    TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED  ...  \
# 0          4.0           1            25.0           3        75.0  ...
# 1        862.0         139            16.0         723        84.0  ...
# 2          4.0           0             0.0           4       100.0  ...
# 3        862.0         140            16.0         722        84.0  ...
# 4        642.0         107            17.0         535        83.0  ...
#
#     White_ENTITY_NAME White_MEAN_SCORE White_NOT_TESTED White_NUM_PROF  \
# ...

# %% [markdown]
# # English Language Learners Dataframe

# %%
df_annual_em_math_2022_eng = df_annual_em_math_2022[column_names].copy()


df_annual_em_math_2022_eng = df_annual_em_math_2022_eng[
    (df_annual_em_math_2022_eng["SUBGROUP_NAME"] == "Non-English Language Learner")
    | (df_annual_em_math_2022_eng["SUBGROUP_NAME"] == "English Language Learner")
]

# %%
# reindex

df_annual_em_math_2022_eng = df_annual_em_math_2022_eng.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_math_2022_eng = df_annual_em_math_2022_eng.reindex(
    columns=sorted(df_annual_em_math_2022_eng.columns, key=lambda x: x[::-1])
)

df_annual_em_math_2022_eng.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_math_2022_eng.columns
]

df_annual_em_math_2022_eng = pd.DataFrame(df_annual_em_math_2022_eng.to_records())

# %%
df_annual_em_math_2022_eng.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME English Language Learner_ENTITY_NAME  \
# 0          1  2021           MATH3                   NYC Public Schools
# 1          1  2021           MATH4                   NYC Public Schools
# 2          1  2021           MATH5                   NYC Public Schools
# 3          1  2021           MATH6                   NYC Public Schools
# 4          1  2021           MATH7                   NYC Public Schools
#
#   English Language Learner_MEAN_SCORE  English Language Learner_NOT_TESTED  \
# 0                                 590                               9873.0
# 1                                 587                               9069.0
# 2                                 585                               8403.0
# 3                                 584                               8344.0
# 4                                 583                               7600.0
#
#   English Language Learner_NUM_PROF  English Language Learner_NUM_TESTED  \
# ...

# %% [markdown]
# # Merge English Language Learners Dataset with All Students + Gender + Race Dataset

# %%
df_math_2022_3 = pd.merge(
    df_math_2022_2,
    df_annual_em_math_2022_eng,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_math_2022_3.head()
# Out:
#    INSTITUTION_ID  ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  \
# 0             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 1             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 2             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 3             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 4             NaN    5000000       CAYUGA County  2021           MATH3
#
#    TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED  ...  \
# 0          4.0           1            25.0           3        75.0  ...
# 1        862.0         139            16.0         723        84.0  ...
# 2          4.0           0             0.0           4       100.0  ...
# 3        862.0         140            16.0         722        84.0  ...
# 4        642.0         107            17.0         535        83.0  ...
#
#   Non-English Language Learner_ENTITY_NAME  \
# 0                       CATTARAUGUS County
# ...

# %% [markdown]
# # Dataframe for Economic Condition

# %%
df_annual_em_math_2022_econ = df_annual_em_math_2022[column_names].copy()

df_annual_em_math_2022_econ = df_annual_em_math_2022_econ[
    (df_annual_em_math_2022_econ["SUBGROUP_NAME"] == "Economically Disadvantaged")
    | (df_annual_em_math_2022_econ["SUBGROUP_NAME"] == "Not Economically Disadvantaged")
]

# %%
# reindex

df_annual_em_math_2022_econ = df_annual_em_math_2022_econ.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_math_2022_econ = df_annual_em_math_2022_econ.reindex(
    columns=sorted(df_annual_em_math_2022_econ.columns, key=lambda x: x[::-1])
)

df_annual_em_math_2022_econ.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_math_2022_econ.columns
]

df_annual_em_math_2022_econ = pd.DataFrame(df_annual_em_math_2022_econ.to_records())

# %%
df_annual_em_math_2022_econ.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME Economically Disadvantaged_ENTITY_NAME  \
# 0          1  2021           MATH3                     NYC Public Schools
# 1          1  2021           MATH4                     NYC Public Schools
# 2          1  2021           MATH5                     NYC Public Schools
# 3          1  2021           MATH6                     NYC Public Schools
# 4          1  2021           MATH7                     NYC Public Schools
#
#   Economically Disadvantaged_MEAN_SCORE  \
# 0                                   596
# 1                                   595
# 2                                   595
# 3                                   596
# 4                                   598
#
#    Economically Disadvantaged_NOT_TESTED Economically Disadvantaged_NUM_PROF  \
# 0                                36891.0                                5441
# 1                                37251.0                                4699
# ...

# %% [markdown]
# # Merge Economic Dataset with All Students + Gender + Race + English Language Dataset

# %%
df_math_2022_4 = pd.merge(
    df_math_2022_3,
    df_annual_em_math_2022_econ,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_math_2022_4.head()
# Out:
#    INSTITUTION_ID  ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  \
# 0             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 1             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 2             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 3             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 4             NaN    5000000       CAYUGA County  2021           MATH3
#
#    TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED  ...  \
# 0          4.0           1            25.0           3        75.0  ...
# 1        862.0         139            16.0         723        84.0  ...
# 2          4.0           0             0.0           4       100.0  ...
# 3        862.0         140            16.0         722        84.0  ...
# 4        642.0         107            17.0         535        83.0  ...
#
#   Not Economically Disadvantaged_ENTITY_NAME  \
# 0                         CATTARAUGUS County
# ...

# %% [markdown]
# # Dataframe for Special Education

# %%
df_annual_em_math_2022_dis = df_annual_em_math_2022[column_names].copy()

df_annual_em_math_2022_dis = df_annual_em_math_2022_dis[
    (df_annual_em_math_2022_dis["SUBGROUP_NAME"] == "Students with Disabilities")
]

# %%
# reindex

df_annual_em_math_2022_dis = df_annual_em_math_2022_dis.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_math_2022_dis = df_annual_em_math_2022_dis.reindex(
    columns=sorted(df_annual_em_math_2022_dis.columns, key=lambda x: x[::-1])
)

df_annual_em_math_2022_dis.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_math_2022_dis.columns
]

df_annual_em_math_2022_dis = pd.DataFrame(df_annual_em_math_2022_dis.to_records())

# %%
df_annual_em_math_2022_dis.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME Students with Disabilities_ENTITY_NAME  \
# 0          1  2021           MATH3                     NYC Public Schools
# 1          1  2021           MATH4                     NYC Public Schools
# 2          1  2021           MATH5                     NYC Public Schools
# 3          1  2021           MATH6                     NYC Public Schools
# 4          1  2021           MATH7                     NYC Public Schools
#
#   Students with Disabilities_MEAN_SCORE  \
# 0                                   588
# 1                                   586
# 2                                   585
# 3                                   586
# 4                                   583
#
#    Students with Disabilities_NOT_TESTED Students with Disabilities_NUM_PROF  \
# 0                                  16821                                1007
# 1                                  16478                                 729
# ...

# %% [markdown]
# # Merge Special Education Dataset with All Students + Gender + Race + English Language + Econ Dataset

# %%
df_math_2022_5 = pd.merge(
    df_math_2022_4,
    df_annual_em_math_2022_dis,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_math_2022_5.head()
# Out:
#    INSTITUTION_ID  ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  \
# 0             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 1             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 2             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 3             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 4             NaN    5000000       CAYUGA County  2021           MATH3
#
#    TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED  ...  \
# 0          4.0           1            25.0           3        75.0  ...
# 1        862.0         139            16.0         723        84.0  ...
# 2          4.0           0             0.0           4       100.0  ...
# 3        862.0         140            16.0         722        84.0  ...
# 4        642.0         107            17.0         535        83.0  ...
#
#   Students with Disabilities_ENTITY_NAME  \
# 0                     CATTARAUGUS County
# ...

# %% [markdown]
# # Clean final ELA dataset

# %%
# show all columns in dataframe

# Drop Entity Name columns

df_math_2022_5 = df_math_2022_5.drop(
    columns=['Female_ENTITY_NAME', 
    'Male_ENTITY_NAME',
    'American Indian or Alaska Native_ENTITY_NAME',
    'Black or African American_ENTITY_NAME',
    'Hispanic or Latino_ENTITY_NAME',
    'Asian or Native Hawaiian/Other Pacific Islander_ENTITY_NAME',
    'White_ENTITY_NAME',
    'Multiracial_ENTITY_NAME',
    'Non-English Language Learner_ENTITY_NAME',
    'English Language Learner_ENTITY_NAME',
    'Economically Disadvantaged_ENTITY_NAME',
    'Not Economically Disadvantaged_ENTITY_NAME',
    'Students with Disabilities_ENTITY_NAME']
)

# %%
df_math_2022_5.head()
# Out:
#    INSTITUTION_ID  ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  \
# 0             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 1             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 2             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 3             NaN    4000000  CATTARAUGUS County  2021           MATH3
# 4             NaN    5000000       CAYUGA County  2021           MATH3
#
#    TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED  ...  \
# 0          4.0           1            25.0           3        75.0  ...
# 1        862.0         139            16.0         723        84.0  ...
# 2          4.0           0             0.0           4       100.0  ...
# 3        862.0         140            16.0         722        84.0  ...
# 4        642.0         107            17.0         535        83.0  ...
#
#   Not Economically Disadvantaged_TOTAL_SCALE_SCORES  \
# ...
