# %%
import pandas as pd
import numpy as np

df_annual_em_ela_2022 = pd.read_csv(
    "/Users/kashafali/Documents/Duke/Spring23/UDS/Project/Data/2022/Annual EM ELA.csv"
)

# %%
df_annual_em_ela_2022.columns
# Out:
# Index(['INSTITUTION_ID', 'ENTITY_CD', 'ENTITY_NAME', 'YEAR', 'ASSESSMENT_NAME',
#        'SUBGROUP_NAME', 'TOTAL_COUNT', 'NOT_TESTED', 'PCT_NOT_TESTED',
#        'NUM_TESTED', 'PCT_TESTED', 'LEVEL1_COUNT', 'LEVEL1_%TESTED',
#        'LEVEL2_COUNT', 'LEVEL2_%TESTED', 'LEVEL3_COUNT', 'LEVEL3_%TESTED',
#        'LEVEL4_COUNT', 'LEVEL4_%TESTED', 'NUM_PROF', 'PER_PROF',
#        'TOTAL_SCALE_SCORES', 'MEAN_SCORE'],
#       dtype='object')

# %%
df_annual_em_ela_2022["SUBGROUP_NAME"].unique()
# Out:
# array(['All Students', 'Female', 'Male',
#        'American Indian or Alaska Native', 'Black or African American',
#        'Hispanic or Latino',
#        'Asian or Native Hawaiian/Other Pacific Islander', 'White',
#        'Multiracial', 'General Education Students',
#        'Students with Disabilities', 'Non-English Language Learner',
#        'English Language Learner', 'Economically Disadvantaged',
#        'Not Economically Disadvantaged', 'Migrant', 'Not Migrant',
#        'Homeless', 'Not Homeless', 'In Foster Care', 'Not in Foster Care',
#        'Parent in Armed Forces', 'Parent Not in Armed Forces',
#        'Small Group Total'], dtype=object)

# %% [markdown]
# # Dataframe for All Students

# %%
# only keep columns
column_names = [
    "ENTITY_CD",
    "ENTITY_NAME",
    "YEAR",
    "ASSESSMENT_NAME",
    "SUBGROUP_NAME",
    "TOTAL_COUNT",
    "NOT_TESTED",
    "PCT_NOT_TESTED",
    "NUM_TESTED",
    "PCT_TESTED",
    "NUM_PROF",
    "PER_PROF",
    "TOTAL_SCALE_SCORES",
    "MEAN_SCORE",
]

df_annual_em_ela_2022_total = df_annual_em_ela_2022[column_names]
df_annual_em_ela_2022_total = df_annual_em_ela_2022_total[
    df_annual_em_ela_2022_total["SUBGROUP_NAME"] == "All Students"
]

# %%
df_annual_em_ela_2022_total.head()
# Out:
#        ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME SUBGROUP_NAME  \
# 0   111111111111  All Public Schools  2021            ELA3  All Students
# 23       1000000       ALBANY County  2021            ELA3  All Students
# 46       2000000     ALLEGANY County  2021            ELA3  All Students
# 66       3000000       BROOME County  2021            ELA3  All Students
# 89       4000000  CATTARAUGUS County  2021            ELA3  All Students
#
#     TOTAL_COUNT  NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  \
# 0        192560       99642              52       92918          48    56106
# 23         2999         993              33        2006          67     1208
# 46          420          39               9         381          91      214
# 66         1859         512              28        1347          72      733
# 89          869         132              15         737          85      396
#
#    PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE
# ...

# %%
df_annual_em_ela_2022_merge = df_annual_em_ela_2022_total.drop(
    columns=["SUBGROUP_NAME"]
).copy()

# %% [markdown]
# # Dataframe for Gender

# %%
df_annual_em_ela_2022_gender = df_annual_em_ela_2022.copy()

df_annual_em_ela_2022_gender = df_annual_em_ela_2022_gender[column_names]

df_annual_em_ela_2022_gender = df_annual_em_ela_2022_gender[
    (df_annual_em_ela_2022_gender["SUBGROUP_NAME"] == "Female")
    | (df_annual_em_ela_2022_gender["SUBGROUP_NAME"] == "Male")
]

# %%
# fix index
df_annual_em_ela_2022_gender = df_annual_em_ela_2022_gender.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2022_gender = df_annual_em_ela_2022_gender.reindex(
    columns=sorted(df_annual_em_ela_2022_gender.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2022_gender.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2022_gender.columns
]

df_annual_em_ela_2022_gender = pd.DataFrame(df_annual_em_ela_2022_gender.to_records())

# %%
df_annual_em_ela_2022_gender.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME  Female_ENTITY_NAME Female_MEAN_SCORE  \
# 0          1  2021            ELA3  NYC Public Schools               608
# 1          1  2021            ELA4  NYC Public Schools               611
# 2          1  2021            ELA5  NYC Public Schools               609
# 3          1  2021            ELA6  NYC Public Schools               610
# 4          1  2021            ELA7  NYC Public Schools               609
#
#    Female_NOT_TESTED Female_NUM_PROF  Female_NUM_TESTED  \
# 0            23589.0            6026             8846.0
# 1            23741.0            6237             8881.0
# 2            25432.0            4728             8296.0
# 3            26215.0            4985             6767.0
# 4            26545.0            4320             6799.0
#
#    Female_PCT_NOT_TESTED  Female_PCT_TESTED  ...    Male_ENTITY_NAME  \
# 0                   73.0               27.0  ...  NYC Public Schools
# ...

# %% [markdown]
# # Merge Gender Dataframe with All Students Dataframe

# %%
df_ela_2022_1 = pd.merge(
    df_annual_em_ela_2022_merge,
    df_annual_em_ela_2022_gender,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2022_1.head()
# Out:
#       ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  TOTAL_COUNT  \
# 0  111111111111  All Public Schools  2021            ELA3       192560
# 1       1000000       ALBANY County  2021            ELA3         2999
# 2       2000000     ALLEGANY County  2021            ELA3          420
# 3       3000000       BROOME County  2021            ELA3         1859
# 4       4000000  CATTARAUGUS County  2021            ELA3          869
#
#    NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  ...  \
# 0       99642              52       92918          48    56106  ...
# 1         993              33        2006          67     1208  ...
# 2          39               9         381          91      214  ...
# 3         512              28        1347          72      733  ...
# 4         132              15         737          85      396  ...
#
#      Male_ENTITY_NAME Male_MEAN_SCORE Male_NOT_TESTED Male_NUM_PROF  \
# ...

# %% [markdown]
# # Dataframe for Race

# %%
df_annual_em_ela_2022_race = df_annual_em_ela_2022[column_names].copy()

df_annual_em_ela_2022_race = df_annual_em_ela_2022_race[
    (df_annual_em_ela_2022_race["SUBGROUP_NAME"] == "American Indian or Alaska Native")
    | (df_annual_em_ela_2022_race["SUBGROUP_NAME"] == "Black or African American")
    | (df_annual_em_ela_2022_race["SUBGROUP_NAME"] == "Hispanic or Latino")
    | (
        df_annual_em_ela_2022_race["SUBGROUP_NAME"]
        == "Asian or Native Hawaiian/Other Pacific Islander"
    )
    | (df_annual_em_ela_2022_race["SUBGROUP_NAME"] == "White")
    | (df_annual_em_ela_2022_race["SUBGROUP_NAME"] == "Multiracial")
]

# %%
# reindex

df_annual_em_ela_2022_race = df_annual_em_ela_2022_race.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2022_race = df_annual_em_ela_2022_race.reindex(
    columns=sorted(df_annual_em_ela_2022_race.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2022_race.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2022_race.columns
]

df_annual_em_ela_2022_race = pd.DataFrame(df_annual_em_ela_2022_race.to_records())

# %%
df_annual_em_ela_2022_race.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME  \
# 0          1  2021            ELA3
# 1          1  2021            ELA4
# 2          1  2021            ELA5
# 3          1  2021            ELA6
# 4          1  2021            ELA7
#
#   American Indian or Alaska Native_ENTITY_NAME  \
# 0                           NYC Public Schools
# 1                           NYC Public Schools
# 2                           NYC Public Schools
# 3                           NYC Public Schools
# 4                           NYC Public Schools
#
#   American Indian or Alaska Native_MEAN_SCORE  \
# 0                                         604
# 1                                         603
# 2                                         603
# 3                                         607
# 4                                         603
#
#    American Indian or Alaska Native_NOT_TESTED  \
# 0                                        687.0
# 1                                        606.0
# ...

# %% [markdown]
# # Merge Race Dataset with All Students + Gender Dataset

# %%
df_ela_2022_2 = pd.merge(
    df_ela_2022_1,
    df_annual_em_ela_2022_race,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2022_2.head()
# Out:
#       ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  TOTAL_COUNT  \
# 0  111111111111  All Public Schools  2021            ELA3       192560
# 1       1000000       ALBANY County  2021            ELA3         2999
# 2       2000000     ALLEGANY County  2021            ELA3          420
# 3       3000000       BROOME County  2021            ELA3         1859
# 4       4000000  CATTARAUGUS County  2021            ELA3          869
#
#    NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  ...  \
# 0       99642              52       92918          48    56106  ...
# 1         993              33        2006          67     1208  ...
# 2          39               9         381          91      214  ...
# 3         512              28        1347          72      733  ...
# 4         132              15         737          85      396  ...
#
#     White_ENTITY_NAME White_MEAN_SCORE White_NOT_TESTED White_NUM_PROF  \
# ...

# %% [markdown]
# # English Language Learners Dataframe

# %%
df_annual_em_ela_2022_eng = df_annual_em_ela_2022[column_names].copy()


df_annual_em_ela_2022_eng = df_annual_em_ela_2022_eng[
    (df_annual_em_ela_2022_eng["SUBGROUP_NAME"] == "Non-English Language Learner")
    | (df_annual_em_ela_2022_eng["SUBGROUP_NAME"] == "English Language Learner")
]

# %%
# reindex

df_annual_em_ela_2022_eng = df_annual_em_ela_2022_eng.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2022_eng = df_annual_em_ela_2022_eng.reindex(
    columns=sorted(df_annual_em_ela_2022_eng.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2022_eng.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2022_eng.columns
]

df_annual_em_ela_2022_eng = pd.DataFrame(df_annual_em_ela_2022_eng.to_records())

# %%
df_annual_em_ela_2022_eng.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME English Language Learner_ENTITY_NAME  \
# 0          1  2021            ELA3                   NYC Public Schools
# 1          1  2021            ELA4                   NYC Public Schools
# 2          1  2021            ELA5                   NYC Public Schools
# 3          1  2021            ELA6                   NYC Public Schools
# 4          1  2021            ELA7                   NYC Public Schools
#
#   English Language Learner_MEAN_SCORE  English Language Learner_NOT_TESTED  \
# 0                                 590                               9988.0
# 1                                 589                               9234.0
# 2                                 583                               8553.0
# 3                                 581                               8449.0
# 4                                 578                               7664.0
#
#   English Language Learner_NUM_PROF  English Language Learner_NUM_TESTED  \
# ...

# %% [markdown]
# # Merge English Language Learners Dataset with All Students + Gender + Race Dataset

# %%
df_ela_2022_3 = pd.merge(
    df_ela_2022_2,
    df_annual_em_ela_2022_eng,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2022_3.head()
# Out:
#       ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  TOTAL_COUNT  \
# 0  111111111111  All Public Schools  2021            ELA3       192560
# 1       1000000       ALBANY County  2021            ELA3         2999
# 2       2000000     ALLEGANY County  2021            ELA3          420
# 3       3000000       BROOME County  2021            ELA3         1859
# 4       4000000  CATTARAUGUS County  2021            ELA3          869
#
#    NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  ...  \
# 0       99642              52       92918          48    56106  ...
# 1         993              33        2006          67     1208  ...
# 2          39               9         381          91      214  ...
# 3         512              28        1347          72      733  ...
# 4         132              15         737          85      396  ...
#
#   Non-English Language Learner_ENTITY_NAME  \
# 0                       All Public Schools
# ...

# %% [markdown]
# # Dataframe for Economic Condition

# %%
df_annual_em_ela_2022_econ = df_annual_em_ela_2022[column_names].copy()

df_annual_em_ela_2022_econ = df_annual_em_ela_2022_econ[
    (df_annual_em_ela_2022_econ["SUBGROUP_NAME"] == "Economically Disadvantaged")
    | (df_annual_em_ela_2022_econ["SUBGROUP_NAME"] == "Not Economically Disadvantaged")
]

# %%
# reindex

df_annual_em_ela_2022_econ = df_annual_em_ela_2022_econ.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2022_econ = df_annual_em_ela_2022_econ.reindex(
    columns=sorted(df_annual_em_ela_2022_econ.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2022_econ.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2022_econ.columns
]

df_annual_em_ela_2022_econ = pd.DataFrame(df_annual_em_ela_2022_econ.to_records())

# %%
df_annual_em_ela_2022_econ.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME Economically Disadvantaged_ENTITY_NAME  \
# 0          1  2021            ELA3                     NYC Public Schools
# 1          1  2021            ELA4                     NYC Public Schools
# 2          1  2021            ELA5                     NYC Public Schools
# 3          1  2021            ELA6                     NYC Public Schools
# 4          1  2021            ELA7                     NYC Public Schools
#
#   Economically Disadvantaged_MEAN_SCORE  \
# 0                                   600
# 1                                   604
# 2                                   602
# 3                                   603
# 4                                   603
#
#    Economically Disadvantaged_NOT_TESTED Economically Disadvantaged_NUM_PROF  \
# 0                                37065.0                                5858
# 1                                37494.0                                6447
# ...

# %% [markdown]
# # Merge Economic Dataset with All Students + Gender + Race + English Language Dataset

# %%
df_ela_2022_4 = pd.merge(
    df_ela_2022_3,
    df_annual_em_ela_2022_econ,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2022_4.head()
# Out:
#       ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  TOTAL_COUNT  \
# 0  111111111111  All Public Schools  2021            ELA3       192560
# 1       1000000       ALBANY County  2021            ELA3         2999
# 2       2000000     ALLEGANY County  2021            ELA3          420
# 3       3000000       BROOME County  2021            ELA3         1859
# 4       4000000  CATTARAUGUS County  2021            ELA3          869
#
#    NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  ...  \
# 0       99642              52       92918          48    56106  ...
# 1         993              33        2006          67     1208  ...
# 2          39               9         381          91      214  ...
# 3         512              28        1347          72      733  ...
# 4         132              15         737          85      396  ...
#
#   Not Economically Disadvantaged_ENTITY_NAME  \
# 0                         All Public Schools
# ...

# %% [markdown]
# # Dataframe for Special Education

# %%
df_annual_em_ela_2022_dis = df_annual_em_ela_2022[column_names].copy()

df_annual_em_ela_2022_dis = df_annual_em_ela_2022_dis[
    (df_annual_em_ela_2022_dis["SUBGROUP_NAME"] == "Students with Disabilities")
]

# %%
# reindex

df_annual_em_ela_2022_dis = df_annual_em_ela_2022_dis.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2022_dis = df_annual_em_ela_2022_dis.reindex(
    columns=sorted(df_annual_em_ela_2022_dis.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2022_dis.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2022_dis.columns
]

df_annual_em_ela_2022_dis = pd.DataFrame(df_annual_em_ela_2022_dis.to_records())

# %%
df_annual_em_ela_2022_dis.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME Students with Disabilities_ENTITY_NAME  \
# 0          1  2021            ELA3                     NYC Public Schools
# 1          1  2021            ELA4                     NYC Public Schools
# 2          1  2021            ELA5                     NYC Public Schools
# 3          1  2021            ELA6                     NYC Public Schools
# 4          1  2021            ELA7                     NYC Public Schools
#
#   Students with Disabilities_MEAN_SCORE  \
# 0                                   591
# 1                                   592
# 2                                   588
# 3                                   589
# 4                                   587
#
#    Students with Disabilities_NOT_TESTED Students with Disabilities_NUM_PROF  \
# 0                                  16878                                1011
# 1                                  16562                                1048
# ...

# %% [markdown]
# # Merge Special Education Dataset with All Students + Gender + Race + English Language + Econ Dataset

# %%
df_ela_2022_5 = pd.merge(
    df_ela_2022_4,
    df_annual_em_ela_2022_dis,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2022_5.head()
# Out:
#       ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  TOTAL_COUNT  \
# 0  111111111111  All Public Schools  2021            ELA3       192560
# 1       1000000       ALBANY County  2021            ELA3         2999
# 2       2000000     ALLEGANY County  2021            ELA3          420
# 3       3000000       BROOME County  2021            ELA3         1859
# 4       4000000  CATTARAUGUS County  2021            ELA3          869
#
#    NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  ...  \
# 0       99642              52       92918          48    56106  ...
# 1         993              33        2006          67     1208  ...
# 2          39               9         381          91      214  ...
# 3         512              28        1347          72      733  ...
# 4         132              15         737          85      396  ...
#
#   Students with Disabilities_ENTITY_NAME  \
# 0                     All Public Schools
# 1                          ALBANY County
# ...

# %% [markdown]
# # Clean final ELA dataset

# %%
# show all columns in dataframe

# Drop Entity Name columns

df_ela_2022_5 = df_ela_2022_5.drop(
    columns=['Female_ENTITY_NAME', 
    'Male_ENTITY_NAME',
    'American Indian or Alaska Native_ENTITY_NAME',
    'Black or African American_ENTITY_NAME',
    'Hispanic or Latino_ENTITY_NAME',
    'Asian or Native Hawaiian/Other Pacific Islander_ENTITY_NAME',
    'White_ENTITY_NAME',
    'Multiracial_ENTITY_NAME',
    'Non-English Language Learner_ENTITY_NAME',
    'English Language Learner_ENTITY_NAME',
    'Economically Disadvantaged_ENTITY_NAME',
    'Not Economically Disadvantaged_ENTITY_NAME',
    'Students with Disabilities_ENTITY_NAME']
)

# %%
df_ela_2022_5.head()
# Out:
#       ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  TOTAL_COUNT  \
# 0  111111111111  All Public Schools  2021            ELA3       192560
# 1       1000000       ALBANY County  2021            ELA3         2999
# 2       2000000     ALLEGANY County  2021            ELA3          420
# 3       3000000       BROOME County  2021            ELA3         1859
# 4       4000000  CATTARAUGUS County  2021            ELA3          869
#
#    NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  ...  \
# 0       99642              52       92918          48    56106  ...
# 1         993              33        2006          67     1208  ...
# 2          39               9         381          91      214  ...
# 3         512              28        1347          72      733  ...
# 4         132              15         737          85      396  ...
#
#   Not Economically Disadvantaged_TOTAL_SCALE_SCORES  \
# 0                                          29473243
# ...

# %%
# save to csv

df_ela_2022_5.to_csv('df_ela_2022.csv', index=False)
