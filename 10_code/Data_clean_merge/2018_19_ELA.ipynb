# %%
import pandas as pd
import numpy as np

df_annual_em_ela_2019 = pd.read_csv(
    "/Users/kashafali/Documents/Duke/Spring23/UDS/Project/Data/2019/Annual EM ELA.csv"
)

# %%
df_annual_em_ela_2019.columns
# Out:
# Index(['ENTITY_CD', 'ENTITY_NAME', 'YEAR', 'ASSESSMENT_NAME', 'SUBGROUP_NAME',
#        'NUM_TESTED', 'NOT_TESTED', 'LEVEL1_COUNT', 'LEVEL1_%TESTED',
#        'LEVEL2_COUNT', 'LEVEL2_%TESTED', 'LEVEL3_COUNT', 'LEVEL3_%TESTED',
#        'LEVEL4_COUNT', 'LEVEL4_%TESTED', 'NUM_PROF', 'PER_PROF',
#        'TOTAL_SCALE_SCORES', 'MEAN_SCORE'],
#       dtype='object')

# %%
df_annual_em_ela_2019["SUBGROUP_NAME"].unique()
# Out:
# array(['Hispanic or Latino', 'Homeless', 'Male',
#        'Non-English Language Learners', 'Not Economically Disadvantaged',
#        'American Indian or Alaska Native',
#        'Asian or Native Hawaiian/Other Pacific Islander',
#        'Black or African American', 'Economically Disadvantaged',
#        'English Language Learners', 'Female', 'General Education',
#        'Multiracial', 'All Students', 'In Foster Care', 'Migrant',
#        'Not Homeless', 'Not in Foster Care', 'Not Migrant',
#        'Parent in Armed Forces', 'Parent Not in Armed Forces',
#        'Students with Disabilities', 'White', 'Small Group Total'],
#       dtype=object)

# %%
# rename Non-English Language Learners to Non-English Language Learner
df_annual_em_ela_2019["SUBGROUP_NAME"] = df_annual_em_ela_2019["SUBGROUP_NAME"].replace("Non-English Language Learners", "Non-English Language Learner")
# rename English Language Learners to English Language Learner
df_annual_em_ela_2019["SUBGROUP_NAME"] = df_annual_em_ela_2019["SUBGROUP_NAME"].replace("English Language Learners", "English Language Learner")

# %% [markdown]
# # Dataframe for All Students

# %%
# only keep columns
column_names = [
    "ENTITY_CD",
    "ENTITY_NAME",
    "YEAR",
    "ASSESSMENT_NAME",
    "SUBGROUP_NAME",
    "NOT_TESTED",
    "NUM_TESTED",
    "NUM_PROF",
    "PER_PROF",
    "TOTAL_SCALE_SCORES",
    "MEAN_SCORE",
]

df_annual_em_ela_2019_total = df_annual_em_ela_2019[column_names]
df_annual_em_ela_2019_total = df_annual_em_ela_2019_total[
    df_annual_em_ela_2019_total["SUBGROUP_NAME"] == "All Students"
]

# %%
df_annual_em_ela_2019_total.head()
# Out:
#     ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME SUBGROUP_NAME  \
# 41          1  NYC Public Schools  2018            ELA5  All Students
# 42          1  NYC Public Schools  2018          ELA3_8  All Students
# 43          1  NYC Public Schools  2018            ELA3  All Students
# 44          1  NYC Public Schools  2018            ELA7  All Students
# 45          1  NYC Public Schools  2018            ELA8  All Students
#
#     NOT_TESTED  NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE
# 41        8982       68439    25990       38           41110322        601
# 42       51959      396804   185099       47                 00         00
# 43       10410       67237    34036       51           40361558        600
# 44        7157       65250    27812       43           39254856        602
# 45        8457       63183    32042       51           38019693        602

# %%
df_annual_em_ela_2019_merge = df_annual_em_ela_2019_total.drop(
    columns=["SUBGROUP_NAME"]
).copy()

# %% [markdown]
# # Dataframe for Gender

# %%
df_annual_em_ela_2019_gender = df_annual_em_ela_2019.copy()

df_annual_em_ela_2019_gender = df_annual_em_ela_2019_gender[column_names]

df_annual_em_ela_2019_gender = df_annual_em_ela_2019_gender[
    (df_annual_em_ela_2019_gender["SUBGROUP_NAME"] == "Female")
    | (df_annual_em_ela_2019_gender["SUBGROUP_NAME"] == "Male")
]

# %%
# fix index
df_annual_em_ela_2019_gender = df_annual_em_ela_2019_gender.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2019_gender = df_annual_em_ela_2019_gender.reindex(
    columns=sorted(df_annual_em_ela_2019_gender.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2019_gender.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2019_gender.columns
]

df_annual_em_ela_2019_gender = pd.DataFrame(df_annual_em_ela_2019_gender.to_records())

# %%
df_annual_em_ela_2019_gender.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME  Female_ENTITY_NAME Female_MEAN_SCORE  \
# 0          1  2018            ELA3  NYC Public Schools               603
# 1          1  2018            ELA4  NYC Public Schools               604
# 2          1  2018            ELA5  NYC Public Schools               604
# 3          1  2018            ELA6  NYC Public Schools               604
# 4          1  2018            ELA7  NYC Public Schools               605
#
#    Female_NOT_TESTED Female_NUM_PROF  Female_NUM_TESTED Female_PER_PROF  \
# 0             4030.0           18392            32870.0              56
# 1             3822.0           18016            33094.0              54
# 2             3532.0           14523            33688.0              43
# 3             3044.0           18035            31926.0              56
# 4             2877.0           15652            31599.0              50
#
#   Female_TOTAL_SCALE_SCORES    Male_ENTITY_NAME Male_MEAN_SCORE  \
# 0                  19821112  NYC Public Schools             598
# 1                  19982478  NYC Public Schools             598
# 2                  20340275  NYC Public Schools             598
# 3                  19292313  NYC Public Schools             597
# 4                  19126216  NYC Public Schools             598
#
#    Male_NOT_TESTED Male_NUM_PROF  Male_NUM_TESTED Male_PER_PROF  \
# 0           6380.0         15644          34367.0            46
# 1           5635.0         15340          34493.0            44
# 2           5450.0         11467          34751.0            33
# 3           4452.0         13828          33182.0            42
# 4           4280.0         12160          33651.0            36
#
#   Male_TOTAL_SCALE_SCORES
# 0                20540446
# 1                20643286
# 2                20770047
# 3                19797315
# 4                20128640

# %% [markdown]
# # Merge Gender Dataframe with All Students Dataframe

# %%
df_ela_2019_1 = pd.merge(
    df_annual_em_ela_2019_merge,
    df_annual_em_ela_2019_gender,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2019_1.head()
# Out:
#    ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  NOT_TESTED  \
# 0          1  NYC Public Schools  2018            ELA5        8982
# 1          1  NYC Public Schools  2018          ELA3_8       51959
# 2          1  NYC Public Schools  2018            ELA3       10410
# 3          1  NYC Public Schools  2018            ELA7        7157
# 4          1  NYC Public Schools  2018            ELA8        8457
#
#    NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0       68439    25990       38           41110322        601  ...
# 1      396804   185099       47                 00         00  ...
# 2       67237    34036       51           40361558        600  ...
# 3       65250    27812       43           39254856        602  ...
# 4       63183    32042       51           38019693        602  ...
#
#   Female_NUM_TESTED Female_PER_PROF  Female_TOTAL_SCALE_SCORES  \
# 0           33688.0              43                   20340275
# 1               NaN             NaN                        NaN
# 2           32870.0              56                   19821112
# 3           31599.0              50                   19126216
# 4           30665.0              58                   18565377
#
#      Male_ENTITY_NAME  Male_MEAN_SCORE Male_NOT_TESTED Male_NUM_PROF  \
# 0  NYC Public Schools              598          5450.0         11467
# 1                 NaN              NaN             NaN           NaN
# 2  NYC Public Schools              598          6380.0         15644
# 3  NYC Public Schools              598          4280.0         12160
# 4  NYC Public Schools              598          4815.0         14291
#
#   Male_NUM_TESTED Male_PER_PROF  Male_TOTAL_SCALE_SCORES
# 0         34751.0            33                 20770047
# 1             NaN           NaN                      NaN
# 2         34367.0            46                 20540446
# 3         33651.0            36                 20128640
# 4         32518.0            44                 19454316
#
# [5 rows x 24 columns]

# %% [markdown]
# # Dataframe for Race

# %%
df_annual_em_ela_2019_race = df_annual_em_ela_2019[column_names].copy()

df_annual_em_ela_2019_race = df_annual_em_ela_2019_race[
    (df_annual_em_ela_2019_race["SUBGROUP_NAME"] == "American Indian or Alaska Native")
    | (df_annual_em_ela_2019_race["SUBGROUP_NAME"] == "Black or African American")
    | (df_annual_em_ela_2019_race["SUBGROUP_NAME"] == "Hispanic or Latino")
    | (
        df_annual_em_ela_2019_race["SUBGROUP_NAME"]
        == "Asian or Native Hawaiian/Other Pacific Islander"
    )
    | (df_annual_em_ela_2019_race["SUBGROUP_NAME"] == "White")
    | (df_annual_em_ela_2019_race["SUBGROUP_NAME"] == "Multiracial")
]

# %%
# reindex

df_annual_em_ela_2019_race = df_annual_em_ela_2019_race.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2019_race = df_annual_em_ela_2019_race.reindex(
    columns=sorted(df_annual_em_ela_2019_race.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2019_race.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2019_race.columns
]

df_annual_em_ela_2019_race = pd.DataFrame(df_annual_em_ela_2019_race.to_records())

# %%
df_annual_em_ela_2019_race.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME  \
# 0          1  2018            ELA3
# 1          1  2018            ELA4
# 2          1  2018            ELA5
# 3          1  2018            ELA6
# 4          1  2018            ELA7
#
#   American Indian or Alaska Native_ENTITY_NAME  \
# 0                           NYC Public Schools
# 1                           NYC Public Schools
# 2                           NYC Public Schools
# 3                           NYC Public Schools
# 4                           NYC Public Schools
#
#   American Indian or Alaska Native_MEAN_SCORE  \
# 0                                         599
# 1                                         599
# 2                                         599
# 3                                         598
# 4                                         599
#
#    American Indian or Alaska Native_NOT_TESTED  \
# 0                                         96.0
# 1                                         83.0
# 2                                         91.0
# 3                                         95.0
# 4                                         76.0
#
#   American Indian or Alaska Native_NUM_PROF  \
# 0                                       348
# 1                                       326
# 2                                       256
# 3                                       322
# 4                                       289
#
#    American Indian or Alaska Native_NUM_TESTED  \
# 0                                        756.0
# 1                                        726.0
# 2                                        762.0
# 3                                        696.0
# 4                                        738.0
#
#   American Indian or Alaska Native_PER_PROF  \
# 0                                        46
# 1                                        45
# 2                                        34
# 3                                        46
# 4                                        39
#
#   American Indian or Alaska Native_TOTAL_SCALE_SCORES  ...  \
# 0                                             452614   ...
# 1                                             435113   ...
# 2                                             456387   ...
# 3                                             416506   ...
# 4                                             442109   ...
#
#   Multiracial_NUM_TESTED Multiracial_PER_PROF  Multiracial_TOTAL_SCALE_SCORES  \
# 0                  937.0                   72                          572429
# 1                  817.0                   76                          501907
# 2                  807.0                   63                          494431
# 3                  641.0                   76                          392825
# 4                  625.0                   71                          383921
#
#     White_ENTITY_NAME  White_MEAN_SCORE White_NOT_TESTED White_NUM_PROF  \
# 0  NYC Public Schools               609           3433.0           7869
# 1  NYC Public Schools               611           3286.0           7638
# 2  NYC Public Schools               610           3189.0           6383
# 3  NYC Public Schools               610           2601.0           7357
# 4  NYC Public Schools               611           2426.0           6680
#
#   White_NUM_TESTED White_PER_PROF  White_TOTAL_SCALE_SCORES
# 0          11416.0             69                   6950213
# 1          11000.0             69                   6720403
# 2          11063.0             58                   6745329
# 3          10467.0             70                   6386851
# 4          10365.0             64                   6332714
#
# [5 rows x 45 columns]

# %% [markdown]
# # Merge Race Dataset with All Students + Gender Dataset

# %%
df_ela_2019_2 = pd.merge(
    df_ela_2019_1,
    df_annual_em_ela_2019_race,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2019_2.head()
# Out:
#    ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  NOT_TESTED  \
# 0          1  NYC Public Schools  2018            ELA5        8982
# 1          1  NYC Public Schools  2018          ELA3_8       51959
# 2          1  NYC Public Schools  2018            ELA3       10410
# 3          1  NYC Public Schools  2018            ELA7        7157
# 4          1  NYC Public Schools  2018            ELA8        8457
#
#    NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0       68439    25990       38           41110322        601  ...
# 1      396804   185099       47                 00         00  ...
# 2       67237    34036       51           40361558        600  ...
# 3       65250    27812       43           39254856        602  ...
# 4       63183    32042       51           38019693        602  ...
#
#   Multiracial_NUM_TESTED Multiracial_PER_PROF  Multiracial_TOTAL_SCALE_SCORES  \
# 0                  807.0                   63                          494431
# 1                    NaN                  NaN                             NaN
# 2                  937.0                   72                          572429
# 3                  625.0                   71                          383921
# 4                  522.0                   73                          319625
#
#     White_ENTITY_NAME  White_MEAN_SCORE White_NOT_TESTED White_NUM_PROF  \
# 0  NYC Public Schools               610           3189.0           6383
# 1                 NaN               NaN              NaN            NaN
# 2  NYC Public Schools               609           3433.0           7869
# 3  NYC Public Schools               611           2426.0           6680
# 4  NYC Public Schools               609           2800.0           6707
#
#   White_NUM_TESTED White_PER_PROF  White_TOTAL_SCALE_SCORES
# 0          11063.0             58                   6745329
# 1              NaN            NaN                       NaN
# 2          11416.0             69                   6950213
# 3          10365.0             64                   6332714
# 4           9850.0             68                   6002917
#
# [5 rows x 66 columns]

# %% [markdown]
# # English Language Learners Dataframe

# %%
df_annual_em_ela_2019_eng = df_annual_em_ela_2019[column_names].copy()


df_annual_em_ela_2019_eng = df_annual_em_ela_2019_eng[
    (df_annual_em_ela_2019_eng["SUBGROUP_NAME"] == "Non-English Language Learner")
    | (df_annual_em_ela_2019_eng["SUBGROUP_NAME"] == "English Language Learner")
]

# %%
# reindex

df_annual_em_ela_2019_eng = df_annual_em_ela_2019_eng.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2019_eng = df_annual_em_ela_2019_eng.reindex(
    columns=sorted(df_annual_em_ela_2019_eng.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2019_eng.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2019_eng.columns
]

df_annual_em_ela_2019_eng = pd.DataFrame(df_annual_em_ela_2019_eng.to_records())

# %%
df_annual_em_ela_2019_eng.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME English Language Learner_ENTITY_NAME  \
# 0          1  2018            ELA3                   NYC Public Schools
# 1          1  2018            ELA4                   NYC Public Schools
# 2          1  2018            ELA5                   NYC Public Schools
# 3          1  2018            ELA6                   NYC Public Schools
# 4          1  2018            ELA7                   NYC Public Schools
#
#   English Language Learner_MEAN_SCORE  English Language Learner_NOT_TESTED  \
# 0                                 586                               2604.0
# 1                                 584                               2391.0
# 2                                 580                               2120.0
# 3                                 579                               2002.0
# 4                                 579                               1953.0
#
#   English Language Learner_NUM_PROF  English Language Learner_NUM_TESTED  \
# 0                              2412                              11825.0
# 1                              1286                               9842.0
# 2                               262                               8330.0
# 3                               510                               7709.0
# 4                               203                               7019.0
#
#   English Language Learner_PER_PROF  \
# 0                                20
# 1                                13
# 2                                03
# 3                                07
# 4                                03
#
#   English Language Learner_TOTAL_SCALE_SCORES  \
# 0                                     6932450
# 1                                     5744189
# 2                                     4828302
# 3                                     4462824
# 4                                     4061768
#
#   Non-English Language Learner_ENTITY_NAME  \
# 0                       NYC Public Schools
# 1                       NYC Public Schools
# 2                       NYC Public Schools
# 3                       NYC Public Schools
# 4                       NYC Public Schools
#
#   Non-English Language Learner_MEAN_SCORE  \
# 0                                     603
# 1                                     604
# 2                                     604
# 3                                     603
# 4                                     604
#
#    Non-English Language Learner_NOT_TESTED  \
# 0                                   7806.0
# 1                                   7066.0
# 2                                   6862.0
# 3                                   5494.0
# 4                                   5204.0
#
#   Non-English Language Learner_NUM_PROF  \
# 0                                 31624
# 1                                 32070
# 2                                 25728
# 3                                 31353
# 4                                 27609
#
#    Non-English Language Learner_NUM_TESTED  \
# 0                                  55412.0
# 1                                  57745.0
# 2                                  60109.0
# 3                                  57399.0
# 4                                  58231.0
#
#   Non-English Language Learner_PER_PROF  \
# 0                                    57
# 1                                    56
# 2                                    43
# 3                                    55
# 4                                    47
#
#   Non-English Language Learner_TOTAL_SCALE_SCORES
# 0                                        33429108
# 1                                        34881575
# 2                                        36282020
# 3                                        34626804
# 4                                        35193088

# %% [markdown]
# # Merge English Language Learners Dataset with All Students + Gender + Race Dataset

# %%
df_ela_2019_3 = pd.merge(
    df_ela_2019_2,
    df_annual_em_ela_2019_eng,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2019_3.head()
# Out:
#    ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  NOT_TESTED  \
# 0          1  NYC Public Schools  2018            ELA5        8982
# 1          1  NYC Public Schools  2018          ELA3_8       51959
# 2          1  NYC Public Schools  2018            ELA3       10410
# 3          1  NYC Public Schools  2018            ELA7        7157
# 4          1  NYC Public Schools  2018            ELA8        8457
#
#    NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0       68439    25990       38           41110322        601  ...
# 1      396804   185099       47                 00         00  ...
# 2       67237    34036       51           40361558        600  ...
# 3       65250    27812       43           39254856        602  ...
# 4       63183    32042       51           38019693        602  ...
#
#   English Language Learner_NUM_TESTED English Language Learner_PER_PROF  \
# 0                              8330.0                                03
# 1                                 NaN                               NaN
# 2                             11825.0                                20
# 3                              7019.0                                03
# 4                              6704.0                                05
#
#    English Language Learner_TOTAL_SCALE_SCORES  \
# 0                                      4828302
# 1                                          NaN
# 2                                      6932450
# 3                                      4061768
# 4                                      3872714
#
#   Non-English Language Learner_ENTITY_NAME  \
# 0                       NYC Public Schools
# 1                                      NaN
# 2                       NYC Public Schools
# 3                       NYC Public Schools
# 4                       NYC Public Schools
#
#    Non-English Language Learner_MEAN_SCORE  \
# 0                                      604
# 1                                      NaN
# 2                                      603
# 3                                      604
# 4                                      605
#
#   Non-English Language Learner_NOT_TESTED  \
# 0                                  6862.0
# 1                                     NaN
# 2                                  7806.0
# 3                                  5204.0
# 4                                  6335.0
#
#   Non-English Language Learner_NUM_PROF  \
# 0                                 25728
# 1                                   NaN
# 2                                 31624
# 3                                 27609
# 4                                 31727
#
#   Non-English Language Learner_NUM_TESTED  \
# 0                                 60109.0
# 1                                     NaN
# 2                                 55412.0
# 3                                 58231.0
# 4                                 56479.0
#
#   Non-English Language Learner_PER_PROF  \
# 0                                    43
# 1                                   NaN
# 2                                    57
# 3                                    47
# 4                                    56
#
#    Non-English Language Learner_TOTAL_SCALE_SCORES
# 0                                         36282020
# 1                                              NaN
# 2                                         33429108
# 3                                         35193088
# 4                                         34146979
#
# [5 rows x 80 columns]

# %% [markdown]
# # Dataframe for Economic Condition

# %%
df_annual_em_ela_2019_econ = df_annual_em_ela_2019[column_names].copy()

df_annual_em_ela_2019_econ = df_annual_em_ela_2019_econ[
    (df_annual_em_ela_2019_econ["SUBGROUP_NAME"] == "Economically Disadvantaged")
    | (df_annual_em_ela_2019_econ["SUBGROUP_NAME"] == "Not Economically Disadvantaged")
]

# %%
# reindex

df_annual_em_ela_2019_econ = df_annual_em_ela_2019_econ.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2019_econ = df_annual_em_ela_2019_econ.reindex(
    columns=sorted(df_annual_em_ela_2019_econ.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2019_econ.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2019_econ.columns
]

df_annual_em_ela_2019_econ = pd.DataFrame(df_annual_em_ela_2019_econ.to_records())

# %%
df_annual_em_ela_2019_econ.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME Economically Disadvantaged_ENTITY_NAME  \
# 0          1  2018            ELA3                     NYC Public Schools
# 1          1  2018            ELA4                     NYC Public Schools
# 2          1  2018            ELA5                     NYC Public Schools
# 3          1  2018            ELA6                     NYC Public Schools
# 4          1  2018            ELA7                     NYC Public Schools
#
#   Economically Disadvantaged_MEAN_SCORE  \
# 0                                   597
# 1                                   598
# 2                                   597
# 3                                   597
# 4                                   599
#
#    Economically Disadvantaged_NOT_TESTED Economically Disadvantaged_NUM_PROF  \
# 0                                 5527.0                               21915
# 1                                 4837.0                               21614
# 2                                 4376.0                               15905
# 3                                 3820.0                               21322
# 4                                 3604.0                               17918
#
#    Economically Disadvantaged_NUM_TESTED Economically Disadvantaged_PER_PROF  \
# 0                                50579.0                                  43
# 1                                51193.0                                  42
# 2                                51391.0                                  31
# 3                                50121.0                                  43
# 4                                49572.0                                  36
#
#   Economically Disadvantaged_TOTAL_SCALE_SCORES  \
# 0                                      30182045
# 1                                      30589790
# 2                                      30700660
# 3                                      29936580
# 4                                      29680655
#
#   Not Economically Disadvantaged_ENTITY_NAME  \
# 0                         NYC Public Schools
# 1                         NYC Public Schools
# 2                         NYC Public Schools
# 3                         NYC Public Schools
# 4                         NYC Public Schools
#
#   Not Economically Disadvantaged_MEAN_SCORE  \
# 0                                       611
# 1                                       612
# 2                                       611
# 3                                       611
# 4                                       611
#
#    Not Economically Disadvantaged_NOT_TESTED  \
# 0                                     4883.0
# 1                                     4620.0
# 2                                     4606.0
# 3                                     3676.0
# 4                                     3553.0
#
#   Not Economically Disadvantaged_NUM_PROF  \
# 0                                   12121
# 1                                   11742
# 2                                   10085
# 3                                   10541
# 4                                    9894
#
#    Not Economically Disadvantaged_NUM_TESTED  \
# 0                                    16658.0
# 1                                    16394.0
# 2                                    17048.0
# 3                                    14987.0
# 4                                    15678.0
#
#   Not Economically Disadvantaged_PER_PROF  \
# 0                                      73
# 1                                      72
# 2                                      59
# 3                                      70
# 4                                      63
#
#   Not Economically Disadvantaged_TOTAL_SCALE_SCORES
# 0                                          10179513
# 1                                          10035974
# 2                                          10409662
# 3                                           9153048
# 4                                           9574201

# %% [markdown]
# # Merge Economic Dataset with All Students + Gender + Race + English Language Dataset

# %%
df_ela_2019_4 = pd.merge(
    df_ela_2019_3,
    df_annual_em_ela_2019_econ,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2019_4.head()
# Out:
#    ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  NOT_TESTED  \
# 0          1  NYC Public Schools  2018            ELA5        8982
# 1          1  NYC Public Schools  2018          ELA3_8       51959
# 2          1  NYC Public Schools  2018            ELA3       10410
# 3          1  NYC Public Schools  2018            ELA7        7157
# 4          1  NYC Public Schools  2018            ELA8        8457
#
#    NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0       68439    25990       38           41110322        601  ...
# 1      396804   185099       47                 00         00  ...
# 2       67237    34036       51           40361558        600  ...
# 3       65250    27812       43           39254856        602  ...
# 4       63183    32042       51           38019693        602  ...
#
#   Economically Disadvantaged_NUM_TESTED Economically Disadvantaged_PER_PROF  \
# 0                               51391.0                                  31
# 1                                   NaN                                 NaN
# 2                               50579.0                                  43
# 3                               49572.0                                  36
# 4                               47734.0                                  45
#
#    Economically Disadvantaged_TOTAL_SCALE_SCORES  \
# 0                                       30700660
# 1                                            NaN
# 2                                       30182045
# 3                                       29680655
# 4                                       28601323
#
#   Not Economically Disadvantaged_ENTITY_NAME  \
# 0                         NYC Public Schools
# 1                                        NaN
# 2                         NYC Public Schools
# 3                         NYC Public Schools
# 4                         NYC Public Schools
#
#    Not Economically Disadvantaged_MEAN_SCORE  \
# 0                                        611
# 1                                        NaN
# 2                                        611
# 3                                        611
# 4                                        610
#
#   Not Economically Disadvantaged_NOT_TESTED  \
# 0                                    4606.0
# 1                                       NaN
# 2                                    4883.0
# 3                                    3553.0
# 4                                    4044.0
#
#   Not Economically Disadvantaged_NUM_PROF  \
# 0                                   10085
# 1                                     NaN
# 2                                   12121
# 3                                    9894
# 4                                   10447
#
#   Not Economically Disadvantaged_NUM_TESTED  \
# 0                                   17048.0
# 1                                       NaN
# 2                                   16658.0
# 3                                   15678.0
# 4                                   15449.0
#
#   Not Economically Disadvantaged_PER_PROF  \
# 0                                      59
# 1                                     NaN
# 2                                      73
# 3                                      63
# 4                                      68
#
#    Not Economically Disadvantaged_TOTAL_SCALE_SCORES
# 0                                           10409662
# 1                                                NaN
# 2                                           10179513
# 3                                            9574201
# 4                                            9418370
#
# [5 rows x 94 columns]

# %% [markdown]
# # Dataframe for Special Education

# %%
df_annual_em_ela_2019_dis = df_annual_em_ela_2019[column_names].copy()

df_annual_em_ela_2019_dis = df_annual_em_ela_2019_dis[
    (df_annual_em_ela_2019_dis["SUBGROUP_NAME"] == "Students with Disabilities")
]

# %%
# reindex

df_annual_em_ela_2019_dis = df_annual_em_ela_2019_dis.set_index(
    ["SUBGROUP_NAME", "ENTITY_CD", "YEAR", "ASSESSMENT_NAME"]
).unstack(["SUBGROUP_NAME"])

df_annual_em_ela_2019_dis = df_annual_em_ela_2019_dis.reindex(
    columns=sorted(df_annual_em_ela_2019_dis.columns, key=lambda x: x[::-1])
)

df_annual_em_ela_2019_dis.columns = [
    "{}_{}".format(t, v) for v, t in df_annual_em_ela_2019_dis.columns
]

df_annual_em_ela_2019_dis = pd.DataFrame(df_annual_em_ela_2019_dis.to_records())

# %%
df_annual_em_ela_2019_dis.head()
# Out:
#    ENTITY_CD  YEAR ASSESSMENT_NAME Students with Disabilities_ENTITY_NAME  \
# 0          1  2018            ELA3                     NYC Public Schools
# 1          1  2018            ELA4                     NYC Public Schools
# 2          1  2018            ELA5                     NYC Public Schools
# 3          1  2018            ELA6                     NYC Public Schools
# 4          1  2018            ELA7                     NYC Public Schools
#
#   Students with Disabilities_MEAN_SCORE  \
# 0                                   585
# 1                                   585
# 2                                   585
# 3                                   584
# 4                                   586
#
#    Students with Disabilities_NOT_TESTED Students with Disabilities_NUM_PROF  \
# 0                                   7291                                3034
# 1                                   6656                                2753
# 2                                   6375                                1648
# 3                                   5192                                2262
# 4                                   4963                                1695
#
#    Students with Disabilities_NUM_TESTED Students with Disabilities_PER_PROF  \
# 0                                  14366                                  21
# 1                                  14934                                  18
# 2                                  15138                                  11
# 3                                  14380                                  16
# 4                                  14230                                  12
#
#   Students with Disabilities_TOTAL_SCALE_SCORES
# 0                                       8402968
# 1                                       8737959
# 2                                       8851450
# 3                                       8401167
# 4                                       8343036

# %% [markdown]
# # Merge Special Education Dataset with All Students + Gender + Race + English Language + Econ Dataset

# %%
df_ela_2019_5 = pd.merge(
    df_ela_2019_4,
    df_annual_em_ela_2019_dis,
    on=["ENTITY_CD", "YEAR", "ASSESSMENT_NAME"],
    how="left",
)

df_ela_2019_5.head()
# Out:
#    ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  NOT_TESTED  \
# 0          1  NYC Public Schools  2018            ELA5        8982
# 1          1  NYC Public Schools  2018          ELA3_8       51959
# 2          1  NYC Public Schools  2018            ELA3       10410
# 3          1  NYC Public Schools  2018            ELA7        7157
# 4          1  NYC Public Schools  2018            ELA8        8457
#
#    NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0       68439    25990       38           41110322        601  ...
# 1      396804   185099       47                 00         00  ...
# 2       67237    34036       51           40361558        600  ...
# 3       65250    27812       43           39254856        602  ...
# 4       63183    32042       51           38019693        602  ...
#
#   Not Economically Disadvantaged_NUM_TESTED  \
# 0                                   17048.0
# 1                                       NaN
# 2                                   16658.0
# 3                                   15678.0
# 4                                   15449.0
#
#   Not Economically Disadvantaged_PER_PROF  \
# 0                                      59
# 1                                     NaN
# 2                                      73
# 3                                      63
# 4                                      68
#
#    Not Economically Disadvantaged_TOTAL_SCALE_SCORES  \
# 0                                           10409662
# 1                                                NaN
# 2                                           10179513
# 3                                            9574201
# 4                                            9418370
#
#   Students with Disabilities_ENTITY_NAME  \
# 0                     NYC Public Schools
# 1                                    NaN
# 2                     NYC Public Schools
# 3                     NYC Public Schools
# 4                     NYC Public Schools
#
#    Students with Disabilities_MEAN_SCORE  \
# 0                                    585
# 1                                    NaN
# 2                                    585
# 3                                    586
# 4                                    586
#
#   Students with Disabilities_NOT_TESTED Students with Disabilities_NUM_PROF  \
# 0                                6375.0                                1648
# 1                                   NaN                                 NaN
# 2                                7291.0                                3034
# 3                                4963.0                                1695
# 4                                4995.0                                2187
#
#   Students with Disabilities_NUM_TESTED Students with Disabilities_PER_PROF  \
# 0                               15138.0                                  11
# 1                                   NaN                                 NaN
# 2                               14366.0                                  21
# 3                               14230.0                                  12
# 4                               13185.0                                  17
#
#    Students with Disabilities_TOTAL_SCALE_SCORES
# 0                                        8851450
# 1                                            NaN
# 2                                        8402968
# 3                                        8343036
# 4                                        7731223
#
# [5 rows x 101 columns]

# %% [markdown]
# # Clean final ELA dataset

# %%
# show all columns in dataframe

# Drop Entity Name columns

df_ela_2019_5 = df_ela_2019_5.drop(
    columns=['Female_ENTITY_NAME', 
    'Male_ENTITY_NAME',
    'American Indian or Alaska Native_ENTITY_NAME',
    'Black or African American_ENTITY_NAME',
    'Hispanic or Latino_ENTITY_NAME',
    'Asian or Native Hawaiian/Other Pacific Islander_ENTITY_NAME',
    'White_ENTITY_NAME',
    'Multiracial_ENTITY_NAME',
    'Non-English Language Learner_ENTITY_NAME',
    'English Language Learner_ENTITY_NAME',
    'Economically Disadvantaged_ENTITY_NAME',
    'Not Economically Disadvantaged_ENTITY_NAME',
    'Students with Disabilities_ENTITY_NAME']
)

# %%
df_ela_2019_5.head()
# Out:
#    ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  NOT_TESTED  \
# 0          1  NYC Public Schools  2018            ELA5        8982
# 1          1  NYC Public Schools  2018          ELA3_8       51959
# 2          1  NYC Public Schools  2018            ELA3       10410
# 3          1  NYC Public Schools  2018            ELA7        7157
# 4          1  NYC Public Schools  2018            ELA8        8457
#
#    NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0       68439    25990       38           41110322        601  ...
# 1      396804   185099       47                 00         00  ...
# 2       67237    34036       51           40361558        600  ...
# 3       65250    27812       43           39254856        602  ...
# 4       63183    32042       51           38019693        602  ...
#
#   Not Economically Disadvantaged_NUM_PROF  \
# 0                                   10085
# 1                                     NaN
# 2                                   12121
# 3                                    9894
# 4                                   10447
#
#    Not Economically Disadvantaged_NUM_TESTED  \
# 0                                    17048.0
# 1                                        NaN
# 2                                    16658.0
# 3                                    15678.0
# 4                                    15449.0
#
#   Not Economically Disadvantaged_PER_PROF  \
# 0                                      59
# 1                                     NaN
# 2                                      73
# 3                                      63
# 4                                      68
#
#    Not Economically Disadvantaged_TOTAL_SCALE_SCORES  \
# 0                                           10409662
# 1                                                NaN
# 2                                           10179513
# 3                                            9574201
# 4                                            9418370
#
#   Students with Disabilities_MEAN_SCORE Students with Disabilities_NOT_TESTED  \
# 0                                   585                                6375.0
# 1                                   NaN                                   NaN
# 2                                   585                                7291.0
# 3                                   586                                4963.0
# 4                                   586                                4995.0
#
#   Students with Disabilities_NUM_PROF  Students with Disabilities_NUM_TESTED  \
# 0                                1648                                15138.0
# 1                                 NaN                                    NaN
# 2                                3034                                14366.0
# 3                                1695                                14230.0
# 4                                2187                                13185.0
#
#   Students with Disabilities_PER_PROF  \
# 0                                  11
# 1                                 NaN
# 2                                  21
# 3                                  12
# 4                                  17
#
#    Students with Disabilities_TOTAL_SCALE_SCORES
# 0                                        8851450
# 1                                            NaN
# 2                                        8402968
# 3                                        8343036
# 4                                        7731223
#
# [5 rows x 88 columns]

# %%
# save to csv

df_ela_2019_5.to_csv('df_ela_2019.csv', index=False)
