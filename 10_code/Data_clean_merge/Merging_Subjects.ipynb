# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Subjects 2021-22

# %% [markdown]
# English (2021-22)

# %%
ELA_2021_2022 = pd.read_csv('df_ela_2022.csv')

# add column for ELA for each row
ELA_2021_2022['SUBJECT'] = 'ELA'

ELA_2021_2022["ASSESSMENT_NAME"].unique()
# Out:
# array(['ELA3', 'ELA4', 'ELA5', 'ELA6', 'ELA7', 'ELA8', 'ELA3_8'],
#       dtype=object)

# %%
# year count
ELA_2021_2022["YEAR"].value_counts()
# Out:
# 2022    21525
# 2021    21497
# Name: YEAR, dtype: int64

# %%
# check for missing values
ELA_2021_2022.isnull().sum()
# Out:
# ENTITY_CD                                            0
# ENTITY_NAME                                          0
# YEAR                                                 0
# ASSESSMENT_NAME                                      0
# TOTAL_COUNT                                          0
#                                                  ...
# Students with Disabilities_PCT_TESTED             9409
# Students with Disabilities_PER_PROF              12474
# Students with Disabilities_TOTAL_COUNT            9409
# Students with Disabilities_TOTAL_SCALE_SCORES    12474
# SUBJECT                                              0
# Length: 131, dtype: int64

# %%
ELA_2021_2022[(ELA_2021_2022["YEAR"] == 2021) & (ELA_2021_2022["ENTITY_CD"] == 1)]
# Out:
#        ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  TOTAL_COUNT  \
# 64             1  NYC Public Schools  2021            ELA3        67914
# 3337           1  NYC Public Schools  2021            ELA4        67875
# 6568           1  NYC Public Schools  2021            ELA5        70506
# 9816           1  NYC Public Schools  2021            ELA6        69048
# 12405          1  NYC Public Schools  2021            ELA7        69806
# 14114          1  NYC Public Schools  2021            ELA8        71970
# 17058          1  NYC Public Schools  2021          ELA3_8       417119
#
#        NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  ...  \
# 64          50476              74       17438          26    11568  ...
# 3337        50177              74       17698          26    12053  ...
# 6568        53927              76       16579          24     8882  ...
# 9816        55275              80       13773          20     9538  ...
# 12405       55892              80       13914          20     8437  ...
# 14114       61170              85       10800          15     7010  ...
# 17058      326917              78       90202          22    57488  ...
#
#       Students with Disabilities_MEAN_SCORE  \
# 64                                      591
# 3337                                    592
# 6568                                    588
# 9816                                    589
# 12405                                   587
# 14114                                   588
# 17058                                   NaN
#
#       Students with Disabilities_NOT_TESTED  \
# 64                                  16878.0
# 3337                                16562.0
# 6568                                18355.0
# 9816                                17618.0
# 12405                               17182.0
# 14114                               17179.0
# 17058                                   NaN
#
#       Students with Disabilities_NUM_PROF  \
# 64                                   1011
# 3337                                 1048
# 6568                                  590
# 9816                                  697
# 12405                                 446
# 14114                                 527
# 17058                                 NaN
#
#       Students with Disabilities_NUM_TESTED  \
# 64                                   2700.0
# 3337                                 2797.0
# 6568                                 2757.0
# 9816                                 2089.0
# 12405                                2085.0
# 14114                                1737.0
# 17058                                   NaN
#
#        Students with Disabilities_PCT_NOT_TESTED  \
# 64                                          86.0
# 3337                                        86.0
# 6568                                        87.0
# 9816                                        89.0
# 12405                                       89.0
# 14114                                       91.0
# 17058                                        NaN
#
#       Students with Disabilities_PCT_TESTED  \
# 64                                     14.0
# 3337                                   14.0
# 6568                                   13.0
# 9816                                   11.0
# 12405                                  11.0
# 14114                                   9.0
# 17058                                   NaN
#
#        Students with Disabilities_PER_PROF  \
# 64                                      37
# 3337                                    37
# 6568                                    21
# 9816                                    33
# 12405                                   21
# 14114                                   30
# 17058                                  NaN
#
#        Students with Disabilities_TOTAL_COUNT  \
# 64                                    19578.0
# 3337                                  19359.0
# 6568                                  21112.0
# 9816                                  19707.0
# 12405                                 19267.0
# 14114                                 18916.0
# 17058                                     NaN
#
#        Students with Disabilities_TOTAL_SCALE_SCORES SUBJECT
# 64                                           1595908     ELA
# 3337                                         1656679     ELA
# 6568                                         1621980     ELA
# 9816                                         1230551     ELA
# 12405                                        1223984     ELA
# 14114                                        1021853     ELA
# 17058                                            NaN     ELA
#
# [7 rows x 131 columns]

# %%
11568+12053+8882+9538+8437+7010
# Out:
# 57488

# %% [markdown]
# Mathematics (2021-22)

# %%
Math_2021_2022 = pd.read_csv('df_Math_2022.csv')

# add column for Math for each row
Math_2021_2022['SUBJECT'] = 'Math'

Math_2021_2022["ASSESSMENT_NAME"].unique()
# Out:
# /var/folders/2s/c87gg64118ndg_yrky9zvlnc0000gn/T/ipykernel_45531/4275389915.py:1: DtypeWarning: Columns (11,12,13,15,19,21,22,24,28,30,31,33,37,39,40,42,46,48,49,51,55,57,58,60,64,66,67,69,73,75,76,78,82,84,85,87,91,93,94,96,100,102,103,105,109,111,112,114,118,120,121,123,127,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   Math_2021_2022 = pd.read_csv('df_Math_2022.csv')
# array(['MATH3', 'MATH4', 'MATH5', 'MATH6', 'MATH7', 'MATH8',
#        'Combined7Math', 'RegentsMath8', 'RegentsMath7', 'Combined8Math',
#        'MATH3_8', 'Combined6Math', 'RegentsMath6'], dtype=object)

# %%
# check for missing values
Math_2021_2022.isnull().sum()
# Out:
# ENTITY_CD                                            0
# ENTITY_NAME                                          0
# YEAR                                                 0
# ASSESSMENT_NAME                                      0
# TOTAL_COUNT                                       3843
#                                                  ...
# Students with Disabilities_PCT_TESTED            25135
# Students with Disabilities_PER_PROF              28570
# Students with Disabilities_TOTAL_COUNT           25135
# Students with Disabilities_TOTAL_SCALE_SCORES    28570
# SUBJECT                                              0
# Length: 131, dtype: int64

# %%
Math_2021_2022[(Math_2021_2022["YEAR"] == 2022) & (Math_2021_2022["ENTITY_CD"] == 1)]
# Out:
#        ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  TOTAL_COUNT  \
# 28037          1  NYC Public Schools  2022           MATH6      60810.0
# 28038          1  NYC Public Schools  2022           MATH3      59191.0
# 28039          1  NYC Public Schools  2022    RegentsMath7          NaN
# 28040          1  NYC Public Schools  2022    RegentsMath8          NaN
# 28041          1  NYC Public Schools  2022   Combined7Math      63143.0
# 28042          1  NYC Public Schools  2022   Combined8Math      65430.0
# 28043          1  NYC Public Schools  2022   Combined6Math      60810.0
# 28044          1  NYC Public Schools  2022           MATH4      61145.0
# 28045          1  NYC Public Schools  2022         MATH3_8     371571.0
# 28046          1  NYC Public Schools  2022           MATH7      63143.0
# 28047          1  NYC Public Schools  2022           MATH8      65430.0
# 28048          1  NYC Public Schools  2022           MATH5      61852.0
#
#        NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  ...  \
# 28037        7644            13.0       53166        87.0    18125  ...
# 28038        6878            12.0       52313        88.0    25349  ...
# 28039           0             0.0         269         0.0      229  ...
# 28040           2             0.0       22304        34.0    15675  ...
# 28041        8145            13.0       54998        87.0    19931  ...
# 28042        9406            14.0       56024        86.0    24105  ...
# 28043        7644            13.0       53166        87.0    18125  ...
# 28044        6927            11.0       54218        89.0    22757  ...
# 28045       46339            12.0      325232        88.0   130826  ...
# 28046        8414            13.0       54729        87.0    19702  ...
# 28047       31710            48.0       33720        52.0     8430  ...
# 28048        7339            12.0       54513        88.0    20559  ...
#
#       Students with Disabilities_MEAN_SCORE  \
# 28037                                   581
# 28038                                   585
# 28039                                   NaN
# 28040                                   NaN
# 28041                                   NaN
# 28042                                   NaN
# 28043                                   NaN
# 28044                                   581
# 28045                                   NaN
# 28046                                   582
# 28047                                   581
# 28048                                   582
#
#       Students with Disabilities_NOT_TESTED  \
# 28037                                4055.0
# 28038                                4158.0
# 28039                                   NaN
# 28040                                   NaN
# 28041                                   NaN
# 28042                                   NaN
# 28043                                   NaN
# 28044                                4072.0
# 28045                                   NaN
# 28046                                4248.0
# 28047                                7382.0
# 28048                                4092.0
#
#       Students with Disabilities_NUM_PROF  \
# 28037                                1220
# 28038                                2786
# 28039                                 NaN
# 28040                                 NaN
# 28041                                 NaN
# 28042                                 NaN
# 28043                                 NaN
# 28044                                2190
# 28045                                 NaN
# 28046                                1133
# 28047                                 497
# 28048                                1742
#
#       Students with Disabilities_NUM_TESTED  \
# 28037                               11622.0
# 28038                               10981.0
# 28039                                   NaN
# 28040                                   NaN
# 28041                                   NaN
# 28042                                   NaN
# 28043                                   NaN
# 28044                               11690.0
# 28045                                   NaN
# 28046                               11569.0
# 28047                                8411.0
# 28048                               11756.0
#
#        Students with Disabilities_PCT_NOT_TESTED  \
# 28037                                       26.0
# 28038                                       27.0
# 28039                                        NaN
# 28040                                        NaN
# 28041                                        NaN
# 28042                                        NaN
# 28043                                        NaN
# 28044                                       26.0
# 28045                                        NaN
# 28046                                       27.0
# 28047                                       47.0
# 28048                                       26.0
#
#       Students with Disabilities_PCT_TESTED  \
# 28037                                  74.0
# 28038                                  73.0
# 28039                                   NaN
# 28040                                   NaN
# 28041                                   NaN
# 28042                                   NaN
# 28043                                   NaN
# 28044                                  74.0
# 28045                                   NaN
# 28046                                  73.0
# 28047                                  53.0
# 28048                                  74.0
#
#        Students with Disabilities_PER_PROF  \
# 28037                                   10
# 28038                                   25
# 28039                                  NaN
# 28040                                  NaN
# 28041                                  NaN
# 28042                                  NaN
# 28043                                  NaN
# 28044                                   19
# 28045                                  NaN
# 28046                                   10
# 28047                                   06
# 28048                                   15
#
#        Students with Disabilities_TOTAL_COUNT  \
# 28037                                 15677.0
# 28038                                 15139.0
# 28039                                     NaN
# 28040                                     NaN
# 28041                                     NaN
# 28042                                     NaN
# 28043                                     NaN
# 28044                                 15762.0
# 28045                                     NaN
# 28046                                 15817.0
# 28047                                 15793.0
# 28048                                 15848.0
#
#        Students with Disabilities_TOTAL_SCALE_SCORES SUBJECT
# 28037                                        6750048    Math
# 28038                                        6419143    Math
# 28039                                            NaN    Math
# 28040                                            NaN    Math
# 28041                                            NaN    Math
# 28042                                            NaN    Math
# 28043                                            NaN    Math
# 28044                                        6790505    Math
# 28045                                            NaN    Math
# 28046                                        6738368    Math
# 28047                                        4888527    Math
# 28048                                        6837098    Math
#
# [12 rows x 131 columns]

# %% [markdown]
# Science (2021-22)

# %%
Science_2021_2022 = pd.read_csv('df_Science_2022.csv')

# add column for Science for each row
Science_2021_2022['SUBJECT'] = 'Science'

Science_2021_2022["ASSESSMENT_NAME"].unique()
# Out:
# /var/folders/2s/c87gg64118ndg_yrky9zvlnc0000gn/T/ipykernel_45531/4099104169.py:1: DtypeWarning: Columns (11,12,13,15,19,21,22,24,28,30,31,33,37,39,40,42,46,48,49,51,55,57,58,60,64,66,67,69,73,75,76,78,82,84,85,87,91,93,94,96,100,102,103,105,109,111,112,114,118,120,121,123,127,129) have mixed types. Specify dtype option on import or set low_memory=False.
#   Science_2021_2022 = pd.read_csv('df_Science_2022.csv')
# array(['Science4', 'Science8', 'RegentsScience8', 'CombinedScience ',
#        'Science4_8'], dtype=object)

# %%
Science_2021_2022[(Science_2021_2022["YEAR"] == 2022) & (Science_2021_2022["ENTITY_CD"] == 1)]
# Out:
#        ENTITY_CD         ENTITY_NAME  YEAR   ASSESSMENT_NAME  TOTAL_COUNT  \
# 13913          1  NYC Public Schools  2022   RegentsScience8          NaN
# 13914          1  NYC Public Schools  2022  CombinedScience       65476.0
# 13915          1  NYC Public Schools  2022        Science4_8     126654.0
# 13916          1  NYC Public Schools  2022          Science4      61178.0
# 13917          1  NYC Public Schools  2022          Science8      65476.0
#
#        NOT_TESTED  PCT_NOT_TESTED  NUM_TESTED  PCT_TESTED NUM_PROF  ...  \
# 13913           0               0       19939          30    13718  ...
# 13914       12018              18       53458          82    28541  ...
# 13915       19634              16      107020          84    70051  ...
# 13916        7616              12       53562          88    41510  ...
# 13917       31957              49       33519          51    14823  ...
#
#       Students with Disabilities_MEAN_SCORE  \
# 13913                                   NaN
# 13914                                   NaN
# 13915                                   NaN
# 13916                                    67
# 13917                                    51
#
#       Students with Disabilities_NOT_TESTED  \
# 13913                                   NaN
# 13914                                   NaN
# 13915                                   NaN
# 13916                                4178.0
# 13917                                7913.0
#
#       Students with Disabilities_NUM_PROF  \
# 13913                                 NaN
# 13914                                 NaN
# 13915                                 NaN
# 13916                                6988
# 13917                                1700
#
#       Students with Disabilities_NUM_TESTED  \
# 13913                                   NaN
# 13914                                   NaN
# 13915                                   NaN
# 13916                               11567.0
# 13917                                7858.0
#
#        Students with Disabilities_PCT_NOT_TESTED  \
# 13913                                        NaN
# 13914                                        NaN
# 13915                                        NaN
# 13916                                       27.0
# 13917                                       50.0
#
#       Students with Disabilities_PCT_TESTED  \
# 13913                                   NaN
# 13914                                   NaN
# 13915                                   NaN
# 13916                                  73.0
# 13917                                  50.0
#
#        Students with Disabilities_PER_PROF  \
# 13913                                  NaN
# 13914                                  NaN
# 13915                                  NaN
# 13916                                   60
# 13917                                   22
#
#        Students with Disabilities_TOTAL_COUNT  \
# 13913                                     NaN
# 13914                                     NaN
# 13915                                     NaN
# 13916                                 15745.0
# 13917                                 15771.0
#
#        Students with Disabilities_TOTAL_SCALE_SCORES  SUBJECT
# 13913                                            NaN  Science
# 13914                                            NaN  Science
# 13915                                            NaN  Science
# 13916                                         775086  Science
# 13917                                         398770  Science
#
# [5 rows x 131 columns]

# %%
# stack the dataframes on top of each other
subject_df_2021_22 = pd.concat([ELA_2021_2022, Math_2021_2022, Science_2021_2022], axis=0)

# %%
subject_df_2021_22["ASSESSMENT_NAME"].unique()
# Out:
# array(['ELA3', 'ELA4', 'ELA5', 'ELA6', 'ELA7', 'ELA8', 'ELA3_8', 'MATH3',
#        'MATH4', 'MATH5', 'MATH6', 'MATH7', 'MATH8', 'Combined7Math',
#        'RegentsMath8', 'RegentsMath7', 'Combined8Math', 'MATH3_8',
#        'Combined6Math', 'RegentsMath6', 'Science4', 'Science8',
#        'RegentsScience8', 'CombinedScience ', 'Science4_8'], dtype=object)

# %% [markdown]
# # Subject 2018-19

# %% [markdown]
# English (2018-19)

# %%
ELA_2018_2019 = pd.read_csv('df_ela_2019.csv')

# add column for ELA for each row
ELA_2018_2019['SUBJECT'] = 'ELA'

ELA_2018_2019["ASSESSMENT_NAME"].unique()
# Out:
# /var/folders/2s/c87gg64118ndg_yrky9zvlnc0000gn/T/ipykernel_45531/260585670.py:1: DtypeWarning: Columns (6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ELA_2018_2019 = pd.read_csv('df_ela_2019.csv')
# array(['ELA5', 'ELA3_8', 'ELA3', 'ELA7', 'ELA8', 'ELA6', 'ELA4'],
#       dtype=object)

# %%
ELA_2018_2019[(ELA_2018_2019["YEAR"] == 2019) & (ELA_2018_2019["ENTITY_CD"] == 1)]
# Out:
#     ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME  NOT_TESTED  \
# 7           1  NYC Public Schools  2019            ELA5        9094
# 8           1  NYC Public Schools  2019          ELA3_8       52862
# 9           1  NYC Public Schools  2019            ELA3       11117
# 10          1  NYC Public Schools  2019            ELA8        8589
# 11          1  NYC Public Schools  2019            ELA7        7172
# 12          1  NYC Public Schools  2019            ELA6        7663
# 13          1  NYC Public Schools  2019            ELA4        9227
#
#     NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 7        66181    26350       40           39723819        600  ...
# 8       392595   186002       47                 00         00  ...
# 9        64752    34498       53           38867037        600  ...
# 10       63706    32237       51           38309671        601  ...
# 11       64983    27766       43           39077597        601  ...
# 12       66181    32008       48           39648032        599  ...
# 13       66792    33143       50           40028416        599  ...
#
#    Not Economically Disadvantaged_NUM_TESTED  \
# 7                                    16916.0
# 8                                        NaN
# 9                                    17079.0
# 10                                   16281.0
# 11                                   16630.0
# 12                                   16859.0
# 13                                   17306.0
#
#     Not Economically Disadvantaged_PER_PROF  \
# 7                                        60
# 8                                       NaN
# 9                                        74
# 10                                       67
# 11                                       63
# 12                                       69
# 13                                       70
#
#    Not Economically Disadvantaged_TOTAL_SCALE_SCORES  \
# 7                                           10321578
# 8                                                NaN
# 9                                           10419470
# 10                                           9911200
# 11                                          10161133
# 12                                          10284246
# 13                                          10543027
#
#     Students with Disabilities_MEAN_SCORE  \
# 7                                     583
# 8                                     NaN
# 9                                     585
# 10                                    586
# 11                                    585
# 12                                    581
# 13                                    584
#
#    Students with Disabilities_NOT_TESTED Students with Disabilities_NUM_PROF  \
# 7                                 6454.0                                1726
# 8                                    NaN                                 NaN
# 9                                 8345.0                                3198
# 10                                5128.0                                2330
# 11                                5012.0                                1583
# 12                                5578.0                                2319
# 13                                6628.0                                2772
#
#    Students with Disabilities_NUM_TESTED  Students with Disabilities_PER_PROF  \
# 7                                14913.0                                   12
# 8                                    NaN                                  NaN
# 9                                14302.0                                   22
# 10                               13460.0                                   17
# 11                               14024.0                                   11
# 12                               14639.0                                   16
# 13                               14993.0                                   18
#
#    Students with Disabilities_TOTAL_SCALE_SCORES  SUBJECT
# 7                                        8698658      ELA
# 8                                            NaN      ELA
# 9                                        8364234      ELA
# 10                                       7893735      ELA
# 11                                       8199157      ELA
# 12                                       8506455      ELA
# 13                                       8752154      ELA
#
# [7 rows x 89 columns]

# %% [markdown]
# Mathematics (2018-19)

# %%
Math_2018_2019 = pd.read_csv('df_Math_2019.csv')

# add column for Math for each row
Math_2018_2019['SUBJECT'] = 'Math'

Math_2018_2019["ASSESSMENT_NAME"].unique()
# Out:
# array(['Combined8Math', 'Combined7Math', 'RegentsMath8', 'MATH3_8',
#        'MATH8', 'MATH7', 'MATH5', 'MATH3', 'MATH6', 'MATH4',
#        'RegentsMath7'], dtype=object)

# %%
Math_2018_2019[(Math_2018_2019["YEAR"] == 2019) & (Math_2018_2019["ENTITY_CD"] == 1)]
# Out:
#        ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME NOT_TESTED  \
# 26935          1  NYC Public Schools  2019           MATH4       7965
# 26936          1  NYC Public Schools  2019         MATH3_8      62299
# 26937          1  NYC Public Schools  2019           MATH7       6774
# 26938          1  NYC Public Schools  2019           MATH8      22960
# 26939          1  NYC Public Schools  2019           MATH5       7881
# 26940          1  NYC Public Schools  2019           MATH3       9776
# 26941          1  NYC Public Schools  2019    RegentsMath7          s
# 26942          1  NYC Public Schools  2019   Combined8Math      22960
# 26943          1  NYC Public Schools  2019    RegentsMath8          s
# 26944          1  NYC Public Schools  2019           MATH6       6943
# 26945          1  NYC Public Schools  2019   Combined7Math       6774
#
#        NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 26935       68046    33604       49           40859159        600  ...
# 26936      398976   187256       47                 00         00  ...
# 26937       65447    27559       42           39329413        601  ...
# 26938       49372    17780       36           29658769        601  ...
# 26939       67386    31066       46           40456825        600  ...
# 26940       66091    35167       53           39651224        600  ...
# 26941         267      215       81                NaN        NaN  ...
# 26942       64831    30249       47                 00         00  ...
# 26943       15459    12469       81                NaN        NaN  ...
# 26944       66908    29396       44           40115105        600  ...
# 26945       65714    27774       42                 00         00  ...
#
#       Not Economically Disadvantaged_NUM_TESTED  \
# 26935                                   17594.0
# 26936                                       NaN
# 26937                                   16694.0
# 26938                                   10816.0
# 26939                                   17184.0
# 26940                                   17402.0
# 26941                                       NaN
# 26942                                       NaN
# 26943                                       NaN
# 26944                                   16971.0
# 26945                                       NaN
#
#        Not Economically Disadvantaged_PER_PROF  \
# 26935                                       70
# 26936                                      NaN
# 26937                                       61
# 26938                                       48
# 26939                                       66
# 26940                                       73
# 26941                                      NaN
# 26942                                      NaN
# 26943                                      NaN
# 26944                                       64
# 26945                                      NaN
#
#       Not Economically Disadvantaged_TOTAL_SCALE_SCORES  \
# 26935                                          10740486
# 26936                                               NaN
# 26937                                          10181278
# 26938                                           6559667
# 26939                                          10473460
# 26940                                          10599926
# 26941                                               NaN
# 26942                                               NaN
# 26943                                               NaN
# 26944                                          10332478
# 26945                                               NaN
#
#        Students with Disabilities_MEAN_SCORE  \
# 26935                                    586
# 26936                                    NaN
# 26937                                    584
# 26938                                    585
# 26939                                    585
# 26940                                    587
# 26941                                    NaN
# 26942                                    NaN
# 26943                                    NaN
# 26944                                    583
# 26945                                    NaN
#
#       Students with Disabilities_NOT_TESTED  \
# 26935                                6580.0
# 26936                                   NaN
# 26937                                5230.0
# 26938                                7262.0
# 26939                                6460.0
# 26940                                8240.0
# 26941                                   NaN
# 26942                                   NaN
# 26943                                   NaN
# 26944                                5760.0
# 26945                                   NaN
#
#       Students with Disabilities_NUM_PROF  \
# 26935                                3284
# 26936                                 NaN
# 26937                                1650
# 26938                                1216
# 26939                                2666
# 26940                                3890
# 26941                                 NaN
# 26942                                 NaN
# 26943                                 NaN
# 26944                                1963
# 26945                                 NaN
#
#       Students with Disabilities_NUM_TESTED  \
# 26935                               15019.0
# 26936                                   NaN
# 26937                               13787.0
# 26938                               11316.0
# 26939                               14872.0
# 26940                               14396.0
# 26941                                   NaN
# 26942                                   NaN
# 26943                                   NaN
# 26944                               14439.0
# 26945                                   NaN
#
#        Students with Disabilities_PER_PROF  \
# 26935                                   22
# 26936                                  NaN
# 26937                                   12
# 26938                                   11
# 26939                                   18
# 26940                                   27
# 26941                                  NaN
# 26942                                  NaN
# 26943                                  NaN
# 26944                                   14
# 26945                                  NaN
#
#       Students with Disabilities_TOTAL_SCALE_SCORES  SUBJECT
# 26935                                       8805016     Math
# 26936                                           NaN     Math
# 26937                                       8053869     Math
# 26938                                       6622129     Math
# 26939                                       8705256     Math
# 26940                                       8457137     Math
# 26941                                           NaN     Math
# 26942                                           NaN     Math
# 26943                                           NaN     Math
# 26944                                       8424631     Math
# 26945                                           NaN     Math
#
# [11 rows x 89 columns]

# %%
# check for missing values
Math_2018_2019.isnull().sum()
# Out:
# ENTITY_CD                                            0
# ENTITY_NAME                                          0
# YEAR                                                 0
# ASSESSMENT_NAME                                      0
# NOT_TESTED                                           4
#                                                  ...
# Students with Disabilities_NUM_PROF              19708
# Students with Disabilities_NUM_TESTED            19708
# Students with Disabilities_PER_PROF              19708
# Students with Disabilities_TOTAL_SCALE_SCORES    19708
# SUBJECT                                              0
# Length: 89, dtype: int64

# %% [markdown]
# Science (2018-19)

# %%
Science_2018_2019 = pd.read_csv('df_Science_2019.csv')

# add column for Science for each row
Science_2018_2019['SUBJECT'] = 'Science'

Science_2018_2019["ASSESSMENT_NAME"].unique()
# Out:
# array(['Science4', 'Science8', 'RegentsScience8', 'CombinedScience ',
#        'Science4_8'], dtype=object)

# %%
Science_2018_2019[(Science_2018_2019["YEAR"] == 2018) & (Science_2018_2019["ENTITY_CD"] == 1)]
# Out:
#    ENTITY_CD         ENTITY_NAME  YEAR   ASSESSMENT_NAME NOT_TESTED  \
# 0          1  NYC Public Schools  2018          Science4       8549
# 1          1  NYC Public Schools  2018          Science8      23690
# 2          1  NYC Public Schools  2018   RegentsScience8          s
# 3          1  NYC Public Schools  2018  CombinedScience       23690
# 4          1  NYC Public Schools  2018        Science4_8      32239
#
#    NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0       68089    59021       87            5510492         81  ...
# 1       47519    25375       53            3062957         64  ...
# 2       14463    11338       78                NaN        NaN  ...
# 3       61982    36713       59            3062957         49  ...
# 4      130071    95734       74            8573449         66  ...
#
#   Not Economically Disadvantaged_NUM_TESTED  \
# 0                                   16622.0
# 1                                    9907.0
# 2                                    5529.0
# 3                                       NaN
# 4                                       NaN
#
#   Not Economically Disadvantaged_PER_PROF  \
# 0                                      95
# 1                                      69
# 2                                      89
# 3                                     NaN
# 4                                     NaN
#
#   Not Economically Disadvantaged_TOTAL_SCALE_SCORES  \
# 0                                           1451579
# 1                                            707668
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Students with Disabilities_MEAN_SCORE  \
# 0                                     74
# 1                                     54
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   Students with Disabilities_NOT_TESTED Students with Disabilities_NUM_PROF  \
# 0                                  6412                               11052
# 1                                  7136                                2910
# 2                                     s                                 537
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#   Students with Disabilities_NUM_TESTED Students with Disabilities_PER_PROF  \
# 0                               14793.0                                  75
# 1                               10589.0                                  27
# 2                                1328.0                                  40
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#   Students with Disabilities_TOTAL_SCALE_SCORES  SUBJECT
# 0                                       1087759  Science
# 1                                        567837  Science
# 2                                           NaN  Science
# 3                                           NaN  Science
# 4                                           NaN  Science
#
# [5 rows x 89 columns]

# %%
# stack the dataframes on top of each other
subject_df_2018_19 = pd.concat([ELA_2018_2019, Math_2018_2019, Science_2018_2019], axis=0)

# %%
subject_df_2018_19["ASSESSMENT_NAME"].unique()
# Out:
# array(['ELA5', 'ELA3_8', 'ELA3', 'ELA7', 'ELA8', 'ELA6', 'ELA4',
#        'Combined8Math', 'Combined7Math', 'RegentsMath8', 'MATH3_8',
#        'MATH8', 'MATH7', 'MATH5', 'MATH3', 'MATH6', 'MATH4',
#        'RegentsMath7', 'Science4', 'Science8', 'RegentsScience8',
#        'CombinedScience ', 'Science4_8'], dtype=object)

# %% [markdown]
# # Final Subjects Dataframe

# %%
# stack the dataframes on top of each other
subject_df_2018_19_2021_22 = pd.concat([subject_df_2018_19, subject_df_2021_22], axis=0)

subject_df_2018_19_2021_22.head()
# Out:
#    ENTITY_CD         ENTITY_NAME  YEAR ASSESSMENT_NAME NOT_TESTED  NUM_TESTED  \
# 0          1  NYC Public Schools  2018            ELA5       8982       68439
# 1          1  NYC Public Schools  2018          ELA3_8      51959      396804
# 2          1  NYC Public Schools  2018            ELA3      10410       67237
# 3          1  NYC Public Schools  2018            ELA7       7157       65250
# 4          1  NYC Public Schools  2018            ELA8       8457       63183
#
#   NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0    25990       38           41110322        601  ...
# 1   185099       47                 00         00  ...
# 2    34036       51           40361558        600  ...
# 3    27812       43           39254856        602  ...
# 4    32042       51           38019693        602  ...
#
#   Non-English Language Learner_TOTAL_COUNT  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Economically Disadvantaged_PCT_NOT_TESTED  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Economically Disadvantaged_PCT_TESTED  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    Economically Disadvantaged_TOTAL_COUNT  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Not Economically Disadvantaged_PCT_NOT_TESTED  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Not Economically Disadvantaged_PCT_TESTED  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Not Economically Disadvantaged_TOTAL_COUNT  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   Students with Disabilities_PCT_NOT_TESTED  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Students with Disabilities_PCT_TESTED  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    Students with Disabilities_TOTAL_COUNT
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 131 columns]

# %%
subject_df_2018_19_2021_22[(subject_df_2018_19_2021_22["YEAR"] == 2018) & (subject_df_2018_19_2021_22["ENTITY_CD"] == 1)]
# Out:
#     ENTITY_CD         ENTITY_NAME  YEAR   ASSESSMENT_NAME NOT_TESTED  \
# 0           1  NYC Public Schools  2018              ELA5       8982
# 1           1  NYC Public Schools  2018            ELA3_8      51959
# 2           1  NYC Public Schools  2018              ELA3      10410
# 3           1  NYC Public Schools  2018              ELA7       7157
# 4           1  NYC Public Schools  2018              ELA8       8457
# 5           1  NYC Public Schools  2018              ELA6       7496
# 6           1  NYC Public Schools  2018              ELA4       9457
# 0           1  NYC Public Schools  2018     Combined8Math      21909
# 1           1  NYC Public Schools  2018     Combined7Math       6675
# 2           1  NYC Public Schools  2018      RegentsMath8          s
# 3           1  NYC Public Schools  2018           MATH3_8      60289
# 4           1  NYC Public Schools  2018             MATH8      21909
# 5           1  NYC Public Schools  2018             MATH7       6675
# 6           1  NYC Public Schools  2018             MATH5       8000
# 7           1  NYC Public Schools  2018             MATH3       8920
# 8           1  NYC Public Schools  2018             MATH6       6635
# 9           1  NYC Public Schools  2018             MATH4       8150
# 10          1  NYC Public Schools  2018      RegentsMath7          s
# 0           1  NYC Public Schools  2018          Science4       8549
# 1           1  NYC Public Schools  2018          Science8      23690
# 2           1  NYC Public Schools  2018   RegentsScience8          s
# 3           1  NYC Public Schools  2018  CombinedScience       23690
# 4           1  NYC Public Schools  2018        Science4_8      32239
#
#     NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0        68439    25990       38           41110322        601  ...
# 1       396804   185099       47                 00         00  ...
# 2        67237    34036       51           40361558        600  ...
# 3        65250    27812       43           39254856        602  ...
# 4        63183    32042       51           38019693        602  ...
# 5        65108    31863       49           39089628        600  ...
# 6        67587    33356       49           40625764        601  ...
# 0        64087    27892       44                 00         00  ...
# 1        65892    26320       40                 00         00  ...
# 2        14361    11369       79                NaN        NaN  ...
# 3       402824   177196       44                 00         00  ...
# 4        49726    16523       33           29864407        601  ...
# 5        65714    26153       40           39370707        599  ...
# 6        69374    28916       42           41569152        599  ...
# 7        68673    35868       52           41161976        599  ...
# 8        65955    26276       40           39462194        598  ...
# 9        68843    31924       46           41274761        600  ...
# 10         178      167       94                NaN        NaN  ...
# 0        68089    59021       87            5510492         81  ...
# 1        47519    25375       53            3062957         64  ...
# 2        14463    11338       78                NaN        NaN  ...
# 3        61982    36713       59            3062957         49  ...
# 4       130071    95734       74            8573449         66  ...
#
#    Non-English Language Learner_TOTAL_COUNT  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Economically Disadvantaged_PCT_NOT_TESTED  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Economically Disadvantaged_PCT_TESTED  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#     Economically Disadvantaged_TOTAL_COUNT  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Not Economically Disadvantaged_PCT_NOT_TESTED  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Not Economically Disadvantaged_PCT_TESTED  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Not Economically Disadvantaged_TOTAL_COUNT  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Students with Disabilities_PCT_NOT_TESTED  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Students with Disabilities_PCT_TESTED  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#     Students with Disabilities_TOTAL_COUNT
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [23 rows x 131 columns]

# %%
# count rows for each year
subject_df_2018_19_2021_22["YEAR"].value_counts()
# Out:
# 2022    66202
# 2021    63447
# 2018    60889
# 2019    57707
# Name: YEAR, dtype: int64

# %%
# check for null values
subject_df_2018_19_2021_22.isnull().sum()
# Out:
# ENTITY_CD                                          0
# ENTITY_NAME                                        0
# YEAR                                               0
# ASSESSMENT_NAME                                    0
# NOT_TESTED                                         4
#                                                ...
# Not Economically Disadvantaged_PCT_TESTED     171837
# Not Economically Disadvantaged_TOTAL_COUNT    171837
# Students with Disabilities_PCT_NOT_TESTED     169962
# Students with Disabilities_PCT_TESTED         169962
# Students with Disabilities_TOTAL_COUNT        169962
# Length: 131, dtype: int64

# %%
# save as csv
subject_df_2018_19_2021_22.to_csv('subject_df_2018_19_2021_22.csv', index=False)

# %%
subject_df_2018_19_2021_22[(subject_df_2018_19_2021_22["YEAR"] == 2018) & (subject_df_2018_19_2021_22["ENTITY_CD"] == 1)]
# Out:
#     ENTITY_CD         ENTITY_NAME  YEAR   ASSESSMENT_NAME NOT_TESTED  \
# 0           1  NYC Public Schools  2018              ELA5       8982
# 1           1  NYC Public Schools  2018            ELA3_8      51959
# 2           1  NYC Public Schools  2018              ELA3      10410
# 3           1  NYC Public Schools  2018              ELA7       7157
# 4           1  NYC Public Schools  2018              ELA8       8457
# 5           1  NYC Public Schools  2018              ELA6       7496
# 6           1  NYC Public Schools  2018              ELA4       9457
# 0           1  NYC Public Schools  2018     Combined8Math      21909
# 1           1  NYC Public Schools  2018     Combined7Math       6675
# 2           1  NYC Public Schools  2018      RegentsMath8          s
# 3           1  NYC Public Schools  2018           MATH3_8      60289
# 4           1  NYC Public Schools  2018             MATH8      21909
# 5           1  NYC Public Schools  2018             MATH7       6675
# 6           1  NYC Public Schools  2018             MATH5       8000
# 7           1  NYC Public Schools  2018             MATH3       8920
# 8           1  NYC Public Schools  2018             MATH6       6635
# 9           1  NYC Public Schools  2018             MATH4       8150
# 10          1  NYC Public Schools  2018      RegentsMath7          s
# 0           1  NYC Public Schools  2018          Science4       8549
# 1           1  NYC Public Schools  2018          Science8      23690
# 2           1  NYC Public Schools  2018   RegentsScience8          s
# 3           1  NYC Public Schools  2018  CombinedScience       23690
# 4           1  NYC Public Schools  2018        Science4_8      32239
#
#     NUM_TESTED NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE  ...  \
# 0        68439    25990       38           41110322        601  ...
# 1       396804   185099       47                 00         00  ...
# 2        67237    34036       51           40361558        600  ...
# 3        65250    27812       43           39254856        602  ...
# 4        63183    32042       51           38019693        602  ...
# 5        65108    31863       49           39089628        600  ...
# 6        67587    33356       49           40625764        601  ...
# 0        64087    27892       44                 00         00  ...
# 1        65892    26320       40                 00         00  ...
# 2        14361    11369       79                NaN        NaN  ...
# 3       402824   177196       44                 00         00  ...
# 4        49726    16523       33           29864407        601  ...
# 5        65714    26153       40           39370707        599  ...
# 6        69374    28916       42           41569152        599  ...
# 7        68673    35868       52           41161976        599  ...
# 8        65955    26276       40           39462194        598  ...
# 9        68843    31924       46           41274761        600  ...
# 10         178      167       94                NaN        NaN  ...
# 0        68089    59021       87            5510492         81  ...
# 1        47519    25375       53            3062957         64  ...
# 2        14463    11338       78                NaN        NaN  ...
# 3        61982    36713       59            3062957         49  ...
# 4       130071    95734       74            8573449         66  ...
#
#    Non-English Language Learner_TOTAL_COUNT  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Economically Disadvantaged_PCT_NOT_TESTED  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Economically Disadvantaged_PCT_TESTED  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#     Economically Disadvantaged_TOTAL_COUNT  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Not Economically Disadvantaged_PCT_NOT_TESTED  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Not Economically Disadvantaged_PCT_TESTED  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Not Economically Disadvantaged_TOTAL_COUNT  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Students with Disabilities_PCT_NOT_TESTED  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Students with Disabilities_PCT_TESTED  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#     Students with Disabilities_TOTAL_COUNT
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [23 rows x 131 columns]
