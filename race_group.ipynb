# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Read in the data
ela_2018 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2018\Annual EM ELA.csv")
math_2018 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2018\Annual EM Math.csv")
science_2018 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2018\Annual EM SCIENCE.csv")
# Out:
# C:\Users\ericr\AppData\Local\Temp\ipykernel_49104\76571593.py:2: DtypeWarning: Columns (15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   ela_2018 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2018\Annual EM ELA.csv")
# C:\Users\ericr\AppData\Local\Temp\ipykernel_49104\76571593.py:3: DtypeWarning: Columns (15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   math_2018 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2018\Annual EM Math.csv")
# C:\Users\ericr\AppData\Local\Temp\ipykernel_49104\76571593.py:4: DtypeWarning: Columns (15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   science_2018 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2018\Annual EM SCIENCE.csv")

# %%
ela_2018
# Out:
#            ENTITY_CD                         ENTITY_NAME  YEAR
# 0       331400011071  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018  \
# 1       331400011071  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018
# 2       331400011071  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018
# 3       331400011071  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018
# 4       331400011071  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018
# ...              ...                                 ...   ...
# 654689  680801040002            DUNDEE ELEMENTARY SCHOOL  2018
# 654690  680801040002            DUNDEE ELEMENTARY SCHOOL  2018
# 654691  680801040002            DUNDEE ELEMENTARY SCHOOL  2018
# 654692  680801040002            DUNDEE ELEMENTARY SCHOOL  2018
# 654693  680801040002            DUNDEE ELEMENTARY SCHOOL  2018
#
#        ASSESSMENT_NAME               SUBGROUP_NAME  NUM_TESTED  NOT_TESTED
# 0                 ELA8          Hispanic or Latino          39           6  \
# 1                 ELA7          Hispanic or Latino          36           2
# 2                 ELA6          Hispanic or Latino          36           2
# 3                 ELA8                    Homeless           9           2
# 4                 ELA7                    Homeless           6           1
# ...                ...                         ...         ...         ...
# 654689            ELA4  Students with Disabilities          10           1
# 654690            ELA5                       White          41           2
# 654691            ELA6                       White          26           4
# 654692            ELA3                       White          65           1
# 654693            ELA4                       White          44           1
#
#        LEVEL1_COUNT LEVEL1_%TESTED LEVEL2_COUNT  ... LEVEL3_COUNT
# 0                17             44           15  ...            6  \
# 1                15             42           15  ...            5
# 2                 8             22           13  ...           11
# 3                 5             56            2  ...            2
# 4                 4             67            2  ...            0
# ...             ...            ...          ...  ...          ...
# 654689            6             60            4  ...            0
# 654690            s              s            s  ...            s
# 654691            s              s            s  ...            s
# 654692            s              s            s  ...            s
# 654693            s              s            s  ...            s
#
#        LEVEL3_%TESTED LEVEL4_COUNT LEVEL4_%TESTED LEVEL5_COUNT LEVEL5_%TESTED
# 0                  15            1             03            0             00  \
# 1                  14            1             03            0             00
# 2                  31            4             11            0             00
# 3                  22            0             00            0             00
# 4                  00            0             00            0             00
# ...               ...          ...            ...          ...            ...
# 654689             00            0             00            0             00
# 654690              s            s              s            s              s
# 654691              s            s              s            s              s
# 654692              s            s              s            s              s
# 654693              s            s              s            s              s
#
#        NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE
# 0             7       18              22910        587
# 1             6       17              21346        593
# 2            15       42              21466        596
# 3             2       22               5284        587
# 4             0       00               3491        582
# ...         ...      ...                ...        ...
# 654689        0       00               5797        580
# 654690        s        s                  s          s
# 654691        s        s                  s          s
# 654692        s        s                  s          s
# 654693        s        s                  s          s
#
# [654694 rows x 21 columns]

# %%
ela_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 654694 entries, 0 to 654693
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ENTITY_CD           654694 non-null  int64
#  1   ENTITY_NAME         654694 non-null  object
#  2   YEAR                654694 non-null  int64
#  3   ASSESSMENT_NAME     654694 non-null  object
#  4   SUBGROUP_NAME       654694 non-null  object
#  5   NUM_TESTED          654694 non-null  int64
#  6   NOT_TESTED          654694 non-null  int64
#  7   LEVEL1_COUNT        654694 non-null  object
#  8   LEVEL1_%TESTED      654694 non-null  object
#  9   LEVEL2_COUNT        654694 non-null  object
#  10  LEVEL2_%TESTED      654694 non-null  object
#  11  LEVEL3_COUNT        654694 non-null  object
#  12  LEVEL3_%TESTED      654694 non-null  object
#  13  LEVEL4_COUNT        654694 non-null  object
#  14  LEVEL4_%TESTED      654694 non-null  object
#  15  LEVEL5_COUNT        304561 non-null  object
#  16  LEVEL5_%TESTED      304561 non-null  object
#  17  NUM_PROF            304561 non-null  object
#  18  PER_PROF            304561 non-null  object
#  19  TOTAL_SCALE_SCORES  654694 non-null  object
#  20  MEAN_SCORE          620662 non-null  object
# dtypes: int64(4), object(17)
# memory usage: 104.9+ MB

# %%
Team_9_keep_cols = ["NUM_TESTED", "NUM_PROF", "TOTAL_SCALE_SCORES", "MEAN_SCORE"]

# %%
ela_2018.SUBGROUP_NAME.unique()
# Out:
# array(['Hispanic or Latino', 'Homeless', 'Male',
#        'Non-English Language Learners', 'Not Economically Disadvantaged',
#        'American Indian or Alaska Native',
#        'Asian or Native Hawaiian/Other Pacific Islander',
#        'Black or African American', 'Economically Disadvantaged',
#        'English Language Learners', 'Female', 'General Education',
#        'Multiracial', 'All Students', 'Not Migrant',
#        'Students with Disabilities', 'White', 'Migrant',
#        'Small Group Total', 'American Indian or Alaska Native Female',
#        'American Indian or Alaska Native Male',
#        'Asian or Native Hawaiian/Other Pacific Islander Female',
#        'Asian or Native Hawaiian/Other Pacific Islander Male',
#        'Black or African American Female',
#        'Black or African American Male', 'Hispanic or Latino Female',
#        'Hispanic or Latino Male', 'Multiracial Female',
#        'Multiracial Male', 'White Female', 'White Male', 'Not Homeless',
#        'Not in Foster Care', 'Parent in Armed Forces',
#        'Parent Not in Armed Forces', 'In Foster Care'], dtype=object)

# %%
import pandas as pd

def race_df_maker(df : pd.DataFrame, base_cols : list[str], subgroups : list[str], keep_cols : list[str] = None) -> pd.DataFrame:
    """Takes a list of dataframes and returns them edited 
    within dictionaries
    """

    copy_df = df.copy() # to contain all the core records

    copy_df['Subject'] = copy_df['ASSESSMENT_NAME'].str.extract(r"([A-Za-z]*).*", expand=False)

    copy_df[copy_df.MEAN_SCORE == 's'] = np.nan

    copy_df['MEAN_SCORE'] = copy_df['MEAN_SCORE'].astype(float)

    copy_df["MEAN_SCORE"].fillna(copy_df.groupby(["YEAR", "ENTITY_CD", "Subject"])["MEAN_SCORE"].transform("mean"), inplace=True)

    base_cols.append("Subject")
    
    if keep_cols is (not None):
        base_cols = keep_cols + base_cols + "SUBGROUP_NAME"

    else:

        base_cols = base_cols + ["SUBGROUP_NAME"]

    base_df = copy_df[base_cols].copy() # get the core records

    base_df.drop_duplicates(inplace=True, ignore_index=True) # remove duplicates

    # At this point, we have a df custom to merge with Team 9's base data
    # that contains all the schools,
    # But we still need the data by race

    # We will create a dictionary of dataframes

    df_dict = {}

    for group in subgroups:

        # copy to avoid pointer issues
        
        group_df = copy_df[copy_df["SUBGROUP_NAME"] == group].copy()

        formatted_name = group.replace(" ", "_").lower()

        df_dict[group] = group_df

        for col in base_cols:

            if col not in ([base_cols] + ['SUBGROUP_NAME']):

                base_df[f"{formatted_name}_{col}"] = base_df.merge(df_dict[group], on=base_cols)[col]
        
    for key in df_dict.keys():

        cols_to_rename = [col for col in df_dict[key].columns if col not in base_cols]

        renaming_dict = ({col : f"{key.replace(' ', '_').lower()}_{col}" for col in cols_to_rename})

        df_dict[key].rename(columns=renaming_dict, inplace=True)

    return base_df, df_dict

# %%
ela_base, ela_dict = race_df_maker(
    ela_2018,
    ["ENTITY_CD", "ENTITY_NAME", "YEAR", "ASSESSMENT_NAME"],
    [
        "Hispanic or Latino",
        "Black or African American",
        "American Indian or Alaska Native",
        "Asian or Native Hawaiian/Other Pacific Islander",
        "Multiracial",
        "White",
    ], keep_cols=Team_9_keep_cols
)

# %%
ela_base.shape
# Out:
# (437547, 36)

# %%
ela_dict.keys()
# Out:
# dict_keys(['Hispanic or Latino', 'Black or African American', 'American Indian or Alaska Native', 'Asian or Native Hawaiian/Other Pacific Islander', 'Multiracial', 'White'])

# %%
ela_dict["American Indian or Alaska Native"]
# Out:
#            ENTITY_CD                             ENTITY_NAME    YEAR
# 49      1.000000e+00                      NYC Public Schools  2018.0  \
# 50      1.000000e+00                      NYC Public Schools  2018.0
# 51      1.000000e+00                      NYC Public Schools  2018.0
# 52      1.000000e+00                      NYC Public Schools  2018.0
# 53      1.000000e+00                      NYC Public Schools  2018.0
# ...              ...                                     ...     ...
# 620282  5.809060e+11  SOUTHAMPTON UNION FREE SCHOOL DISTRICT  2018.0
# 649084  6.623000e+11            YONKERS CITY SCHOOL DISTRICT  2018.0
# 649085  6.623000e+11            YONKERS CITY SCHOOL DISTRICT  2018.0
# 649086  6.623000e+11            YONKERS CITY SCHOOL DISTRICT  2018.0
# 649088  6.623000e+11            YONKERS CITY SCHOOL DISTRICT  2018.0
#
#        ASSESSMENT_NAME                     SUBGROUP_NAME
# 49                ELA5  American Indian or Alaska Native  \
# 50                ELA3  American Indian or Alaska Native
# 51                ELA7  American Indian or Alaska Native
# 52                ELA8  American Indian or Alaska Native
# 53                ELA6  American Indian or Alaska Native
# ...                ...                               ...
# 620282            ELA5  American Indian or Alaska Native
# 649084            ELA5  American Indian or Alaska Native
# 649085            ELA4  American Indian or Alaska Native
# 649086            ELA8  American Indian or Alaska Native
# 649088            ELA7  American Indian or Alaska Native
#
#         american_indian_or_alaska_native_NUM_TESTED
# 49                                            762.0  \
# 50                                            756.0
# 51                                            738.0
# 52                                            764.0
# 53                                            696.0
# ...                                             ...
# 620282                                         10.0
# 649084                                         11.0
# 649085                                          7.0
# 649086                                          5.0
# 649088                                          6.0
#
#         american_indian_or_alaska_native_NOT_TESTED
# 49                                             91.0  \
# 50                                             96.0
# 51                                             76.0
# 52                                             93.0
# 53                                             95.0
# ...                                             ...
# 620282                                          8.0
# 649084                                          0.0
# 649085                                          0.0
# 649086                                          1.0
# 649088                                          1.0
#
#        american_indian_or_alaska_native_LEVEL1_COUNT
# 49                                               282  \
# 50                                               135
# 51                                               240
# 52                                               137
# 53                                               210
# ...                                              ...
# 620282                                             6
# 649084                                             8
# 649085                                             1
# 649086                                             1
# 649088                                             3
#
#        american_indian_or_alaska_native_LEVEL1_%TESTED
# 49                                                  37  \
# 50                                                  18
# 51                                                  33
# 52                                                  18
# 53                                                  30
# ...                                                ...
# 620282                                              60
# 649084                                              73
# 649085                                              14
# 649086                                              20
# 649088                                              50
#
#        american_indian_or_alaska_native_LEVEL2_COUNT  ...
# 49                                               224  ...  \
# 50                                               273  ...
# 51                                               209  ...
# 52                                               279  ...
# 53                                               164  ...
# ...                                              ...  ...
# 620282                                             2  ...
# 649084                                             0  ...
# 649085                                             4  ...
# 649086                                             2  ...
# 649088                                             1  ...
#
#        american_indian_or_alaska_native_LEVEL3_%TESTED
# 49                                                  22  \
# 50                                                  39
# 51                                                  27
# 52                                                  27
# 53                                                  19
# ...                                                ...
# 620282                                              20
# 649084                                              09
# 649085                                              14
# 649086                                              40
# 649088                                              17
#
#        american_indian_or_alaska_native_LEVEL4_COUNT
# 49                                                89  \
# 50                                                56
# 51                                                89
# 52                                               145
# 53                                               189
# ...                                              ...
# 620282                                             0
# 649084                                             2
# 649085                                             1
# 649086                                             0
# 649088                                             1
#
#        american_indian_or_alaska_native_LEVEL4_%TESTED
# 49                                                  12  \
# 50                                                  07
# 51                                                  12
# 52                                                  19
# 53                                                  27
# ...                                                ...
# 620282                                              00
# 649084                                              18
# 649085                                              14
# 649086                                              00
# 649088                                              17
#
#        american_indian_or_alaska_native_LEVEL5_COUNT
# 49                                                 0  \
# 50                                                 0
# 51                                                 0
# 52                                                 0
# 53                                                 0
# ...                                              ...
# 620282                                             0
# 649084                                             0
# 649085                                             0
# 649086                                             0
# 649088                                             0
#
#        american_indian_or_alaska_native_LEVEL5_%TESTED
# 49                                                  00  \
# 50                                                  00
# 51                                                  00
# 52                                                  00
# 53                                                  00
# ...                                                ...
# 620282                                              00
# 649084                                              00
# 649085                                              00
# 649086                                              00
# 649088                                              00
#
#        american_indian_or_alaska_native_NUM_PROF
# 49                                           256  \
# 50                                           348
# 51                                           289
# 52                                           348
# 53                                           322
# ...                                          ...
# 620282                                         2
# 649084                                         3
# 649085                                         2
# 649086                                         2
# 649088                                         2
#
#        american_indian_or_alaska_native_PER_PROF
# 49                                            34  \
# 50                                            46
# 51                                            39
# 52                                            46
# 53                                            46
# ...                                          ...
# 620282                                        20
# 649084                                        27
# 649085                                        29
# 649086                                        40
# 649088                                        33
#
#        american_indian_or_alaska_native_TOTAL_SCALE_SCORES
# 49                                                 456387   \
# 50                                                 452614
# 51                                                 442109
# 52                                                 457773
# 53                                                 416506
# ...                                                   ...
# 620282                                               5855
# 649084                                               6480
# 649085                                               4193
# 649086                                               2985
# 649088                                               3583
#
#        american_indian_or_alaska_native_MEAN_SCORE Subject
# 49                                           599.0     ELA
# 50                                           599.0     ELA
# 51                                           599.0     ELA
# 52                                           599.0     ELA
# 53                                           598.0     ELA
# ...                                            ...     ...
# 620282                                       586.0     ELA
# 649084                                       589.0     ELA
# 649085                                       599.0     ELA
# 649086                                       597.0     ELA
# 649088                                       597.0     ELA
#
# [1084 rows x 22 columns]

# %%
def merge_to_base(base_df : pd.DataFrame, df_dict : dict, keep_cols : list[str] = None) -> pd.DataFrame:
    """Takes a base dataframe and a dictionary of dataframes
    and returns a dataframe with all the data merged
    """
    for key in df_dict.keys():

        combined_df = base_df.merge(df_dict[key], on=["ENTITY_CD", "YEAR", "Subject", "ASSESSMENT_NAME"], how="inner")

    combined_df_col_list = [col for col in combined_df.columns]

    if keep_cols is (not None):

        keep_list = []

        for col in keep_cols:

            if col in combined_df.columns:

                col_list.append(col)

        combined_df = (combined_df[["ENTITY_CD", "YEAR", "Subject", "ASSESSMENT_NAME"] + col_list]).copy()

    return combined_df

# %%
"Joojo".__contains__("Joo")
# Out:
# True

# %%
Team_9_keep_cols = ["NUM_TESTED", "NUM_PROF", "TOTAL_SCALE_SCORES", "MEAN_SCORE"]

# %%
["ENTITY_CD", "YEAR", "Subject", "ASSESSMENT_NAME"] + Team_9_keep_cols
# Out:
# ['ENTITY_CD',
#  'YEAR',
#  'Subject',
#  'ASSESSMENT_NAME',
#  'NUM_TESTED',
#  'NUM_PROF',
#  'TOTAL_SCALE_SCORES',
#  'MEAN_SCORE']

# %%
ela_base_combined = merge_to_base(ela_base, ela_dict, Team_9_keep_cols)
# Out:
# []

# %%
ela_base_combined
# Out:
#           ENTITY_CD    YEAR Subject ASSESSMENT_NAME
# 0      1.000000e+00  2017.0     ELA            ELA3
# 1      1.000000e+00  2018.0     ELA            ELA5
# 2      1.000000e+00  2018.0     ELA            ELA3
# 3      1.000000e+00  2018.0     ELA            ELA7
# 4      1.000000e+00  2018.0     ELA            ELA8
# ...             ...     ...     ...             ...
# 18928  6.806011e+11  2018.0     ELA            ELA8
# 18929  6.806011e+11  2018.0     ELA            ELA6
# 18930  6.806011e+11  2018.0     ELA            ELA7
# 18931  6.806011e+11  2018.0     ELA            ELA5
# 18932  6.806011e+11  2018.0     ELA            ELA4
#
# [18933 rows x 4 columns]

# %%
ela_base_combined.shape
# Out:
# (18933, 53)

# %%
ela_base_combined.head()
# Out:
#    ENTITY_CD       ENTITY_NAME_x    YEAR ASSESSMENT_NAME Subject
# 0        1.0  NYC Public Schools  2017.0            ELA3     ELA  \
# 1        1.0  NYC Public Schools  2018.0            ELA5     ELA
# 2        1.0  NYC Public Schools  2018.0            ELA3     ELA
# 3        1.0  NYC Public Schools  2018.0            ELA7     ELA
# 4        1.0  NYC Public Schools  2018.0            ELA8     ELA
#
#    hispanic_or_latino_ENTITY_CD hispanic_or_latino_ENTITY_NAME
# 0                           1.0             NYC Public Schools  \
# 1                           1.0             NYC Public Schools
# 2                           1.0             NYC Public Schools
# 3                           1.0             NYC Public Schools
# 4                           2.0                   Large Cities
#
#    hispanic_or_latino_YEAR hispanic_or_latino_ASSESSMENT_NAME
# 0                   2018.0                               ELA3  \
# 1                   2018.0                               ELA7
# 2                   2018.0                               ELA6
# 3                   2018.0                               ELA4
# 4                   2017.0                               ELA3
#
#   hispanic_or_latino_Subject  ...  white_LEVEL3_COUNT white_LEVEL3_%TESTED
# 0                        ELA  ...                5291                   47  \
# 1                        ELA  ...                3047                   28
# 2                        ELA  ...                6025                   53
# 3                        ELA  ...                3680                   36
# 4                        ELA  ...                2887                   29
#
#    white_LEVEL4_COUNT white_LEVEL4_%TESTED white_LEVEL5_COUNT
# 0                1817                   16                NaN  \
# 1                3336                   30                  0
# 2                1844                   16                  0
# 3                3000                   29                  0
# 4                3820                   39                  0
#
#    white_LEVEL5_%TESTED white_NUM_PROF  white_PER_PROF
# 0                   NaN            NaN             NaN  \
# 1                    00           6383              58
# 2                    00           7869              69
# 3                    00           6680              64
# 4                    00           6707              68
#
#   white_TOTAL_SCALE_SCORES white_MEAN_SCORE
# 0                  3642798            324.0
# 1                  6745329            610.0
# 2                  6950213            609.0
# 3                  6332714            611.0
# 4                  6002917            609.0
#
# [5 rows x 53 columns]

# %%
for i in ela_base_combined.columns:

    if "ENTITY" in i:

        print(i)
# Out:
# ENTITY_CD
# ENTITY_NAME_x
# hispanic_or_latino_ENTITY_CD
# hispanic_or_latino_ENTITY_NAME
# black_or_african_american_ENTITY_CD
# black_or_african_american_ENTITY_NAME
# american_indian_or_alaska_native_ENTITY_CD
# american_indian_or_alaska_native_ENTITY_NAME
# asian_or_native_hawaiian/other_pacific_islander_ENTITY_CD
# asian_or_native_hawaiian/other_pacific_islander_ENTITY_NAME
# multiracial_ENTITY_CD
# multiracial_ENTITY_NAME
# white_ENTITY_CD
# white_ENTITY_NAME
# ENTITY_NAME_y

# %%
special_exp_df = ela_base_combined.copy()

# %%
for i in special_exp_df.columns:

    if "hispanic" in i:

        special_exp_df.drop(columns=[i], inplace=True)

# %%
special_exp_df
# Out:
#           ENTITY_CD               ENTITY_NAME_x    YEAR ASSESSMENT_NAME
# 0      1.000000e+00          NYC Public Schools  2017.0            ELA3  \
# 1      1.000000e+00          NYC Public Schools  2018.0            ELA5
# 2      1.000000e+00          NYC Public Schools  2018.0            ELA3
# 3      1.000000e+00          NYC Public Schools  2018.0            ELA7
# 4      1.000000e+00          NYC Public Schools  2018.0            ELA8
# ...             ...                         ...     ...             ...
# 18928  6.806011e+11      PENN YAN MIDDLE SCHOOL  2018.0            ELA8
# 18929  6.806011e+11      PENN YAN MIDDLE SCHOOL  2018.0            ELA6
# 18930  6.806011e+11      PENN YAN MIDDLE SCHOOL  2018.0            ELA7
# 18931  6.806011e+11  PENN YAN ELEMENTARY SCHOOL  2018.0            ELA5
# 18932  6.806011e+11  PENN YAN ELEMENTARY SCHOOL  2018.0            ELA4
#
#       Subject  black_or_african_american_ENTITY_CD
# 0         ELA                         1.000000e+00  \
# 1         ELA                         1.000000e+00
# 2         ELA                         2.000000e+00
# 3         ELA                         1.406000e+11
# 4         ELA                         1.406000e+11
# ...       ...                                  ...
# 18928     ELA                                  NaN
# 18929     ELA                                  NaN
# 18930     ELA                                  NaN
# 18931     ELA                                  NaN
# 18932     ELA                                  NaN
#
#       black_or_african_american_ENTITY_NAME  black_or_african_american_YEAR
# 0                        NYC Public Schools                          2018.0  \
# 1                        NYC Public Schools                          2018.0
# 2                              Large Cities                          2017.0
# 3                PS 27 HILLERY PARK ACADEMY                          2017.0
# 4               HARRIET ROSS TUBMAN ACADEMY                          2017.0
# ...                                     ...                             ...
# 18928                                   NaN                             NaN
# 18929                                   NaN                             NaN
# 18930                                   NaN                             NaN
# 18931                                   NaN                             NaN
# 18932                                   NaN                             NaN
#
#       black_or_african_american_ASSESSMENT_NAME
# 0                                          ELA8  \
# 1                                          ELA6
# 2                                          ELA3
# 3                                          ELA3
# 4                                          ELA3
# ...                                         ...
# 18928                                       NaN
# 18929                                       NaN
# 18930                                       NaN
# 18931                                       NaN
# 18932                                       NaN
#
#       black_or_african_american_Subject  ...  white_LEVEL3_COUNT
# 0                                   ELA  ...                5291  \
# 1                                   ELA  ...                3047
# 2                                   ELA  ...                6025
# 3                                   ELA  ...                3680
# 4                                   ELA  ...                2887
# ...                                 ...  ...                 ...
# 18928                               NaN  ...                   9
# 18929                               NaN  ...                  17
# 18930                               NaN  ...                  14
# 18931                               NaN  ...                  15
# 18932                               NaN  ...                  25
#
#       white_LEVEL3_%TESTED  white_LEVEL4_COUNT white_LEVEL4_%TESTED
# 0                       47                1817                   16  \
# 1                       28                3336                   30
# 2                       53                1844                   16
# 3                       36                3000                   29
# 4                       29                3820                   39
# ...                    ...                 ...                  ...
# 18928                   14                   7                   11
# 18929                   21                  14                   17
# 18930                   23                   3                   05
# 18931                   23                   9                   14
# 18932                   33                  10                   13
#
#       white_LEVEL5_COUNT  white_LEVEL5_%TESTED white_NUM_PROF  white_PER_PROF
# 0                    NaN                   NaN            NaN             NaN  \
# 1                      0                    00           6383              58
# 2                      0                    00           7869              69
# 3                      0                    00           6680              64
# 4                      0                    00           6707              68
# ...                  ...                   ...            ...             ...
# 18928                  0                    00             16              25
# 18929                  0                    00             31              38
# 18930                  0                    00             17              27
# 18931                  0                    00             24              37
# 18932                  0                    00             35              47
#
#       white_TOTAL_SCALE_SCORES white_MEAN_SCORE
# 0                      3642798            324.0
# 1                      6745329            610.0
# 2                      6950213            609.0
# 3                      6332714            611.0
# 4                      6002917            609.0
# ...                        ...              ...
# 18928                    37924            593.0
# 18929                    48244            596.0
# 18930                    36929            596.0
# 18931                    38990            600.0
# 18932                    44986            600.0
#
# [18933 rows x 48 columns]

# %%
def df_stacker(full_df : pd.DataFrame, to_stack_df : pd.DataFrame) -> pd.DataFrame:
    """Takes a dataframe and stacks it on the full_df
    """
    # Get the columns that are not in the full_df
    
    stacked_df =  pd.concat([full_df, to_stack_df], ignore_index = True, axis=0)

    return stacked_df

# %%
df_stacker(ela_base_combined, special_exp_df)
# Out:
#           ENTITY_CD               ENTITY_NAME_x    YEAR ASSESSMENT_NAME
# 0      1.000000e+00          NYC Public Schools  2017.0            ELA3  \
# 1      1.000000e+00          NYC Public Schools  2018.0            ELA5
# 2      1.000000e+00          NYC Public Schools  2018.0            ELA3
# 3      1.000000e+00          NYC Public Schools  2018.0            ELA7
# 4      1.000000e+00          NYC Public Schools  2018.0            ELA8
# ...             ...                         ...     ...             ...
# 37861  6.806011e+11      PENN YAN MIDDLE SCHOOL  2018.0            ELA8
# 37862  6.806011e+11      PENN YAN MIDDLE SCHOOL  2018.0            ELA6
# 37863  6.806011e+11      PENN YAN MIDDLE SCHOOL  2018.0            ELA7
# 37864  6.806011e+11  PENN YAN ELEMENTARY SCHOOL  2018.0            ELA5
# 37865  6.806011e+11  PENN YAN ELEMENTARY SCHOOL  2018.0            ELA4
#
#       Subject  hispanic_or_latino_ENTITY_CD hispanic_or_latino_ENTITY_NAME
# 0         ELA                           1.0             NYC Public Schools  \
# 1         ELA                           1.0             NYC Public Schools
# 2         ELA                           1.0             NYC Public Schools
# 3         ELA                           1.0             NYC Public Schools
# 4         ELA                           2.0                   Large Cities
# ...       ...                           ...                            ...
# 37861     ELA                           NaN                            NaN
# 37862     ELA                           NaN                            NaN
# 37863     ELA                           NaN                            NaN
# 37864     ELA                           NaN                            NaN
# 37865     ELA                           NaN                            NaN
#
#        hispanic_or_latino_YEAR hispanic_or_latino_ASSESSMENT_NAME
# 0                       2018.0                               ELA3  \
# 1                       2018.0                               ELA7
# 2                       2018.0                               ELA6
# 3                       2018.0                               ELA4
# 4                       2017.0                               ELA3
# ...                        ...                                ...
# 37861                      NaN                                NaN
# 37862                      NaN                                NaN
# 37863                      NaN                                NaN
# 37864                      NaN                                NaN
# 37865                      NaN                                NaN
#
#       hispanic_or_latino_Subject  ...  white_LEVEL3_COUNT
# 0                            ELA  ...                5291  \
# 1                            ELA  ...                3047
# 2                            ELA  ...                6025
# 3                            ELA  ...                3680
# 4                            ELA  ...                2887
# ...                          ...  ...                 ...
# 37861                        NaN  ...                   9
# 37862                        NaN  ...                  17
# 37863                        NaN  ...                  14
# 37864                        NaN  ...                  15
# 37865                        NaN  ...                  25
#
#       white_LEVEL3_%TESTED  white_LEVEL4_COUNT white_LEVEL4_%TESTED
# 0                       47                1817                   16  \
# 1                       28                3336                   30
# 2                       53                1844                   16
# 3                       36                3000                   29
# 4                       29                3820                   39
# ...                    ...                 ...                  ...
# 37861                   14                   7                   11
# 37862                   21                  14                   17
# 37863                   23                   3                   05
# 37864                   23                   9                   14
# 37865                   33                  10                   13
#
#       white_LEVEL5_COUNT  white_LEVEL5_%TESTED white_NUM_PROF  white_PER_PROF
# 0                    NaN                   NaN            NaN             NaN  \
# 1                      0                    00           6383              58
# 2                      0                    00           7869              69
# 3                      0                    00           6680              64
# 4                      0                    00           6707              68
# ...                  ...                   ...            ...             ...
# 37861                  0                    00             16              25
# 37862                  0                    00             31              38
# 37863                  0                    00             17              27
# 37864                  0                    00             24              37
# 37865                  0                    00             35              47
#
#       white_TOTAL_SCALE_SCORES white_MEAN_SCORE
# 0                      3642798            324.0
# 1                      6745329            610.0
# 2                      6950213            609.0
# 3                      6332714            611.0
# 4                      6002917            609.0
# ...                        ...              ...
# 37861                    37924            593.0
# 37862                    48244            596.0
# 37863                    36929            596.0
# 37864                    38990            600.0
# 37865                    44986            600.0
#
# [37866 rows x 53 columns]

# %%
 # Experiments below

# %%
for i in  ela_2018.MEAN_SCORE.unique():

    try:

        float(i)

    except:
            
            print(i)

# %%
ela_2018[ela_2018.MEAN_SCORE == 's'] = np.nan
# ela_2018.MEAN_SCORE = ela_2018.MEAN_SCORE.astype(float)

# %%
ela_2018.MEAN_SCORE = ela_2018.MEAN_SCORE.astype(float)

# %%
for i in ela_2018.MEAN_SCORE.unique():

    if i is np.nan:

        print(i)

# %%
ela_2018[ela_2018.ENTITY_CD == 331400011071]
# Out:
#            ENTITY_CD                         ENTITY_NAME    YEAR
# 0       3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0  \
# 1       3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 2       3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 3       3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 4       3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# ...              ...                                 ...     ...
# 499243  3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 499244  3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 499245  3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 499246  3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 499247  3.314000e+11  JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
#
#        ASSESSMENT_NAME       SUBGROUP_NAME  NUM_TESTED  NOT_TESTED
# 0                 ELA8  Hispanic or Latino        39.0         6.0  \
# 1                 ELA7  Hispanic or Latino        36.0         2.0
# 2                 ELA6  Hispanic or Latino        36.0         2.0
# 3                 ELA8            Homeless         9.0         2.0
# 4                 ELA7            Homeless         6.0         1.0
# ...                ...                 ...         ...         ...
# 499243            ELA7              Female        23.0         2.0
# 499244            ELA6              Female        24.0         0.0
# 499245            ELA8   General Education        42.0         4.0
# 499246            ELA7   General Education        37.0         2.0
# 499247            ELA6   General Education        34.0         1.0
#
#        LEVEL1_COUNT LEVEL1_%TESTED LEVEL2_COUNT  ... LEVEL3_COUNT
# 0                17             44           15  ...            6  \
# 1                15             42           15  ...            5
# 2                 8             22           13  ...           11
# 3                 5             56            2  ...            2
# 4                 4             67            2  ...            0
# ...             ...            ...          ...  ...          ...
# 499243            6             26           11  ...            6
# 499244            5             21           10  ...            6
# 499245           11             26           19  ...            9
# 499246           13             35           15  ...            8
# 499247            5             15           14  ...           10
#
#        LEVEL3_%TESTED LEVEL4_COUNT LEVEL4_%TESTED LEVEL5_COUNT LEVEL5_%TESTED
# 0                  15            1             03            0             00  \
# 1                  14            1             03            0             00
# 2                  31            4             11            0             00
# 3                  22            0             00            0             00
# 4                  00            0             00            0             00
# ...               ...          ...            ...          ...            ...
# 499243             26            0             00            0             00
# 499244             25            3             13            0             00
# 499245             21            3             07            0             00
# 499246             22            1             03            0             00
# 499247             29            5             15            0             00
#
#        NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE
# 0             7       18              22910      587.0
# 1             6       17              21346      593.0
# 2            15       42              21466      596.0
# 3             2       22               5284      587.0
# 4             0       00               3491      582.0
# ...         ...      ...                ...        ...
# 499243        6       26              13759      598.0
# 499244        9       38              14321      597.0
# 499245       12       29              24893      593.0
# 499246        9       24              22090      597.0
# 499247       15       44              20401      600.0
#
# [87 rows x 21 columns]

# %%
# Building the skeleton

t9_df = pd.DataFrame()

# %%
t9_df = ela_2018[["ENTITY_CD","ENTITY_NAME","YEAR","ASSESSMENT_NAME"]].copy()

# %%
t9_df
print(t9_df.shape)
# Out:
# (654694, 4)

# %%
t9_df.drop_duplicates(inplace=True, ignore_index=True)
t9_df.shape
# Out:
# (36740, 4)

# %%
t9_df.head(15)
# Out:
#        ENTITY_CD                                  ENTITY_NAME    YEAR
# 0   3.314000e+11           JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0  \
# 1   3.314000e+11           JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 2   3.314000e+11           JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 3            NaN                                          NaN     NaN
# 4   3.314000e+11  YOUNG WOMEN'S LEADERSHIP SCHOOL OF BROOKLYN  2018.0
# 5   3.314000e+11  YOUNG WOMEN'S LEADERSHIP SCHOOL OF BROOKLYN  2018.0
# 6   3.314000e+11  YOUNG WOMEN'S LEADERSHIP SCHOOL OF BROOKLYN  2018.0
# 7   1.000000e+00                           NYC Public Schools  2017.0
# 8   1.000000e+00                           NYC Public Schools  2018.0
# 9   1.000000e+00                           NYC Public Schools  2018.0
# 10  1.000000e+00                           NYC Public Schools  2018.0
# 11  1.000000e+00                           NYC Public Schools  2018.0
# 12  1.000000e+00                           NYC Public Schools  2018.0
# 13  1.000000e+00                           NYC Public Schools  2018.0
# 14  1.000000e+00                           NYC Public Schools  2018.0
#
#    ASSESSMENT_NAME
# 0             ELA8
# 1             ELA7
# 2             ELA6
# 3              NaN
# 4             ELA8
# 5             ELA7
# 6             ELA6
# 7             ELA3
# 8             ELA5
# 9           ELA3_8
# 10            ELA3
# 11            ELA7
# 12            ELA8
# 13            ELA6
# 14            ELA4

# %%
t9_df['Subject'] = t9_df['ASSESSMENT_NAME'].str.extract(r"([A-Za-z]*).*", expand=False)
t9_df.head(5)
# Out:
#       ENTITY_CD                                  ENTITY_NAME    YEAR
# 0  3.314000e+11           JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0  \
# 1  3.314000e+11           JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 2  3.314000e+11           JUAN MOREL CAMPOS SECONDARY SCHOOL  2018.0
# 3           NaN                                          NaN     NaN
# 4  3.314000e+11  YOUNG WOMEN'S LEADERSHIP SCHOOL OF BROOKLYN  2018.0
#
#   ASSESSMENT_NAME Subject
# 0            ELA8     ELA
# 1            ELA7     ELA
# 2            ELA6     ELA
# 3             NaN     NaN
# 4            ELA8     ELA

# %%
ela_2018.SUBGROUP_NAME.unique()
# Out:
# array(['Hispanic or Latino', 'Homeless', 'Male',
#        'Non-English Language Learners', nan,
#        'Not Economically Disadvantaged', 'Black or African American',
#        'Economically Disadvantaged', 'Female', 'General Education',
#        'All Students', 'American Indian or Alaska Native',
#        'Asian or Native Hawaiian/Other Pacific Islander',
#        'English Language Learners', 'Multiracial', 'Not Migrant',
#        'Students with Disabilities', 'White', 'Migrant',
#        'Small Group Total', 'American Indian or Alaska Native Female',
#        'American Indian or Alaska Native Male',
#        'Asian or Native Hawaiian/Other Pacific Islander Female',
#        'Asian or Native Hawaiian/Other Pacific Islander Male',
#        'Black or African American Female',
#        'Black or African American Male', 'Hispanic or Latino Female',
#        'Hispanic or Latino Male', 'Multiracial Female',
#        'Multiracial Male', 'White Female', 'White Male', 'Not Homeless',
#        'Not in Foster Care', 'Parent in Armed Forces',
#        'Parent Not in Armed Forces', 'In Foster Care'], dtype=object)

# %%
ela_2018.YEAR.unique()
# Out:
# array([2018.,   nan, 2017.])

# %%
sum(ela_2018["MEAN_SCORE"] == "303295s274311s")
# Out:
# 0

# %%
ela_2018[ela_2018["SUBGROUP_NAME"] == "All Students"]

df_dict = {}

for group in ela_2018.SUBGROUP_NAME.unique():

    copy_df = ela_2018[ela_2018["SUBGROUP_NAME"] == group].copy()

    copy_df['Subject'] = copy_df['ASSESSMENT_NAME'].str.extract(r"([A-Za-z]*).*", expand=False)

    copy_df["MEAN_SCORE"].fillna(copy_df.groupby(["YEAR", "ENTITY_CD", "Subject"])["MEAN_SCORE"].transform("mean"), inplace=True)

    df_dict[group] = copy_df

# %%
df_dict["Hispanic or Latino"]
# Out:
#            ENTITY_CD                                  ENTITY_NAME  YEAR
# 0       331400011071           JUAN MOREL CAMPOS SECONDARY SCHOOL  2018  \
# 1       331400011071           JUAN MOREL CAMPOS SECONDARY SCHOOL  2018
# 2       331400011071           JUAN MOREL CAMPOS SECONDARY SCHOOL  2018
# 33      331400011614  YOUNG WOMEN'S LEADERSHIP SCHOOL OF BROOKLYN  2018
# 34      331400011614  YOUNG WOMEN'S LEADERSHIP SCHOOL OF BROOKLYN  2018
# ...              ...                                          ...   ...
# 654529  680801040000               DUNDEE CENTRAL SCHOOL DISTRICT  2018
# 654647  680801040002                     DUNDEE ELEMENTARY SCHOOL  2018
# 654648  680801040002                     DUNDEE ELEMENTARY SCHOOL  2018
# 654649  680801040002                     DUNDEE ELEMENTARY SCHOOL  2018
# 654650  680801040002                     DUNDEE ELEMENTARY SCHOOL  2018
#
#        ASSESSMENT_NAME       SUBGROUP_NAME  NUM_TESTED  NOT_TESTED
# 0                 ELA8  Hispanic or Latino          39           6  \
# 1                 ELA7  Hispanic or Latino          36           2
# 2                 ELA6  Hispanic or Latino          36           2
# 33                ELA8  Hispanic or Latino          24           0
# 34                ELA7  Hispanic or Latino          22           0
# ...                ...                 ...         ...         ...
# 654529            ELA6  Hispanic or Latino           1           0
# 654647            ELA5  Hispanic or Latino           3           0
# 654648            ELA6  Hispanic or Latino           1           0
# 654649            ELA3  Hispanic or Latino           1           0
# 654650            ELA4  Hispanic or Latino           3           0
#
#        LEVEL1_COUNT LEVEL1_%TESTED LEVEL2_COUNT  ... LEVEL3_COUNT
# 0                17             44           15  ...            6  \
# 1                15             42           15  ...            5
# 2                 8             22           13  ...           11
# 33                3             13           11  ...            8
# 34                s              s            s  ...            s
# ...             ...            ...          ...  ...          ...
# 654529            s              s            s  ...            s
# 654647            s              s            s  ...            s
# 654648            s              s            s  ...            s
# 654649            s              s            s  ...            s
# 654650            s              s            s  ...            s
#
#        LEVEL3_%TESTED LEVEL4_COUNT LEVEL4_%TESTED LEVEL5_COUNT LEVEL5_%TESTED
# 0                  15            1             03            0             00  \
# 1                  14            1             03            0             00
# 2                  31            4             11            0             00
# 33                 33            2             08            0             00
# 34                  s            s              s            s              s
# ...               ...          ...            ...          ...            ...
# 654529              s            s              s            s              s
# 654647              s            s              s            s              s
# 654648              s            s              s            s              s
# 654649              s            s              s            s              s
# 654650              s            s              s            s              s
#
#        NUM_PROF PER_PROF TOTAL_SCALE_SCORES MEAN_SCORE
# 0             7       18              22910        587
# 1             6       17              21346        593
# 2            15       42              21466        596
# 33           10       42              14345        598
# 34            s        s                  s          s
# ...         ...      ...                ...        ...
# 654529        s        s                  s          s
# 654647        s        s                  s          s
# 654648        s        s                  s          s
# 654649        s        s                  s          s
# 654650        s        s                  s          s
#
# [28857 rows x 21 columns]

# %%
test_rename = t9_df.copy()
renaming_dn = {}
for col in test_rename.columns:
    print(col)
    renaming_dn[col] = "Race_" + col

test_rename.rename(columns=renaming_dn, inplace=True)

test_rename.head()
# Out:
# ENTITY_CD
# ENTITY_NAME
# YEAR
# ASSESSMENT_NAME
#    race_ENTITY_CD                             race_ENTITY_NAME  race_YEAR
# 0    331400011071           JUAN MOREL CAMPOS SECONDARY SCHOOL       2018  \
# 1    331400011071           JUAN MOREL CAMPOS SECONDARY SCHOOL       2018
# 2    331400011071           JUAN MOREL CAMPOS SECONDARY SCHOOL       2018
# 3    331400011614  YOUNG WOMEN'S LEADERSHIP SCHOOL OF BROOKLYN       2018
# 4    331400011614  YOUNG WOMEN'S LEADERSHIP SCHOOL OF BROOKLYN       2018
#
#   race_ASSESSMENT_NAME
# 0                 ELA8
# 1                 ELA7
# 2                 ELA6
# 3                 ELA7
# 4                 ELA6

# %%
ela_2019 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2019\Annual EM ELA.csv")
math_2019 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2019\Annual EM MATH.csv")
science_2019 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2019\Annual EM SCIENCE.csv")

# %%
# 2020 was unobserved
# notes
# imputation
# stacking schools with years and assessments
# df["MEAN_SCORE"].fillna(df.groupby(["YEAR", "ENTITY_CD", "Subject"])["MEAN_SCORE"].transform("mean"), inplace=True)

# Stack should be a function

# Merge is separate at the end

# %%
ela_2021 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2021\Annual EM ELA.csv")
math_2021 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2021\Annual EM Math.csv")
science_2021 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2021\Annual EM SCIENCE.csv")
# Out:
# C:\Users\ericr\AppData\Local\Temp\ipykernel_48768\1302384497.py:2: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   math_2021 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2021\Annual EM Math.csv")

# %%
ela_2022 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2022\Annual EM ELA.csv")
math_2022 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2022\Annual EM Math.csv")
science_2022 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2022\Annual EM SCIENCE.csv")
# Out:
# C:\Users\ericr\AppData\Local\Temp\ipykernel_48768\1554254005.py:2: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   math_2022 = pd.read_csv(r"C:\Users\ericr\Desktop\IDS 701 - Unifying Data Science\uds final project\Data-20230420T224029Z-001\Data\2022\Annual EM Math.csv")
